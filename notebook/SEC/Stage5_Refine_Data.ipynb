# %%
import pandas as pd
import numpy as np
import seaborn as sns
from os import listdir
import re

import csv
import datetime
import pickle
import os

import calendar
import random

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 500)
pd.options.display.float_format = '{:.0f}'.format

# %%
DATA_ROOT_PATH="/mnt/data/projects/MD1/data/R1000/reports/"
PROJ_ROOT_PATH="/home/priyesh/projects/MD1"

# %%
# Read from Pickle file

filepath = os.path.join(PROJ_ROOT_PATH,'pickle','std_statements_stage4.pkl')
master_std_statements = pd.read_pickle(filepath)

# %%
# Read from Pickle file

filepath = os.path.join(PROJ_ROOT_PATH,'pickle','clean_master_data_stage2.pkl')
clean_master_data = pd.read_pickle(filepath)

# %%
# Read from Pickle file

filepath = os.path.join(PROJ_ROOT_PATH,'pickle','master_data_stage2.pkl')
master_data = pd.read_pickle(filepath)

# %%
# Read from Pickle file

table_labels = {}

filepath = os.path.join(PROJ_ROOT_PATH,'pickle','mappings_cash_stage3.pkl')
table_labels['cash'] = pd.read_pickle(filepath)
                        
filepath = os.path.join(PROJ_ROOT_PATH,'pickle','mappings_bal_stage3.pkl')
table_labels['balance'] = pd.read_pickle(filepath)
                        
filepath = os.path.join(PROJ_ROOT_PATH,'pickle','mappings_income_stage3.pkl')
table_labels['income'] = pd.read_pickle(filepath)

# %%
stype='balance'
table_labels[stype]['headings']
# Out:
#                                                                                     type
# heading
# Eidp | 3.50 Series Preferred Stock [Member]                                         EXCL
# International Annuity [Member]                                                      EXCL
# Non-Controlling Common Units In The Operating Partnership [Member]                  EXCL
# Electric [Member]                                                                   EXCL
# Houston Electric [Member] | Variable Interest Entity, Primary Beneficiary [Member]  EXCL
# ...                                                                                  ...
# Ohio Power Co [Member]                                                              EXCL
# First Horizon National Corporation Shareholders Equity:                               SE
# Ku [Member]                                                                         EXCL
# Unity Software Inc. Stockholders Equity:                                              SE
# Commerce Bancshares, Inc. Stockholders Equity:                                        SE
#
# [612 rows x 1 columns]

# %%
heading_lookup = {}
line_item_lookup = {}

for stype in ['balance','income','cash']:
  print(stype) 
  temp = table_labels[stype]['headings'].to_dict()
  heading_lookup[stype] = temp['type']

  temp = table_labels[stype]['line_items'].to_dict()
  line_item_lookup[stype] = temp['type']
# Out:
# balance
# income
# cash

# %%
clean_master_data['GOOGL'].keys()
# Out:
# dict_keys(['17', '23', '16', '22', '21', '19', '18', '20'])

# %%
def swap_text(type, text, stype):
  
  # Default to original text. Swap if found in lookup.
    
  new_text = text
    
  if text in swap_text_dict[stype][type]:
      
    new_text = swap_text_dict[stype][type][text]

  return new_text

# %%
def find_line_items(table, heading_lookup, line_item_lookup, stype):
 
  df_new = pd.DataFrame()

  h = 'No Heading'
  items_found = []
    
  h_lookup = heading_lookup[stype]
  l_lookup = line_item_lookup[stype]
    
  items_required = list(set(l_lookup.values()))

  # Go through each line in table, if row contains only nan then assume heading

  for index, row in table.iterrows():

    if row.isnull().all():
   
      # If all columns are null then it is either a header we are interested in, a header not recognised 
      # or a line item where values are not specified.
    
      # If we encounter a header that has Member or Abstract then terminate loop and ignore subsequent items.
    
      if index in h_lookup:
        
        h = h_lookup[index]
        
        if h == 'EXCL':
          break
        else:
          r1 = row.copy()
          #r1 = r1.rename(swap_text('H',index,stype))
          r1['type'] = h
          r1['line_type'] = 'H'
          df_new = pd.concat([df_new, pd.DataFrame([r1])])
  
    else:
      # If row matches one of the items mapped for current header then store
    
      if index.startswith('Basic'):
        break
        
      if index.startswith('Net Revenues From Collaborators'):
        break
        
      if re.match(r'^Weighted.*Average.*Shares',index, re.IGNORECASE):
        break
        
      if re.match(r'^Weighted.*Average.*Basic',index, re.IGNORECASE):
        break
        
      if re.match(r'^Earnings.*Common Share.*Basic',index, re.IGNORECASE): 
        break
        
      if re.match(r'^Earnings.*per Share.*Basic',index, re.IGNORECASE): 
        break
        
      if re.match(r'^Net.*Income.*Attrib',index, re.IGNORECASE): 
        break
        
      if index in l_lookup:
        
        l = l_lookup[index]
        items_found.append(l)
          
        r1 = row.copy()
        #r1.rename(swap_text('L',index,stype))
        r1['type'] = l
        r1['line_type'] = 'L'
        df_new = pd.concat([df_new, pd.DataFrame([r1])])

  return(df_new)

# %%
stype='income'
l_lookup = line_item_lookup[stype]
l_lookup['Revenues']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 3
#       1 stype='income'
#       2 l_lookup = line_item_lookup[stype]
# ----> 3 l_lookup['Revenues']
#
# KeyError: 'Revenues'

# %%
def extract_summary(stype):
    
  ticker_list = list(clean_master_data.keys())

  master_statements = {}

  for ticker in ticker_list:

    master_statements[ticker] = {}
    print(ticker)
    
    for yr in clean_master_data[ticker]:
    
      # Extract statement for each year
    
      master_statements[ticker]
      if stype in clean_master_data[ticker][yr]:
        
        master_statements[ticker][yr] = find_line_items(clean_master_data[ticker][yr][stype]['table'],
                                                          heading_lookup,line_item_lookup,stype)
  return master_statements

# %%
def conv_date_cols(cols):
    
  mnth_lookup = {month: index for index, month in enumerate(calendar.month_abbr) if month}

  new_cols = []

  for c in cols:
    
    x = re.search(r"^[A-Z][a-z][a-z]\. \d{2}, \d{4}", c)
    
    if x:
      mnth = mnth_lookup[c.split(".")[0]]
      yr = c[-4:]
      t = yr + '-' + str(mnth)
      new_cols = new_cols + [t]
    else:
      new_cols = new_cols + [c] 

  return new_cols

# %%
def extract_statements(stype, master_summary_data):
    
  ticker_list = list(master_summary_data.keys())

  master_statements = {}

  for ticker in master_summary_data:
    
    print(ticker)
    statement = master_summary_data[ticker]
    keys = list(statement.keys())
    
    if len(keys) > 0:
                                            
      keys = sorted(keys,reverse=True)
      df = statement[keys[0]].copy()
      df = df[~df.index.duplicated(keep='first')]

      for i in range(1,len(keys)):
        
        print("Building Table for",ticker,i)
        
        df1_cols = list(set(statement[keys[i]].columns)- set(df.columns))
        df1 = statement[keys[i]][df1_cols].copy()
        df1 = df1[~df1.index.duplicated(keep='first')] 
        df = df.merge(df1, right_index=True, left_index=True, how='left', suffixes=['_x', '_y'])  
    
      # We could end up with an empty dataframe if there are no matches. So skip if that is the case.
     
      if len(df) > 0:
        # Amend date format of column names
        
        cols = list(df.columns)
        new_cols = conv_date_cols(cols)
        df.columns = new_cols

        # Sort in reverse date order, place type and line_type at end
    
        new_cols.remove('type')
        new_cols.remove('line_type')
        cols = sorted(new_cols,reverse=True) + ['type','line_type']
        df = df[cols]
        
      master_statements[ticker] = df

  return master_statements

# %%
def find_duplicates(df1):

  df_temp = df1.copy()
  df_temp = df_temp.reset_index(names=['line_item'])
  df_dup = df_temp[df_temp.duplicated(subset=['line_item','line_type'])]

  return df_dup

# %%
df1 = clean_master_data['ADI']['11']['income']['table']
df1
# Out:
#                                                          Oct. 29, 2011  \
# line_item
# Revenue                                                            NaN
# Revenue                                                        2993320
# Costs And Expenses                                                 NaN
# Cost Of Sales                                                  1006779
# Gross Margin                                                   1986541
# Operating Expenses:                                                NaN
# Research And Development                                        505570
# SGA                                                             406707
# Special Charges                                                   2239
# Total Operating Expenses                                        914516
# Operating Income From Continuing Operations                    1072025
# Nonoperating Income Expenses:                                      NaN
# Interest Expense                                                 19146
# Interest Income                                                  -9060
# Other, Net                                                         492
# Total Nonoperating Income Expense                                10578
# Earnings                                                           NaN
# Income From Continuing Operations Before Income Taxes          1061447
# Provision For Income Taxes:                                        NaN
# Payable Currently                                               198849
# Deferred                                                          1704
# Provision For Income Taxes                                      200553
# Income From Continuing Operations, Net Of Tax                   860894
# Discontinued Operations, Net Of Tax:                               NaN
# Income From Discontinued Operations                                NaN
# Gain On Sale Of Discontinued Operations                           6500
# Total Income From Discontinued Operations, Net Of Tax             6500
# Net Income                                                      867394
# Shares Used To Compute Earnings Per Share  Basic                299417
# Shares Used To Compute Earnings Per Share  Diluted              308236
# Earnings Per Share  Basic                                          NaN
# Income From Continuing Operations, Net Of Tax                        3
# Net Income                                                           3
# Earnings Per Share  Diluted                                        NaN
# Income From Continuing Operations, Net Of Tax                        3
# Net Income                                                           3
# Dividends Declared And Paid Per Share                                1
# Cost Of Sales [Member]                                             NaN
# Includes Stock-Based Compensation Expense As Follows:              NaN
# Stock-Based Compensation Expense                                  7294
# Research And Development [Member]                                  NaN
# Includes Stock-Based Compensation Expense As Follows:              NaN
# Stock-Based Compensation Expense                                 23289
# Selling, Marketing, General And Administrative [Member]            NaN
# Includes Stock-Based Compensation Expense As Follows:              NaN
# Stock-Based Compensation Expense                                 21775
# Nan                                                                NaN
#
#                                                          Oct. 30, 2010  \
# line_item
# Revenue                                                            NaN
# Revenue                                                        2761503
# Costs And Expenses                                                 NaN
# Cost Of Sales                                                   962081
# Gross Margin                                                   1799422
# Operating Expenses:                                                NaN
# Research And Development                                        492305
# SGA                                                             390560
# Special Charges                                                  16483
# Total Operating Expenses                                        899348
# Operating Income From Continuing Operations                     900074
# Nonoperating Income Expenses:                                      NaN
# Interest Expense                                                 10429
# Interest Income                                                  -9837
# Other, Net                                                       -2183
# Total Nonoperating Income Expense                                -1591
# Earnings                                                           NaN
# Income From Continuing Operations Before Income Taxes           901665
# Provision For Income Taxes:                                        NaN
# Payable Currently                                               200306
# Deferred                                                         -9866
# Provision For Income Taxes                                      190440
# Income From Continuing Operations, Net Of Tax                   711225
# Discontinued Operations, Net Of Tax:                               NaN
# Income From Discontinued Operations                                NaN
# Gain On Sale Of Discontinued Operations                            859
# Total Income From Discontinued Operations, Net Of Tax              859
# Net Income                                                      712084
# Shares Used To Compute Earnings Per Share  Basic                297387
# Shares Used To Compute Earnings Per Share  Diluted              305861
# Earnings Per Share  Basic                                          NaN
# Income From Continuing Operations, Net Of Tax                        2
# Net Income                                                           2
# Earnings Per Share  Diluted                                        NaN
# Income From Continuing Operations, Net Of Tax                        2
# Net Income                                                           2
# Dividends Declared And Paid Per Share                                1
# Cost Of Sales [Member]                                             NaN
# Includes Stock-Based Compensation Expense As Follows:              NaN
# Stock-Based Compensation Expense                                  7333
# Research And Development [Member]                                  NaN
# Includes Stock-Based Compensation Expense As Follows:              NaN
# Stock-Based Compensation Expense                                 23342
# Selling, Marketing, General And Administrative [Member]            NaN
# Includes Stock-Based Compensation Expense As Follows:              NaN
# Stock-Based Compensation Expense                                 21077
# Nan                                                                NaN
#
#                                                          Oct. 31, 2009
# line_item
# Revenue                                                            NaN
# Revenue                                                        2014908
# Costs And Expenses                                                 NaN
# Cost Of Sales                                                   896271
# Gross Margin                                                   1118637
# Operating Expenses:                                                NaN
# Research And Development                                        446980
# SGA                                                             333184
# Special Charges                                                  53656
# Total Operating Expenses                                        833820
# Operating Income From Continuing Operations                     284817
# Nonoperating Income Expenses:                                      NaN
# Interest Expense                                                  4094
# Interest Income                                                 -15621
# Other, Net                                                       -1100
# Total Nonoperating Income Expense                               -12627
# Earnings                                                           NaN
# Income From Continuing Operations Before Income Taxes           297444
# Provision For Income Taxes:                                        NaN
# Payable Currently                                                38441
# Deferred                                                         11595
# Provision For Income Taxes                                       50036
# Income From Continuing Operations, Net Of Tax                   247408
# Discontinued Operations, Net Of Tax:                               NaN
# Income From Discontinued Operations                                364
# Gain On Sale Of Discontinued Operations                            NaN
# Total Income From Discontinued Operations, Net Of Tax              364
# Net Income                                                      247772
# Shares Used To Compute Earnings Per Share  Basic                291385
# Shares Used To Compute Earnings Per Share  Diluted              292698
# Earnings Per Share  Basic                                          NaN
# Income From Continuing Operations, Net Of Tax                        1
# Net Income                                                           1
# Earnings Per Share  Diluted                                        NaN
# Income From Continuing Operations, Net Of Tax                        1
# Net Income                                                           1
# Dividends Declared And Paid Per Share                                1
# Cost Of Sales [Member]                                             NaN
# Includes Stock-Based Compensation Expense As Follows:              NaN
# Stock-Based Compensation Expense                                  7469
# Research And Development [Member]                                  NaN
# Includes Stock-Based Compensation Expense As Follows:              NaN
# Stock-Based Compensation Expense                                 22666
# Selling, Marketing, General And Administrative [Member]            NaN
# Includes Stock-Based Compensation Expense As Follows:              NaN
# Stock-Based Compensation Expense                                 18478
# Nan                                                                NaN

# %%
df1 = find_line_items(df1, heading_lookup, line_item_lookup, 'income')
df1
# Out:
#                                                        Oct. 29, 2011  \
# Revenue                                                          NaN
# Costs And Expenses                                               NaN
# Cost Of Sales                                                1006779
# Gross Margin                                                 1986541
# Research And Development                                      505570
# SGA                                                           406707
# Total Operating Expenses                                      914516
# Operating Income From Continuing Operations                  1072025
# Income From Continuing Operations Before Income Taxes        1061447
# Income From Continuing Operations, Net Of Tax                 860894
# Net Income                                                    867394
#
#                                                        Oct. 30, 2010  \
# Revenue                                                          NaN
# Costs And Expenses                                               NaN
# Cost Of Sales                                                 962081
# Gross Margin                                                 1799422
# Research And Development                                      492305
# SGA                                                           390560
# Total Operating Expenses                                      899348
# Operating Income From Continuing Operations                   900074
# Income From Continuing Operations Before Income Taxes         901665
# Income From Continuing Operations, Net Of Tax                 711225
# Net Income                                                    712084
#
#                                                        Oct. 31, 2009 type  \
# Revenue                                                          NaN    R
# Costs And Expenses                                               NaN   OE
# Cost Of Sales                                                 896271   CR
# Gross Margin                                                 1118637   GM
# Research And Development                                      446980   RD
# SGA                                                           333184  SGA
# Total Operating Expenses                                      833820  TOE
# Operating Income From Continuing Operations                   284817  ICO
# Income From Continuing Operations Before Income Taxes         297444  ICO
# Income From Continuing Operations, Net Of Tax                 247408  ICO
# Net Income                                                    247772   NI
#
#                                                       line_type
# Revenue                                                       H
# Costs And Expenses                                            H
# Cost Of Sales                                                 L
# Gross Margin                                                  L
# Research And Development                                      L
# SGA                                                           L
# Total Operating Expenses                                      L
# Operating Income From Continuing Operations                   L
# Income From Continuing Operations Before Income Taxes         L
# Income From Continuing Operations, Net Of Tax                 L
# Net Income                                                    L

# %%
master_data['NFG']['22']['income']
# Out:
#    Consolidated Statements Of Income And Earnings Reinvested In The Business - USD ($)  $ in Thousands  \
#    Consolidated Statements Of Income And Earnings Reinvested In The Business - USD ($)  $ in Thousands
# 0                                                                                               INCOME
# 1                                                                                   Operating Revenues
# 2                                                                                  Operating Expenses:
# 3                                                                                        Purchased Gas
# 4                                                                  Property, Franchise and Other Taxes
# 5                                                             Depreciation, Depletion and Amortization
# 6                                                       Impairment of Oil and Gas Producing Properties
# 7                                                                             Total Operating Expenses
# 8                                                                               Gain on Sale of Assets
# 9                                                                                     Operating Income
# 10                                                                             Other Income (Expense):
# 11                                                                           Other Income (Deductions)
# 12                                                                  Interest Expense on Long-Term Debt
# 13                                                                              Other Interest Expense
# 14                                                                   Income (Loss) Before Income Taxes
# 15                                                                                  Income Tax Expense
# 16                                                        Net Income (Loss) Available for Common Stock
# 17                                                                 EARNINGS REINVESTED IN THE BUSINESS
# 18                                                                        Balance at Beginning of Year
# 19                            Beginning Retained Earnings Unappropriated And Current Period Net Income
# 20                                                                           Dividends on Common Stock
# 21                                                                              Balance at End of Year
# 22                                                            Earnings (Loss) Per Common Share, Basic:
# 23                                 Net Income (Loss) Available for Common Stock (in dollars per share)
# 24                                                          Earnings (Loss) Per Common Share, Diluted:
# 25                                 Net Income (Loss) Available for Common Stock (in dollars per share)
# 26                                                      Weighted Average Number of Shares Outstanding:
# 27                                                                           Used in Basic Calculation
# 28                                                                         Used in Diluted Calculation
# 29                                                               Utility and Energy Marketing [Member]
# 30                                                                                              INCOME
# 31                                                                                  Operating Revenues
# 32                                                                                 Operating Expenses:
# 33                                                                           Operation and Maintenance
# 34                                                       Exploration and Production and Other [Member]
# 35                                                                                              INCOME
# 36                                                                                  Operating Revenues
# 37                                                                                 Operating Expenses:
# 38                                                                           Operation and Maintenance
# 39                                                         Pipeline and Storage and Gathering [Member]
# 40                                                                                              INCOME
# 41                                                                                  Operating Revenues
# 42                                                                                 Operating Expenses:
# 43                                                                           Operation and Maintenance
# 44    Guidance for Hedging [Member] | Cumulative Effect of Adoption of Authoritative Guidance [Member]
# 45                                                                 EARNINGS REINVESTED IN THE BUSINESS
# 46                                                                        Balance at Beginning of Year
# 47                                                                              Balance at End of Year
#
#    12 Months Ended
#      Sep. 30, 2022 Sep. 30, 2021 Sep. 30, 2020
# 0              NaN           NaN           NaN
# 1      $ 2,186,046   $ 1,742,659   $ 1,546,291
# 2              NaN           NaN           NaN
# 3           392093        171827        233890
# 4           101182         94713         88400
# 5           369790        335303        306158
# 6                0         76152        449438
# 7          1384266       1153801       1516433
# 8         (12,736)      (51,066)             0
# 9           814516        639924         29858
# 10             NaN           NaN           NaN
# 11         (1,509)      (15,238)      (17,814)
# 12       (120,507)     (141,457)     (110,012)
# 13         (9,850)       (4,900)       (7,065)
# 14          682650        478329     (105,033)
# 15          116629        114682         18739
# 16          566021        363647     (123,772)
# 17             NaN           NaN           NaN
# 18         1191175        991630       1272601
# 19         1757196       1355277       1148829
# 20       (170,111)     (164,102)     (156,249)
# 21     $ 1,587,085   $ 1,191,175     $ 991,630
# 22             NaN           NaN           NaN
# 23          $ 6.19        $ 3.99      $ (1.41)
# 24             NaN           NaN           NaN
# 25          $ 6.15        $ 3.97      $ (1.41)
# 26             NaN           NaN           NaN
# 27        91410625      91130941      87968895
# 28        92107066      91684583      87968895
# 29             NaN           NaN           NaN
# 30             NaN           NaN           NaN
# 31       $ 897,916     $ 667,549     $ 728,336
# 32             NaN           NaN           NaN
# 33          193058        179547        181051
# 34             NaN           NaN           NaN
# 35             NaN           NaN           NaN
# 36         1010629        837597        611885
# 37             NaN           NaN           NaN
# 38          191572        173041        148856
# 39             NaN           NaN           NaN
# 40             NaN           NaN           NaN
# 41          277501        237513        206070
# 42             NaN           NaN           NaN
# 43          136571        123218        108640
# 44             NaN           NaN           NaN
# 45             NaN           NaN           NaN
# 46             $ 0             0         (950)
# 47             NaN           $ 0           $ 0

# %%
# Create lookup dictionaries

swap_text_dict = {}
swap_text_dict['income'] = {}
swap_text_dict['cash'] = {}
swap_text_dict['balance'] = {}
              
swap_text_dict['income']['H'] = {}
swap_text_dict['income']['L'] = {}

swap_text_dict['cash']['H'] = {}
swap_text_dict['cash']['L'] = {}

swap_text_dict['balance']['H'] = {}
swap_text_dict['balance']['L'] = {}

# %% [markdown]
# ## Income Statement

# %%
income_summary = extract_summary('income')
# Out:
# AA
# AAL
# AAP
# AAPL
# ABBV
# ABNB
# ABT
# ACGL
# ACHC
# ACI
# ACM
# ACN
# ADBE
# ADI
# ADM
# ADP
# ADSK
# ADT
# AEE
# AEP
# AES
# AFG
# AFL
# AFRM
# AGCO
# AGL
# AGNC
# AGO
# AGR
# AIG
# AIZ
# AJG
# AKAM
# AL
# ALB
# ALGM
# ALGN
# ALK
# ALL
# ALLE
# ALLY
# ALNY
# ALSN
# AM
# AMAT
# AMC
# AMCR
# AMD
# AME
# AMED
# AMG
# AMGN
# AMP
# AMZN
# AN
# ANET
# ANSS
# AON
# AOS
# APA
# APD
# APH
# APO
# APP
# APTV
# AR
# ARES
# ARMK
# ARW
# ASH
# ATO
# ATR
# ATUS
# ATVI
# AVGO
# AVT
# AVTR
# AWI
# AWK
# AXON
# AXS
# AXTA
# AYI
# AYX
# AZEK
# AZO
# AZTA
# BA
# BAC
# BAH
# BALL
# BAX
# BBWI
# BBY
# BC
# BDX
# BEN
# BERY
# BFAM
# BG
# BHF
# BIIB
# BILL
# BIO
# BJ
# BK
# BKNG
# BLD
# BLDR
# BLK
# BMRN
# BMY
# BOKF
# BR
# BRKR
# BRO
# BSX
# BSY
# BURL
# BWA
# BWXT
# BX
# BYD
# C
# CABO
# CACC
# CAH
# CAR
# CARR
# CAT
# CB
# CBOE
# CBSH
# CC
# CCCS
# CCK
# CCL
# CDAY
# CDNS
# CDW
# CE
# CEG
# CERT
# CF
# CFG
# CFLT
# CFR
# CG
# CGNX
# CHD
# CHDN
# CHE
# CHH
# CHPT
# CHRW
# CHTR
# CIEN
# CINF
# CL
# CLH
# CLVT
# CLX
# CMA
# CMCSA
# CME
# CMG
# CMI
# CMS
# CNA
# CNM
# CNP
# CNXC
# COF
# COIN
# COLB
# COLM
# COO
# COST
# COTY
# CPB
# CPRI
# CPRT
# CR
# CRI
# CRL
# CRUS
# CRWD
# CSCO
# CSL
# CTLT
# CTRA
# CTSH
# CTVA
# CVNA
# CVX
# CW
# CZR
# D
# DAL
# DAR
# DASH
# DBX
# DCI
# DD
# DDOG
# DECK
# DFS
# DG
# DGX
# DHI
# DHR
# DINO
# DIS
# DISH
# DKNG
# DKS
# DLB
# DLTR
# DNA
# DOCS
# DOCU
# DOV
# DOW
# DPZ
# DRVN
# DT
# DTE
# DTM
# DUK
# DV
# DVA
# DVN
# DXC
# DXCM
# EA
# EBAY
# ECL
# ED
# EEFT
# EFX
# EHAB
# EHC
# EIX
# EL
# ELAN
# EMN
# EMR
# ENOV
# ENPH
# ENTG
# EOG
# EPAM
# EQH
# EQT
# ERIE
# ES
# ESAB
# ESI
# ESTC
# ETN
# ETR
# ETSY
# EVA
# EVR
# EVRG
# EW
# EWBC
# EXAS
# EXC
# EXEL
# EXP
# EXPD
# EXPE
# F
# FAF
# FANG
# FAST
# FCN
# FCNCA
# FCX
# FDS
# FE
# FFIV
# FG
# FHB
# FHN
# FICO
# FIS
# FISV
# FITB
# FIVE
# FIVN
# FLO
# FLS
# FLT
# FMC
# FNB
# FND
# FNF
# FOUR
# FOX
# FRPT
# FSLR
# FTNT
# FTV
# G
# GD
# GDDY
# GE
# GGG
# GILD
# GL
# GLW
# GM
# GME
# GMED
# GNRC
# GNTX
# GO
# GOOG
# GOOGL
# GPC
# GPK
# GPN
# GPS
# GRMN
# GS
# GTES
# GWRE
# GWW
# GXO
# H
# HAL
# HAS
# HAYW
# HBAN
# HBI
# HCA
# HD
# HE
# HEI
# HES
# HIG
# HII
# HLT
# HOG
# HOLX
# HON
# HPE
# HPP
# HPQ
# HRL
# HSIC
# HSY
# HTZ
# HUBB
# HUBS
# HUN
# HWM
# HXL
# HZNP
# IAC
# IART
# IBKR
# IBM
# ICE
# ICUI
# IDA
# IDXX
# IEX
# IFF
# ILMN
# INCY
# INFA
# INGR
# INTC
# INTU
# IONS
# IP
# IPG
# IPGP
# IQV
# IR
# ISRG
# IT
# ITT
# ITW
# IVZ
# J
# JAMF
# JAZZ
# JBHT
# JBL
# JBLU
# JCI
# JEF
# JHG
# JKHY
# JNJ
# JNPR
# JPM
# JWN
# K
# KBR
# KDP
# KEX
# KEY
# KEYS
# KHC
# KKR
# KLAC
# KMB
# KMI
# KMPR
# KMX
# KNX
# KO
# KR
# KSS
# L
# LAD
# LAZ
# LBRDA
# LCID
# LDOS
# LEA
# LECO
# LEG
# LEN
# LESL
# LFUS
# LH
# LHX
# LII
# LITE
# LKQ
# LLY
# LMT
# LNC
# LNG
# LNT
# LOPE
# LOW
# LPLA
# LPX
# LRCX
# LSCC
# LSTR
# LULU
# LUMN
# LUV
# LVS
# LYB
# LYFT
# LYV
# M
# MA
# MAN
# MANH
# MAR
# MAS
# MASI
# MAT
# MCD
# MCHP
# MCK
# MCO
# MCW
# MDB
# MDLZ
# MDT
# MDU
# MET
# META
# MGM
# MHK
# MIDD
# MKC
# MKL
# MKSI
# MKTX
# MLM
# MMC
# MMM
# MNST
# MO
# MORN
# MOS
# MP
# MPC
# MPWR
# MRCY
# MRK
# MRNA
# MRO
# MRTX
# MRVI
# MRVL
# MS
# MSA
# MSCI
# MSFT
# MSGS
# MSI
# MSM
# MTB
# MTCH
# MTD
# MTG
# MTN
# MTZ
# MU
# NATI
# NBIX
# NCLH
# NCNO
# NCR
# NDAQ
# NDSN
# NEE
# NEM
# NET
# NEU
# NEWR
# NFE
# NFG
# NFLX
# NI
# NLY
# NOC
# NOV
# NOW
# NRG
# NSC
# NTAP
# NTNX
# NTRA
# NTRS
# NUE
# NVAX
# NVCR
# NVDA
# NVR
# NVST
# NVT
# NWL
# NWS
# NXST
# NYCB
# NYT
# OC
# ODFL
# OGE
# OGN
# OKE
# OKTA
# OLED
# OLLI
# OLN
# OLPX
# OMC
# OMF
# ON
# ORI
# ORLY
# OSH
# OTIS
# OVV
# OWL
# OXY
# PACW
# PAG
# PANW
# PARA
# PATH
# PAYC
# PB
# PCAR
# PCG
# PCOR
# PCTY
# PDCE
# PEG
# PEGA
# PEN
# PENN
# PEP
# PFE
# PFG
# PFGC
# PG
# PGR
# PH
# PHM
# PII
# PINC
# PINS
# PKG
# PKI
# PLNT
# PLTK
# PLTR
# PLUG
# PM
# PNC
# PNFP
# PNR
# PNW
# PODD
# POOL
# POST
# PPC
# PPG
# PPL
# PRGO
# PRI
# PRU
# PSTG
# PSX
# PTC
# PTON
# PVH
# PWR
# PXD
# PYPL
# QCOM
# QDEL
# QRVO
# QS
# RARE
# RE
# REGN
# REYN
# RF
# RGA
# RGEN
# RH
# RJF
# RL
# RMD
# RNG
# RNR
# RRC
# RRX
# RS
# RSG
# RTX
# RUN
# S
# SAM
# SBUX
# SCCO
# SCHW
# SCI
# SEB
# SEE
# SEIC
# SF
# SGEN
# SHC
# SHW
# SIRI
# SITE
# SIX
# SJM
# SKX
# SLB
# SLGN
# SMAR
# SMG
# SNA
# SNDR
# SNOW
# SNPS
# SNV
# SNX
# SO
# SOFI
# SON
# SPB
# SPLK
# SPR
# SQ
# SRCL
# SRE
# SSNC
# SSRM
# ST
# STE
# STLD
# STT
# STWD
# STZ
# SWK
# SWKS
# SWN
# SYF
# SYK
# SYNH
# SYY
# T
# TAP
# TDC
# TDG
# TDOC
# TDY
# TECH
# TER
# TFC
# TFSL
# TFX
# TGT
# THC
# THG
# THO
# TJX
# TKR
# TMO
# TMUS
# TNDM
# TNL
# TOL
# TOST
# TPL
# TPR
# TPX
# TREX
# TRGP
# TRIP
# TRMB
# TROW
# TRU
# TRV
# TSCO
# TSLA
# TSN
# TT
# TTC
# TTD
# TTEK
# TTWO
# TW
# TWKS
# TWLO
# TXG
# TXN
# TXT
# TYL
# U
# UAL
# UBER
# UGI
# UHS
# UI
# ULTA
# UNM
# UNP
# UNVR
# UPS
# UPST
# URI
# USB
# USFD
# UTHR
# UWMC
# V
# VAC
# VEEV
# VFC
# VIRT
# VLO
# VMC
# VMI
# VMW
# VNT
# VOYA
# VRSK
# VRSN
# VRT
# VRTX
# VSAT
# VSCO
# VST
# VTRS
# VVV
# VZ
# W
# WAB
# WAL
# WAT
# WBA
# WBD
# WBS
# WCC
# WDAY
# WDC
# WEC
# WEN
# WEX
# WFC
# WH
# WHR
# WLK
# WM
# WMB
# WMS
# WMT
# WOLF
# WOOF
# WRB
# WRK
# WSC
# WSM
# WSO
# WST
# WTFC
# WTM
# WTRG
# WTW
# WU
# WWD
# WWE
# WYNN
# X
# XEL
# XOM
# XPO
# XRAY
# XYL
# YETI
# YUM
# Z
# ZBRA

# %%
income_summary['NFG']['22']
# Out:
#                                                        Dec. 31, 2019  \
# Revenues                                                         NaN
# Total Revenue                                                   4891
# Total Losses And Expenses                                       4369
# Income From Continuing Operations Before Income Taxes            522
# Income From Continuing Operations                                429
# Net Income                                                       425
#
#                                                        Dec. 31, 2018  \
# Revenues                                                         NaN
# Total Revenue                                                   4494
# Total Losses And Expenses                                       4212
# Income From Continuing Operations Before Income Taxes            282
# Income From Continuing Operations                                239
# Net Income                                                       391
#
#                                                        Dec. 31, 2017 type  \
# Revenues                                                         NaN    R
# Total Revenue                                                   4268   TR
# Total Losses And Expenses                                       3975  TOE
# Income From Continuing Operations Before Income Taxes            293  ICO
# Income From Continuing Operations                                216  ICO
# Net Income                                                       186   NI
#
#                                                       line_type
# Revenues                                                      H
# Total Revenue                                                 L
# Total Losses And Expenses                                     L
# Income From Continuing Operations Before Income Taxes         L
# Income From Continuing Operations                             L
# Net Income                                                    L

# %%
dups_list = []
tickers_with_dups = {}

ticker_list = list(income_summary.keys())

for ticker in ticker_list:
  
  print(ticker)
    
  for yr in income_summary[ticker]:
    
    df_dup = find_duplicates(income_summary[ticker][yr])
    
    if len(df_dup) > 0:
      
       dups = {}
       dups['yr'] = yr
       dups['df_orig'] = income_summary[ticker][yr]
       dups['df_dup']  = df_dup
        
       tickers_with_dups[ticker] = dups
# Out:
# AA
# AAL
# AAP
# AAPL
# ABBV
# ABNB
# ABT
# ACGL
# ACHC
# ACI
# ACM
# ACN
# ADBE
# ADI
# ADM
# ADP
# ADSK
# ADT
# AEE
# AEP
# AES
# AFG
# AFL
# AFRM
# AGCO
# AGL
# AGNC
# AGO
# AGR
# AIG
# AIZ
# AJG
# AKAM
# AL
# ALB
# ALGM
# ALGN
# ALK
# ALL
# ALLE
# ALLY
# ALNY
# ALSN
# AM
# AMAT
# AMC
# AMCR
# AMD
# AME
# AMED
# AMG
# AMGN
# AMP
# AMZN
# AN
# ANET
# ANSS
# AON
# AOS
# APA
# APD
# APH
# APO
# APP
# APTV
# AR
# ARES
# ARMK
# ARW
# ASH
# ATO
# ATR
# ATUS
# ATVI
# AVGO
# AVT
# AVTR
# AWI
# AWK
# AXON
# AXS
# AXTA
# AYI
# AYX
# AZEK
# AZO
# AZTA
# BA
# BAC
# BAH
# BALL
# BAX
# BBWI
# BBY
# BC
# BDX
# BEN
# BERY
# BFAM
# BG
# BHF
# BIIB
# BILL
# BIO
# BJ
# BK
# BKNG
# BLD
# BLDR
# BLK
# BMRN
# BMY
# BOKF
# BR
# BRKR
# BRO
# BSX
# BSY
# BURL
# BWA
# BWXT
# BX
# BYD
# C
# CABO
# CACC
# CAH
# CAR
# CARR
# CAT
# CB
# CBOE
# CBSH
# CC
# CCCS
# CCK
# CCL
# CDAY
# CDNS
# CDW
# CE
# CEG
# CERT
# CF
# CFG
# CFLT
# CFR
# CG
# CGNX
# CHD
# CHDN
# CHE
# CHH
# CHPT
# CHRW
# CHTR
# CIEN
# CINF
# CL
# CLH
# CLVT
# CLX
# CMA
# CMCSA
# CME
# CMG
# CMI
# CMS
# CNA
# CNM
# CNP
# CNXC
# COF
# COIN
# COLB
# COLM
# COO
# COST
# COTY
# CPB
# CPRI
# CPRT
# CR
# CRI
# CRL
# CRUS
# CRWD
# CSCO
# CSL
# CTLT
# CTRA
# CTSH
# CTVA
# CVNA
# CVX
# CW
# CZR
# D
# DAL
# DAR
# DASH
# DBX
# DCI
# DD
# DDOG
# DECK
# DFS
# DG
# DGX
# DHI
# DHR
# DINO
# DIS
# DISH
# DKNG
# DKS
# DLB
# DLTR
# DNA
# DOCS
# DOCU
# DOV
# DOW
# DPZ
# DRVN
# DT
# DTE
# DTM
# DUK
# DV
# DVA
# DVN
# DXC
# DXCM
# EA
# EBAY
# ECL
# ED
# EEFT
# EFX
# EHAB
# EHC
# EIX
# EL
# ELAN
# EMN
# EMR
# ENOV
# ENPH
# ENTG
# EOG
# EPAM
# EQH
# EQT
# ERIE
# ES
# ESAB
# ESI
# ESTC
# ETN
# ETR
# ETSY
# EVA
# EVR
# EVRG
# EW
# EWBC
# EXAS
# EXC
# EXEL
# EXP
# EXPD
# EXPE
# F
# FAF
# FANG
# FAST
# FCN
# FCNCA
# FCX
# FDS
# FE
# FFIV
# FG
# FHB
# FHN
# FICO
# FIS
# FISV
# FITB
# FIVE
# FIVN
# FLO
# FLS
# FLT
# FMC
# FNB
# FND
# FNF
# FOUR
# FOX
# FRPT
# FSLR
# FTNT
# FTV
# G
# GD
# GDDY
# GE
# GGG
# GILD
# GL
# GLW
# GM
# GME
# GMED
# GNRC
# GNTX
# GO
# GOOG
# GOOGL
# GPC
# GPK
# GPN
# GPS
# GRMN
# GS
# GTES
# GWRE
# GWW
# GXO
# H
# HAL
# HAS
# HAYW
# HBAN
# HBI
# HCA
# HD
# HE
# HEI
# HES
# HIG
# HII
# HLT
# HOG
# HOLX
# HON
# HPE
# HPP
# HPQ
# HRL
# HSIC
# HSY
# HTZ
# HUBB
# HUBS
# HUN
# HWM
# HXL
# HZNP
# IAC
# IART
# IBKR
# IBM
# ICE
# ICUI
# IDA
# IDXX
# IEX
# IFF
# ILMN
# INCY
# INFA
# INGR
# INTC
# INTU
# IONS
# IP
# IPG
# IPGP
# IQV
# IR
# ISRG
# IT
# ITT
# ITW
# IVZ
# J
# JAMF
# JAZZ
# JBHT
# JBL
# JBLU
# JCI
# JEF
# JHG
# JKHY
# JNJ
# JNPR
# JPM
# JWN
# K
# KBR
# KDP
# KEX
# KEY
# KEYS
# KHC
# KKR
# KLAC
# KMB
# KMI
# KMPR
# KMX
# KNX
# KO
# KR
# KSS
# L
# LAD
# LAZ
# LBRDA
# LCID
# LDOS
# LEA
# LECO
# LEG
# LEN
# LESL
# LFUS
# LH
# LHX
# LII
# LITE
# LKQ
# LLY
# LMT
# LNC
# LNG
# LNT
# LOPE
# LOW
# LPLA
# LPX
# LRCX
# LSCC
# LSTR
# LULU
# LUMN
# LUV
# LVS
# LYB
# LYFT
# LYV
# M
# MA
# MAN
# MANH
# MAR
# MAS
# MASI
# MAT
# MCD
# MCHP
# MCK
# MCO
# MCW
# MDB
# MDLZ
# MDT
# MDU
# MET
# META
# MGM
# MHK
# MIDD
# MKC
# MKL
# MKSI
# MKTX
# MLM
# MMC
# MMM
# MNST
# MO
# MORN
# MOS
# MP
# MPC
# MPWR
# MRCY
# MRK
# MRNA
# MRO
# MRTX
# MRVI
# MRVL
# MS
# MSA
# MSCI
# MSFT
# MSGS
# MSI
# MSM
# MTB
# MTCH
# MTD
# MTG
# MTN
# MTZ
# MU
# NATI
# NBIX
# NCLH
# NCNO
# NCR
# NDAQ
# NDSN
# NEE
# NEM
# NET
# NEU
# NEWR
# NFE
# NFG
# NFLX
# NI
# NLY
# NOC
# NOV
# NOW
# NRG
# NSC
# NTAP
# NTNX
# NTRA
# NTRS
# NUE
# NVAX
# NVCR
# NVDA
# NVR
# NVST
# NVT
# NWL
# NWS
# NXST
# NYCB
# NYT
# OC
# ODFL
# OGE
# OGN
# OKE
# OKTA
# OLED
# OLLI
# OLN
# OLPX
# OMC
# OMF
# ON
# ORI
# ORLY
# OSH
# OTIS
# OVV
# OWL
# OXY
# PACW
# PAG
# PANW
# PARA
# PATH
# PAYC
# PB
# PCAR
# PCG
# PCOR
# PCTY
# PDCE
# PEG
# PEGA
# PEN
# PENN
# PEP
# PFE
# PFG
# PFGC
# PG
# PGR
# PH
# PHM
# PII
# PINC
# PINS
# PKG
# PKI
# PLNT
# PLTK
# PLTR
# PLUG
# PM
# PNC
# PNFP
# PNR
# PNW
# PODD
# POOL
# POST
# PPC
# PPG
# PPL
# PRGO
# PRI
# PRU
# PSTG
# PSX
# PTC
# PTON
# PVH
# PWR
# PXD
# PYPL
# QCOM
# QDEL
# QRVO
# QS
# RARE
# RE
# REGN
# REYN
# RF
# RGA
# RGEN
# RH
# RJF
# RL
# RMD
# RNG
# RNR
# RRC
# RRX
# RS
# RSG
# RTX
# RUN
# S
# SAM
# SBUX
# SCCO
# SCHW
# SCI
# SEB
# SEE
# SEIC
# SF
# SGEN
# SHC
# SHW
# SIRI
# SITE
# SIX
# SJM
# SKX
# SLB
# SLGN
# SMAR
# SMG
# SNA
# SNDR
# SNOW
# SNPS
# SNV
# SNX
# SO
# SOFI
# SON
# SPB
# SPLK
# SPR
# SQ
# SRCL
# SRE
# SSNC
# SSRM
# ST
# STE
# STLD
# STT
# STWD
# STZ
# SWK
# SWKS
# SWN
# SYF
# SYK
# SYNH
# SYY
# T
# TAP
# TDC
# TDG
# TDOC
# TDY
# TECH
# TER
# TFC
# TFSL
# TFX
# TGT
# THC
# THG
# THO
# TJX
# TKR
# TMO
# TMUS
# TNDM
# TNL
# TOL
# TOST
# TPL
# TPR
# TPX
# TREX
# TRGP
# TRIP
# TRMB
# TROW
# TRU
# TRV
# TSCO
# TSLA
# TSN
# TT
# TTC
# TTD
# TTEK
# TTWO
# TW
# TWKS
# TWLO
# TXG
# TXN
# TXT
# TYL
# U
# UAL
# UBER
# UGI
# UHS
# UI
# ULTA
# UNM
# UNP
# UNVR
# UPS
# UPST
# URI
# USB
# USFD
# UTHR
# UWMC
# V
# VAC
# VEEV
# VFC
# VIRT
# VLO
# VMC
# VMI
# VMW
# VNT
# VOYA
# VRSK
# VRSN
# VRT
# VRTX
# VSAT
# VSCO
# VST
# VTRS
# VVV
# VZ
# W
# WAB
# WAL
# WAT
# WBA
# WBD
# WBS
# WCC
# WDAY
# WDC
# WEC
# WEN
# WEX
# WFC
# WH
# WHR
# WLK
# WM
# WMB
# WMS
# WMT
# WOLF
# WOOF
# WRB
# WRK
# WSC
# WSM
# WSO
# WST
# WTFC
# WTM
# WTRG
# WTW
# WU
# WWD
# WWE
# WYNN
# X
# XEL
# XOM
# XPO
# XRAY
# XYL
# YETI
# YUM
# Z
# ZBRA

# %%
tickers_with_dups.keys()
# Out:
# dict_keys(['AEE', 'ALLY', 'AMC', 'ARES', 'ATO', 'ATVI', 'BALL', 'BKNG', 'CE', 'CLH', 'CLX', 'CVNA', 'CVX', 'DECK', 'DISH', 'DLTR', 'DTE', 'DVA', 'ED', 'EIX', 'EPAM', 'EQT', 'EVA', 'EXEL', 'FCNCA', 'FITB', 'FOUR', 'FTNT', 'GPS', 'HAYW', 'HBI', 'HSY', 'HWM', 'IART', 'IEX', 'IQV', 'ITT', 'KHC', 'L', 'LII', 'LKQ', 'LSCC', 'LUV', 'MASI', 'MCHP', 'MRCY', 'MRTX', 'MS', 'MSA', 'NI', 'NOC', 'NVT', 'OWL', 'PARA', 'PCG', 'PENN', 'PKI', 'PNR', 'PSX', 'QS', 'RARE', 'RMD', 'SEB', 'SGEN', 'SMG', 'SPB', 'SSNC', 'STZ', 'TFX', 'TNDM', 'TRU', 'VRTX', 'VST', 'WRK', 'X', 'Z'])

# %%
len(tickers_with_dups)
# Out:
# 76

# %%
# Remove companies with duplicates

for ticker in tickers_with_dups.keys():
   print(ticker)
   clean_master_data.pop(ticker)
# Out:
# AEE
# ALLY
# AMC
# ARES
# ATO
# ATVI
# BALL
# BKNG
# CE
# CLH
# CLX
# CVNA
# CVX
# DECK
# DISH
# DLTR
# DTE
# DVA
# ED
# EIX
# EPAM
# EQT
# EVA
# EXEL
# FCNCA
# FITB
# FOUR
# FTNT
# GPS
# HAYW
# HBI
# HSY
# HWM
# IART
# IEX
# IQV
# ITT
# KHC
# L
# LII
# LKQ
# LSCC
# LUV
# MASI
# MCHP
# MRCY
# MRTX
# MS
# MSA
# NI
# NOC
# NVT
# OWL
# PARA
# PCG
# PENN
# PKI
# PNR
# PSX
# QS
# RARE
# RMD
# SEB
# SGEN
# SMG
# SPB
# SSNC
# STZ
# TFX
# TNDM
# TRU
# VRTX
# VST
# WRK
# X
# Z

# %%
# Repeat the extraction. This time we shouldn't have any duplicates.

income_summary = extract_summary('income')
# Out:
# AA
# AAL
# AAP
# AAPL
# ABBV
# ABNB
# ABT
# ACGL
# ACHC
# ACI
# ACM
# ACN
# ADBE
# ADI
# ADM
# ADP
# ADSK
# ADT
# AEP
# AES
# AFG
# AFL
# AFRM
# AGCO
# AGL
# AGNC
# AGO
# AGR
# AIG
# AIZ
# AJG
# AKAM
# AL
# ALB
# ALGM
# ALGN
# ALK
# ALL
# ALLE
# ALNY
# ALSN
# AM
# AMAT
# AMCR
# AMD
# AME
# AMED
# AMG
# AMGN
# AMP
# AMZN
# AN
# ANET
# ANSS
# AON
# AOS
# APA
# APD
# APH
# APO
# APP
# APTV
# AR
# ARMK
# ARW
# ASH
# ATR
# ATUS
# AVGO
# AVT
# AVTR
# AWI
# AWK
# AXON
# AXS
# AXTA
# AYI
# AYX
# AZEK
# AZO
# AZTA
# BA
# BAC
# BAH
# BAX
# BBWI
# BBY
# BC
# BDX
# BEN
# BERY
# BFAM
# BG
# BHF
# BIIB
# BILL
# BIO
# BJ
# BK
# BLD
# BLDR
# BLK
# BMRN
# BMY
# BOKF
# BR
# BRKR
# BRO
# BSX
# BSY
# BURL
# BWA
# BWXT
# BX
# BYD
# C
# CABO
# CACC
# CAH
# CAR
# CARR
# CAT
# CB
# CBOE
# CBSH
# CC
# CCCS
# CCK
# CCL
# CDAY
# CDNS
# CDW
# CEG
# CERT
# CF
# CFG
# CFLT
# CFR
# CG
# CGNX
# CHD
# CHDN
# CHE
# CHH
# CHPT
# CHRW
# CHTR
# CIEN
# CINF
# CL
# CLVT
# CMA
# CMCSA
# CME
# CMG
# CMI
# CMS
# CNA
# CNM
# CNP
# CNXC
# COF
# COIN
# COLB
# COLM
# COO
# COST
# COTY
# CPB
# CPRI
# CPRT
# CR
# CRI
# CRL
# CRUS
# CRWD
# CSCO
# CSL
# CTLT
# CTRA
# CTSH
# CTVA
# CW
# CZR
# D
# DAL
# DAR
# DASH
# DBX
# DCI
# DD
# DDOG
# DFS
# DG
# DGX
# DHI
# DHR
# DINO
# DIS
# DKNG
# DKS
# DLB
# DNA
# DOCS
# DOCU
# DOV
# DOW
# DPZ
# DRVN
# DT
# DTM
# DUK
# DV
# DVN
# DXC
# DXCM
# EA
# EBAY
# ECL
# EEFT
# EFX
# EHAB
# EHC
# EL
# ELAN
# EMN
# EMR
# ENOV
# ENPH
# ENTG
# EOG
# EQH
# ERIE
# ES
# ESAB
# ESI
# ESTC
# ETN
# ETR
# ETSY
# EVR
# EVRG
# EW
# EWBC
# EXAS
# EXC
# EXP
# EXPD
# EXPE
# F
# FAF
# FANG
# FAST
# FCN
# FCX
# FDS
# FE
# FFIV
# FG
# FHB
# FHN
# FICO
# FIS
# FISV
# FIVE
# FIVN
# FLO
# FLS
# FLT
# FMC
# FNB
# FND
# FNF
# FOX
# FRPT
# FSLR
# FTV
# G
# GD
# GDDY
# GE
# GGG
# GILD
# GL
# GLW
# GM
# GME
# GMED
# GNRC
# GNTX
# GO
# GOOG
# GOOGL
# GPC
# GPK
# GPN
# GRMN
# GS
# GTES
# GWRE
# GWW
# GXO
# H
# HAL
# HAS
# HBAN
# HCA
# HD
# HE
# HEI
# HES
# HIG
# HII
# HLT
# HOG
# HOLX
# HON
# HPE
# HPP
# HPQ
# HRL
# HSIC
# HTZ
# HUBB
# HUBS
# HUN
# HXL
# HZNP
# IAC
# IBKR
# IBM
# ICE
# ICUI
# IDA
# IDXX
# IFF
# ILMN
# INCY
# INFA
# INGR
# INTC
# INTU
# IONS
# IP
# IPG
# IPGP
# IR
# ISRG
# IT
# ITW
# IVZ
# J
# JAMF
# JAZZ
# JBHT
# JBL
# JBLU
# JCI
# JEF
# JHG
# JKHY
# JNJ
# JNPR
# JPM
# JWN
# K
# KBR
# KDP
# KEX
# KEY
# KEYS
# KKR
# KLAC
# KMB
# KMI
# KMPR
# KMX
# KNX
# KO
# KR
# KSS
# LAD
# LAZ
# LBRDA
# LCID
# LDOS
# LEA
# LECO
# LEG
# LEN
# LESL
# LFUS
# LH
# LHX
# LITE
# LLY
# LMT
# LNC
# LNG
# LNT
# LOPE
# LOW
# LPLA
# LPX
# LRCX
# LSTR
# LULU
# LUMN
# LVS
# LYB
# LYFT
# LYV
# M
# MA
# MAN
# MANH
# MAR
# MAS
# MAT
# MCD
# MCK
# MCO
# MCW
# MDB
# MDLZ
# MDT
# MDU
# MET
# META
# MGM
# MHK
# MIDD
# MKC
# MKL
# MKSI
# MKTX
# MLM
# MMC
# MMM
# MNST
# MO
# MORN
# MOS
# MP
# MPC
# MPWR
# MRK
# MRNA
# MRO
# MRVI
# MRVL
# MSCI
# MSFT
# MSGS
# MSI
# MSM
# MTB
# MTCH
# MTD
# MTG
# MTN
# MTZ
# MU
# NATI
# NBIX
# NCLH
# NCNO
# NCR
# NDAQ
# NDSN
# NEE
# NEM
# NET
# NEU
# NEWR
# NFE
# NFG
# NFLX
# NLY
# NOV
# NOW
# NRG
# NSC
# NTAP
# NTNX
# NTRA
# NTRS
# NUE
# NVAX
# NVCR
# NVDA
# NVR
# NVST
# NWL
# NWS
# NXST
# NYCB
# NYT
# OC
# ODFL
# OGE
# OGN
# OKE
# OKTA
# OLED
# OLLI
# OLN
# OLPX
# OMC
# OMF
# ON
# ORI
# ORLY
# OSH
# OTIS
# OVV
# OXY
# PACW
# PAG
# PANW
# PATH
# PAYC
# PB
# PCAR
# PCOR
# PCTY
# PDCE
# PEG
# PEGA
# PEN
# PEP
# PFE
# PFG
# PFGC
# PG
# PGR
# PH
# PHM
# PII
# PINC
# PINS
# PKG
# PLNT
# PLTK
# PLTR
# PLUG
# PM
# PNC
# PNFP
# PNW
# PODD
# POOL
# POST
# PPC
# PPG
# PPL
# PRGO
# PRI
# PRU
# PSTG
# PTC
# PTON
# PVH
# PWR
# PXD
# PYPL
# QCOM
# QDEL
# QRVO
# RE
# REGN
# REYN
# RF
# RGA
# RGEN
# RH
# RJF
# RL
# RNG
# RNR
# RRC
# RRX
# RS
# RSG
# RTX
# RUN
# S
# SAM
# SBUX
# SCCO
# SCHW
# SCI
# SEE
# SEIC
# SF
# SHC
# SHW
# SIRI
# SITE
# SIX
# SJM
# SKX
# SLB
# SLGN
# SMAR
# SNA
# SNDR
# SNOW
# SNPS
# SNV
# SNX
# SO
# SOFI
# SON
# SPLK
# SPR
# SQ
# SRCL
# SRE
# SSRM
# ST
# STE
# STLD
# STT
# STWD
# SWK
# SWKS
# SWN
# SYF
# SYK
# SYNH
# SYY
# T
# TAP
# TDC
# TDG
# TDOC
# TDY
# TECH
# TER
# TFC
# TFSL
# TGT
# THC
# THG
# THO
# TJX
# TKR
# TMO
# TMUS
# TNL
# TOL
# TOST
# TPL
# TPR
# TPX
# TREX
# TRGP
# TRIP
# TRMB
# TROW
# TRV
# TSCO
# TSLA
# TSN
# TT
# TTC
# TTD
# TTEK
# TTWO
# TW
# TWKS
# TWLO
# TXG
# TXN
# TXT
# TYL
# U
# UAL
# UBER
# UGI
# UHS
# UI
# ULTA
# UNM
# UNP
# UNVR
# UPS
# UPST
# URI
# USB
# USFD
# UTHR
# UWMC
# V
# VAC
# VEEV
# VFC
# VIRT
# VLO
# VMC
# VMI
# VMW
# VNT
# VOYA
# VRSK
# VRSN
# VRT
# VSAT
# VSCO
# VTRS
# VVV
# VZ
# W
# WAB
# WAL
# WAT
# WBA
# WBD
# WBS
# WCC
# WDAY
# WDC
# WEC
# WEN
# WEX
# WFC
# WH
# WHR
# WLK
# WM
# WMB
# WMS
# WMT
# WOLF
# WOOF
# WRB
# WSC
# WSM
# WSO
# WST
# WTFC
# WTM
# WTRG
# WTW
# WU
# WWD
# WWE
# WYNN
# XEL
# XOM
# XPO
# XRAY
# XYL
# YETI
# YUM
# ZBRA

# %%
random.randint(0,)

# %%
key_list = list(income_summary.keys())
len(key_list)
# Out:
# 757

# %%
key_list = list(income_summary.keys())
i = random.randint(0,len(key_list))
ticker=key_list[i]
print(ticker)
income_summary[ticker]['22']
# Out:
# CABO
#                           Dec. 31, 2021  Dec. 31, 2020  Dec. 31, 2019 type  \
# Revenues                        1605836        1325229        1167997    R
# Costs And Expenses:                 NaN            NaN            NaN   OE
# SGA                              347058         255163         245120  SGA
# Total Costs And Expenses        1149264         855879         857546  TOE
# Net Income                       291824         304391         178582   NI
#
#                          line_type
# Revenues                         L
# Costs And Expenses:              H
# SGA                              L
# Total Costs And Expenses         L
# Net Income                       L

# %%
print(ticker)
clean_master_data[ticker]['22']['income']['table']
# Out:
# CABO
#                                                                           Dec. 31, 2021  \
# line_item
# Revenues                                                                        1605836
# Costs And Expenses:                                                                 NaN
# Operating Excluding Depreciation And Amortization                                455352
# SGA                                                                              347058
# Depreciation And Amortization                                                    339025
# -Gain Loss On Asset Sales And Disposals, Net                                       7829
# Gain On Sale Of Business                                                              0
# Total Costs And Expenses                                                        1149264
# Income From Operations                                                           456572
# Interest Expense                                                                -113449
# Other Income Expense, Net                                                         -6002
# Income Before Income Taxes And Equity Method Investment Income Loss, Net         337121
# Income Tax Provision                                                              45765
# Income Before Equity Method Investment Income Loss, Net                          291356
# Equity Method Investment Income Loss, Net                                           468
# Net Income                                                                       291824
# Net Income Per Common Share:                                                        NaN
# Basic In Dollars Per Share                                                           48
# Diluted In Dollars Per Share                                                         46
# Weighted Average Common Shares Outstanding:                                         NaN
# Basic In Shares                                                                 6017778
# Diluted In Shares                                                               6387354
# Unrealized Gain Loss On Cash Flow Hedges And Other, Net Of Tax                    57888
# Comprehensive Income                                                             349712
#
#                                                                           Dec. 31, 2020  \
# line_item
# Revenues                                                                        1325229
# Costs And Expenses:                                                                 NaN
# Operating Excluding Depreciation And Amortization                                418704
# SGA                                                                              255163
# Depreciation And Amortization                                                    265658
# -Gain Loss On Asset Sales And Disposals, Net                                      -1072
# Gain On Sale Of Business                                                         -82574
# Total Costs And Expenses                                                         855879
# Income From Operations                                                           469350
# Interest Expense                                                                 -73607
# Other Income Expense, Net                                                        -16411
# Income Before Income Taxes And Equity Method Investment Income Loss, Net         379332
# Income Tax Provision                                                              76317
# Income Before Equity Method Investment Income Loss, Net                          303015
# Equity Method Investment Income Loss, Net                                          1376
# Net Income                                                                       304391
# Net Income Per Common Share:                                                        NaN
# Basic In Dollars Per Share                                                           52
# Diluted In Dollars Per Share                                                         51
# Weighted Average Common Shares Outstanding:                                         NaN
# Basic In Shares                                                                 5884780
# Diluted In Shares                                                               5937582
# Unrealized Gain Loss On Cash Flow Hedges And Other, Net Of Tax                   -72525
# Comprehensive Income                                                             231866
#
#                                                                           Dec. 31, 2019
# line_item
# Revenues                                                                        1167997
# Costs And Expenses:                                                                 NaN
# Operating Excluding Depreciation And Amortization                                388552
# SGA                                                                              245120
# Depreciation And Amortization                                                    216687
# -Gain Loss On Asset Sales And Disposals, Net                                       7187
# Gain On Sale Of Business                                                              0
# Total Costs And Expenses                                                         857546
# Income From Operations                                                           310451
# Interest Expense                                                                 -71729
# Other Income Expense, Net                                                         -4907
# Income Before Income Taxes And Equity Method Investment Income Loss, Net         233815
# Income Tax Provision                                                              55233
# Income Before Equity Method Investment Income Loss, Net                          178582
# Equity Method Investment Income Loss, Net                                             0
# Net Income                                                                       178582
# Net Income Per Common Share:                                                        NaN
# Basic In Dollars Per Share                                                           31
# Diluted In Dollars Per Share                                                         31
# Weighted Average Common Shares Outstanding:                                         NaN
# Basic In Shares                                                                 5678990
# Diluted In Shares                                                               5737856
# Unrealized Gain Loss On Cash Flow Hedges And Other, Net Of Tax                   -68062
# Comprehensive Income                                                             110520

# %%
tickers_with_dups['LUV']
# Out:
# {'yr': '19',
#  'df_orig':                           Dec. 31, 2018  Dec. 31, 2017  Dec. 31, 2016 type  \
#  Operating Revenues:                 NaN            NaN            NaN    R
#  Operating Revenue                 21965          21146          20289    R
#  Operating Expenses:                 NaN            NaN            NaN   OE
#  Total Operating Expenses          18759          17739          16767  TOE
#  Operating Income                   3206           3407           3522   OI
#  Net Income                         2465           3357           2183   NI
#  Operating Revenues:                 NaN            NaN            NaN    R
#  Operating Revenue                 20455          19763          19068    R
#  Operating Revenues:                 NaN            NaN            NaN    R
#  Operating Revenue                   175            173            171    R
#  Operating Revenues:                 NaN            NaN            NaN    R
#  Operating Revenue                  1335           1210           1050    R
#
#                           line_type
#  Operating Revenues:              H
#  Operating Revenue                L
#  Operating Expenses:              H
#  Total Operating Expenses         L
#  Operating Income                 L
#  Net Income                       L
#  Operating Revenues:              H
#  Operating Revenue                L
#  Operating Revenues:              H
#  Operating Revenue                L
#  Operating Revenues:              H
#  Operating Revenue                L  ,
#  'df_dup':               line_item  Dec. 31, 2018  Dec. 31, 2017  Dec. 31, 2016 type  \
#  6   Operating Revenues:            NaN            NaN            NaN    R
#  7     Operating Revenue          20455          19763          19068    R
#  8   Operating Revenues:            NaN            NaN            NaN    R
#  9     Operating Revenue            175            173            171    R
#  10  Operating Revenues:            NaN            NaN            NaN    R
#  11    Operating Revenue           1335           1210           1050    R
#
#     line_type
#  6          H
#  7          L
#  8          H
#  9          L
#  10         H
#  11         L  }

# %%
income_summary['LUV']['19']
# Out:
#                           Dec. 31, 2018  Dec. 31, 2017  Dec. 31, 2016 type  \
# Operating Revenues:                 NaN            NaN            NaN    R
# Operating Revenue                 21965          21146          20289    R
# Operating Expenses:                 NaN            NaN            NaN   OE
# Total Operating Expenses          18759          17739          16767  TOE
# Operating Income                   3206           3407           3522   OI
# Net Income                         2465           3357           2183   NI
# Operating Revenues:                 NaN            NaN            NaN    R
# Operating Revenue                 20455          19763          19068    R
# Operating Revenues:                 NaN            NaN            NaN    R
# Operating Revenue                   175            173            171    R
# Operating Revenues:                 NaN            NaN            NaN    R
# Operating Revenue                  1335           1210           1050    R
#
#                          line_type
# Operating Revenues:              H
# Operating Revenue                L
# Operating Expenses:              H
# Total Operating Expenses         L
# Operating Income                 L
# Net Income                       L
# Operating Revenues:              H
# Operating Revenue                L
# Operating Revenues:              H
# Operating Revenue                L
# Operating Revenues:              H
# Operating Revenue                L

# %%
clean_master_data['LUV']['19']['income']['table']
# Out:
#                                     Dec. 31, 2018  Dec. 31, 2017  \
# line_item
# Operating Revenues:                           NaN            NaN
# Operating Revenue                           21965          21146
# Operating Expenses:                           NaN            NaN
# Salaries, Wages, And Benefits                7649           7305
# Fuel And Oil                                 4616           4076
# Maintenance Materials And Repairs            1107           1001
# Landing Fees And Airport Rentals             1334           1292
# Depreciation And Amortization                1201           1218
# Other Operating Expenses                     2852           2847
# Total Operating Expenses                    18759          17739
# Operating Income                             3206           3407
# Other Expenses                                NaN            NaN
# Interest Expense                              131            114
# Capitalized Interest                          -38            -49
# Interest Income                               -69            -35
# Other Gains Losses, Net                       -18           -112
# Total Other Expenses Income                    42            142
# Income Before Income Taxes                   3164           3265
# Provision Benefit For Income Taxes            699            -92
# Net Income                                   2465           3357
# Passenger                                     NaN            NaN
# Operating Revenues:                           NaN            NaN
# Operating Revenue                           20455          19763
# Freight                                       NaN            NaN
# Operating Revenues:                           NaN            NaN
# Operating Revenue                             175            173
# Other                                         NaN            NaN
# Operating Revenues:                           NaN            NaN
# Operating Revenue                            1335           1210
#
#                                     Dec. 31, 2016
# line_item
# Operating Revenues:                           NaN
# Operating Revenue                           20289
# Operating Expenses:                           NaN
# Salaries, Wages, And Benefits                6786
# Fuel And Oil                                 3801
# Maintenance Materials And Repairs            1045
# Landing Fees And Airport Rentals             1211
# Depreciation And Amortization                1221
# Other Operating Expenses                     2703
# Total Operating Expenses                    16767
# Operating Income                             3522
# Other Expenses                                NaN
# Interest Expense                              122
# Capitalized Interest                          -47
# Interest Income                               -24
# Other Gains Losses, Net                       -21
# Total Other Expenses Income                    72
# Income Before Income Taxes                   3450
# Provision Benefit For Income Taxes           1267
# Net Income                                   2183
# Passenger                                     NaN
# Operating Revenues:                           NaN
# Operating Revenue                           19068
# Freight                                       NaN
# Operating Revenues:                           NaN
# Operating Revenue                             171
# Other                                         NaN
# Operating Revenues:                           NaN
# Operating Revenue                            1050

# %%
master_data['ADM']['20']['income']
# Out:
#    Consolidated Statements Of Earnings - USD ($)  shares in Millions, $ in Millions  \
#    Consolidated Statements Of Earnings - USD ($)  shares in Millions, $ in Millions
# 0                                                       Income Statement [Abstract]
# 1                                                                          Revenues
# 2                                                             Cost of products sold
# 3                                                                      Gross Profit
# 4                                      Selling, general and administrative expenses
# 5                                   Asset impairment, exit, and restructuring costs
# 6                                                                  Interest expense
# 7                                   Equity in earnings of unconsolidated affiliates
# 8                                                                   Interest income
# 9                                                      Other (income) expense - net
# 10                                                     Earnings Before Income Taxes
# 11                                                               Income tax expense
# 12                                  Net Earnings Including Noncontrolling Interests
# 13             Less: Net earnings (losses) attributable to noncontrolling interests
# 14                               Net Earnings Attributable to Controlling Interests
# 15                                     Average number of shares outstanding - basic
# 16                                   Average number of shares outstanding - diluted
# 17                              Basic earnings per common share (dollars per share)
# 18                            Diluted earnings per common share (dollars per share)
#
#    12 Months Ended
#      Dec. 31, 2019 Dec. 31, 2018 Dec. 31, 2017
# 0              NaN           NaN           NaN
# 1         $ 64,656      $ 64,341      $ 60,828
# 2            60509         60160         57310
# 3             4147          4181          3518
# 4             2493          2165          1978
# 5              303           171           173
# 6              402           364           330
# 7            (454)         (518)         (456)
# 8            (192)         (162)         (106)
# 9                7           101          (10)
# 10            1588          2060          1609
# 11             209           245             7
# 12            1379          1815          1602
# 13               0             5             7
# 14         $ 1,379       $ 1,810       $ 1,595
# 15             563           564           569
# 16             565           567           572
# 17          $ 2.45        $ 3.21        $ 2.80
# 18          $ 2.44        $ 3.19        $ 2.79

# %%
ticker='TGT'
yr='20'
df_dup = find_duplicates(income_summary[ticker][yr])
df_dup

# %%
idx=65
print(dups_list[idx]['company'])
print(dups_list[idx]['yr'])
dups_list[idx]['df_dup']

# %%
dups_list[idx]['df_orig']

# %%
len(dups_list)

# %%
#df_temp = income_summary[income_summary['AAL']['21'].duplicated()]

df_temp = income_summary['MSFT']['21']
df_temp = df_temp.reset_index(names=['line_item'])
X = df_temp[df_temp.duplicated(subset=['line_item','line_type'])]
X

# %%
master_statements = extract_statements('income',income_summary)

# %%
master_statements['GOOG']

# %%
df_headings = df[df['line_type'] == 'H']
df_headings[['line_item','line_type']].value_counts()

# %%
swap_text_dict['income']['H'] = { 'Net Sales:' : 'Revenue:',
                                  'Revenues': 'Revenue:',
                                  'Revenues:': 'Revenue:',
                                  'Revenue': 'Revenue:',
                                  'Net Revenue:': 'Revenue:',
                                  'Operating Revenue:': 'Revenue:',
                                  'Sales And Revenues:': 'Revenue:',
                                  'Sales And Other Operating Revenues:': 'Revenue:',
                                  'Net Sales And Revenue': 'Revenue:',
                                  'Costs And Operating Expenses': 'Operating Expenses:',
                                  'Cost And Expenses:': 'Operating Expenses:',
                                  'Cost And Expenses': 'Operating Expenses:',
                                  'Cost Of Sales And Operating Expenses:': 'Operating Expenses:',
                                  'Cost Of Sales And Service Revenues': 'Cost of Sales'                 
                                }

# %%
df['line_item'] = df['line_item'].apply(lambda x: swap_text('H',x,'income'))

# %%
swap_text('H','Net Sales:', 'income')

# %%
df_line_items = df[df['line_type'] == 'L']
df_line_items[['line_item','type']].value_counts()

# %%
swap_text_dict['income']['L'] = 
         {'Selling, General And Administrative Expense' : 'Selling, General And Admin',
          'Selling, General, And Administrative Expenses': 'Selling, General And Admin',
          'Selling, General & Administrative Expenses': 'Selling, General And Admin',
          'Selling, General, And Administrative Expense': 'Selling, General And Admin',
          'Selling, General, And Administrative': 'Selling, General And Admin',
          'Selling, General and Administrative': 'Selling, General And Admin',
          'Operating, Selling, General And Administrative Expenses': 'Selling, General And Admin',
          'General And Administrative Expenses': 'General And Admin',
          'Marketing, General And Administrative': 'Marketing, General And Admin',
          'Marketing, General And Administrative Expenses': 'Marketing, General And Admin',
          'General, Administrative And Other': 'General And Admin',
          'Selling And Administrative': 'Selling, General And Admin',
          'General, Administrative And Other Expenses': 'General And Admin',
          'Total General And Administrative Expenses': 'Total General And Admin',
          'Corporate General And Administrative': 'General And Admin',
          'Selling, General Administrative, And Other Expenses': 'Selling, General And Admin',
          'General And Administrative Expenses -Exclusive Of Depreciation And Amortization': 'General And Admin',
          'Operating, General And Administrative': 'General And Admin'                             
          }

# %%
df['line_item'] = df['line_item'].apply(lambda x: swap_text('L',x,'income'))

# %%
df_headings

# %%
df_headings = df[df['line_type'] == 'H']
df_headings[['line_item','line_type']].value_counts()

# %%
df_line_items = df[df['line_type'] == 'L']
df_line_items[['line_item','line_type']].value_counts()

# %%
df = master_std_statements['income']['CSCO']
df.reset_index(names=['line_item'])

# %% [markdown]
# ## Balance Statement

# %%
balance_summary = extract_summary('balance')

# %%
balance_summary['T']['17']

# %%
cols = list(df.columns)

new_cols = []

for c in cols:
    if (c != 'type') & (c != 'line_type'):
        new_cols = new_cols + [c.split("-")[0]]
        
new_cols

# %%
master_statements = extract_statements('balance',balance_summary)

# %%
master_statements['CSCO']

# %% [markdown]
# ## Cash Statement

# %%
cash_summary = extract_summary('cash')

# %%
master_statements = extract_statements('cash',cash_summary)

# %%
master_statements['F']

# %%
df_headings = df[df['line_type'] == 'H']
df_headings[['line_item','type']].value_counts()

# %%
cash_summary['NVDA']['22']

# %%
len(master_statements)

# %%
# Save to file

with open(PROJ_ROOT_PATH + '/pickle/clean_master_data_stage5.pkl', 'wb') as f:
  pickle.dump(clean_master_data, f)

# %%
# Save to file

with open(PROJ_ROOT_PATH + '/pickle/income_summary_stage5.pkl', 'wb') as f:
  pickle.dump(income_summary, f)
