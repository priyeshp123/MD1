# %%
import pandas as pd
import numpy as np
import pandas as pd
import openpyexcel
from openpyexcel import workbook, load_workbook
from openpyxl.worksheet.table import Table, TableStyleInfo
from openpyexcel.utils import get_column_letter
from itertools import islice
from os import listdir
import re
import csv
import datetime
import pickle

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 100)
pd.options.display.float_format = '{:.0f}'.format

# %%
company = pd.read_csv('CSV/company_ws.csv',index_col=0)
company
# Out:
#                                        Balance  \
# ADBE1.xlsx         Consolidated Balance Sheets
# ADBE2.xlsx         Consolidated Balance Sheets
# ADBE3.xlsx         Consolidated Balance Sheets
# ADBE4.xlsx         Consolidated Balance Sheets
# ADBE5.xlsx         Consolidated_Balance_Sheets
# AME1.xlsx           Consolidated Balance Sheet
# AME2.xlsx           Consolidated Balance Sheet
# AME3.xlsx           Consolidated Balance Sheet
# AME4.xlsx           Consolidated Balance Sheet
# AME5.xlsx           Consolidated_Balance_Sheet
# AMGN1.xlsx         Consolidated Balance Sheets
# AMGN2.xlsx         Consolidated Balance Sheets
# AMGN3.xlsx         Consolidated Balance Sheets
# AMGN4.xlsx         Consolidated Balance Sheets
# AMGN5.xlsx         Consolidated_Balance_Sheets
# ANET1.xlsx         Consolidated Balance Sheets
# ANET2.xlsx         Consolidated Balance Sheets
# ANET3.xlsx         Consolidated Balance Sheets
# ANET4.xlsx         Consolidated Balance Sheets
# ANET5.xlsx         Consolidated_Balance_Sheets
# BBY1.xlsx          Consolidated Balance Sheets
# BBY2.xlsx          Consolidated Balance Sheets
# BBY3.xlsx          CONSOLIDATED BALANCE SHEETS
# BBY4.xlsx          CONSOLIDATED BALANCE SHEETS
# BBY5.xlsx          CONSOLIDATED_BALANCE_SHEETS
# BG1.xlsx           CONSOLIDATED BALANCE SHEETS
# BG2.xlsx           CONSOLIDATED BALANCE SHEETS
# BG3.xlsx           CONSOLIDATED BALANCE SHEETS
# BG4.xlsx           CONSOLIDATED BALANCE SHEETS
# BG5.xlsx           CONSOLIDATED_BALANCE_SHEETS
# BIIB1.xlsx         Consolidated Balance Sheets
# BIIB2.xlsx         Consolidated Balance Sheets
# BIIB3.xlsx         Consolidated Balance Sheets
# BIIB4.xlsx         Consolidated Balance Sheets
# BIIB5.xlsx         Consolidated_Balance_Sheets
# BWA1.xlsx          CONSOLIDATED BALANCE SHEETS
# BWA2.xlsx          CONSOLIDATED BALANCE SHEETS
# CAT1.xlsx      Consolidated Financial Position
# CAT2.xlsx      Consolidated Financial Position
# CAT3.xlsx      Consolidated Financial Position
# CAT4.xlsx      Consolidated Financial Position
# CAT5.xlsx       Consolidated_Financial_Positio
# CHTR1.xlsx         CONSOLIDATED BALANCE SHEETS
# CHTR2.xlsx         CONSOLIDATED BALANCE SHEETS
# CHTR3.xlsx         CONSOLIDATED BALANCE SHEETS
# CHTR4.xlsx         CONSOLIDATED BALANCE SHEETS
# CHTR5.xlsx         CONSOLIDATED_BALANCE_SHEETS
# CMCSA1.xlsx         Consolidated Balance Sheet
# CMCSA2.xlsx         Consolidated Balance Sheet
# CMCSA3.xlsx         Consolidated Balance Sheet
# CMCSA4.xlsx         Consolidated Balance Sheet
# CMCSA5.xlsx         Consolidated_Balance_Sheet
# COST1.xlsx         Consolidated Balance Sheets
# COST2.xlsx         Consolidated Balance Sheets
# COST3.xlsx         Consolidated Balance Sheets
# COST4.xlsx         Consolidated Balance Sheets
# COST5.xlsx         Consolidated_Balance_Sheets
# CPB1.xlsx          Consolidated Balance Sheets
# CPB2.xlsx          Consolidated Balance Sheets
# CPB3.xlsx          Consolidated Balance Sheets
# CRM1.xlsx          Consolidated Balance Sheets
# CRM2.xlsx          Consolidated Balance Sheets
# CRM4.xlsx          Consolidated Balance Sheets
# CRM5.xlsx          Consolidated_Balance_Sheets
# CSCO1.xlsx         Consolidated Balance Sheets
# CSCO2.xlsx         Consolidated Balance Sheets
# CSCO3.xlsx         Consolidated Balance Sheets
# CSCO4.xlsx         Consolidated Balance Sheets
# CSCO5.xlsx         Consolidated_Balance_Sheets
# D1.xlsx            Consolidated Balance Sheets
# D2.xlsx            Consolidated Balance Sheets
# D3.xlsx            Consolidated Balance Sheets
# D4.xlsx            Consolidated Balance Sheets
# D5.xlsx            Consolidated_Balance_Sheets
# DG1.xlsx           CONSOLIDATED BALANCE SHEETS
# DG2.xlsx           CONSOLIDATED BALANCE SHEETS
# DG3.xlsx           CONSOLIDATED BALANCE SHEETS
# DG4.xlsx           CONSOLIDATED BALANCE SHEETS
# DG5.xlsx           CONSOLIDATED_BALANCE_SHEETS
# DLTR1.xlsx         CONSOLIDATED BALANCE SHEETS
# DLTR2.xlsx         CONSOLIDATED BALANCE SHEETS
# DLTR3.xlsx         CONSOLIDATED BALANCE SHEETS
# DLTR4.xlsx         CONSOLIDATED BALANCE SHEETS
# DLTR5.xlsx         CONSOLIDATED_BALANCE_SHEETS
# EIX1.xlsx          Consolidated Balance Sheets
# EIX2.xlsx          Consolidated Balance Sheets
# EIX3.xlsx          Consolidated Balance Sheets
# EIX4.xlsx          Consolidated Balance Sheets
# EIX5.xlsx          Consolidated_Balance_Sheets
# EMR1.xlsx          Consolidated Balance Sheets
# EMR2.xlsx          Consolidated Balance Sheets
# EMR3.xlsx          Consolidated Balance Sheets
# EMR4.xlsx          Consolidated Balance Sheets
# EMR5.xlsx          Consolidated_Balance_Sheets
# FDX1.xlsx          Consolidated Balance Sheets
# FDX2.xlsx          Consolidated Balance Sheets
# FDX3.xlsx          Consolidated Balance Sheets
# FDX4.xlsx          Consolidated Balance Sheets
# FDX5.xlsx          Consolidated_Balance_Sheets
# FE1.xlsx           Consolidated Balance Sheets
# FE2.xlsx           Consolidated Balance Sheets
# FE3.xlsx           Consolidated Balance Sheets
# FE4.xlsx       Consolidated Balance Sheets (Fi
# FE5.xlsx                                   NaN
# FE6.xlsx                                   NaN
# FFIV1.xlsx         Consolidated Balance Sheets
# FFIV2.xlsx         Consolidated Balance Sheets
# FFIV3.xlsx         Consolidated Balance Sheets
# FFIV4.xlsx         Consolidated Balance Sheets
# FFIV5.xlsx         Consolidated_Balance_Sheets
# GILD1.xlsx         CONSOLIDATED BALANCE SHEETS
# GILD2.xlsx         Consolidated Balance Sheets
# GILD3.xlsx         Consolidated Balance Sheets
# GILD4.xlsx         Consolidated Balance Sheets
# GILD5.xlsx         Consolidated_Balance_Sheets
# GM1.xlsx           Consolidated Balance Sheets
# GM2.xlsx           Consolidated Balance Sheets
# GM3.xlsx           Consolidated Balance Sheets
# GM4.xlsx           Consolidated Balance Sheets
# GM5.xlsx           Consolidated_Balance_Sheets
# INCY1.xlsx         CONSOLIDATED BALANCE SHEETS
# INCY2.xlsx         CONSOLIDATED BALANCE SHEETS
# INCY3.xlsx         CONSOLIDATED BALANCE SHEETS
# INCY4.xlsx         CONSOLIDATED BALANCE SHEETS
# INCY5.xlsx         CONSOLIDATED_BALANCE_SHEETS
# JNPR1.xlsx         Consolidated Balance Sheets
# JNPR2.xlsx         Consolidated Balance Sheets
# JNPR3.xlsx         Consolidated Balance Sheets
# JNPR4.xlsx         Consolidated Balance Sheets
# JNPR5.xlsx         Consolidated_Balance_Sheets
# KO3.xlsx           CONSOLIDATED BALANCE SHEETS
# KO4.xlsx           CONSOLIDATED BALANCE SHEETS
# KO5.xlsx           CONSOLIDATED BALANCE SHEETS
# KR1.xlsx           CONSOLIDATED BALANCE SHEETS
# KR2.xlsx           CONSOLIDATED BALANCE SHEETS
# KR3.xlsx           CONSOLIDATED BALANCE SHEETS
# KR4.xlsx           CONSOLIDATED_BALANCE_SHEETS
# LNT1.xlsx          Consolidated Balance Sheets
# LNT2.xlsx          Consolidated Balance Sheets
# LNT3.xlsx          Consolidated Balance Sheets
# LNT4.xlsx          Consolidated Balance Sheets
# LNT5.xlsx          Consolidated_Balance_Sheets
# LVS1.xlsx          CONSOLIDATED BALANCE SHEETS
# LVS2.xlsx          CONSOLIDATED BALANCE SHEETS
# LVS3.xlsx          CONSOLIDATED BALANCE SHEETS
# LVS4.xlsx          CONSOLIDATED BALANCE SHEETS
# LVS5.xlsx          CONSOLIDATED_BALANCE_SHEETS
# MDLZ1.xlsx     Consolidated Balance Sheets, as
# MDLZ2.xlsx     Consolidated Balance Sheets, as
# MDLZ3.xlsx         Consolidated_Balance_Sheets
# MGM1.xlsx          CONSOLIDATED BALANCE SHEETS
# MGM2.xlsx          Consolidated Balance Sheets
# MGM3.xlsx          Consolidated Balance Sheets
# MGM4.xlsx          Consolidated Balance Sheets
# MGM5.xlsx          Consolidated_Balance_Sheets
# MLM1.xlsx          Consolidated Balance Sheets
# MLM2.xlsx          Consolidated Balance Sheets
# MLM3.xlsx          Consolidated Balance Sheets
# MLM4.xlsx          Consolidated Balance Sheets
# MLM5.xlsx          Consolidated_Balance_Sheets
# MSI1.xlsx          Consolidated Balance Sheets
# MSI2.xlsx          Consolidated Balance Sheets
# MSI3.xlsx          Consolidated Balance Sheets
# MSI4.xlsx          Consolidated Balance Sheets
# MSI5.xlsx          Consolidated_Balance_Sheets
# NKE1.xlsx          Consolidated Balance Sheets
# NKE2.xlsx          Consolidated Balance Sheets
# NKE3.xlsx          Consolidated Balance Sheets
# NKE4.xlsx          Consolidated Balance Sheets
# NKE5.xlsx          Consolidated_Balance_Sheets
# ORCL1.xlsx         CONSOLIDATED BALANCE SHEETS
# ORCL2.xlsx         CONSOLIDATED BALANCE SHEETS
# ORCL3.xlsx         CONSOLIDATED BALANCE SHEETS
# ORCL4.xlsx         CONSOLIDATED BALANCE SHEETS
# ORCL5.xlsx         CONSOLIDATED_BALANCE_SHEETS
# PCAR1.xlsx         Consolidated Balance Sheets
# PCAR2.xlsx         Consolidated Balance Sheets
# PCAR3.xlsx         Consolidated Balance Sheets
# PCAR4.xlsx         Consolidated Balance Sheets
# PCAR5.xlsx         Consolidated_Balance_Sheets
# PEG1.xlsx          Consolidated Balance Sheets
# PEG2.xlsx          Consolidated Balance Sheets
# PEG3.xlsx          Consolidated Balance Sheets
# PEG4.xlsx          Consolidated Balance Sheets
# PEG5.xlsx          Consolidated_Balance_Sheets
# Pepsico1.xlsx       Consolidated Balance Sheet
# Pepsico2.xlsx       Consolidated Balance Sheet
# Pepsico3.xlsx       Consolidated Balance Sheet
# PPL1.xlsx          CONSOLIDATED BALANCE SHEETS
# PPL2.xlsx          CONSOLIDATED BALANCE SHEETS
# PPL3.xlsx          CONSOLIDATED BALANCE SHEETS
# PPL4.xlsx          CONSOLIDATED BALANCE SHEETS
# PPL5.xlsx          CONSOLIDATED_BALANCE_SHEETS
# REGN1.xlsx         CONSOLIDATED BALANCE SHEETS
# REGN2.xlsx         CONSOLIDATED BALANCE SHEETS
# REGN3.xlsx         CONSOLIDATED BALANCE SHEETS
# REGN4.xlsx         CONSOLIDATED BALANCE SHEETS
# REGN5.xlsx         CONSOLIDATED_BALANCE_SHEETS
# RL1.xlsx           Consolidated Balance Sheets
# RL2.xlsx           Consolidated Balance Sheets
# RL3.xlsx           Consolidated Balance Sheets
# RL4.xlsx           Consolidated Balance Sheets
# RL5.xlsx           Consolidated_Balance_Sheets
# ROK1.xlsx           Consolidated Balance Sheet
# ROK2.xlsx           Consolidated Balance Sheet
# ROk3.xlsx           Consolidated Balance Sheet
# ROK4.xlsx           Consolidated Balance Sheet
# ROK5.xlsx           Consolidated_Balance_Sheet
# ROST1.xlsx         Consolidated Balance Sheets
# ROST2.xlsx         Consolidated Balance Sheets
# ROST3.xlsx         Consolidated Balance Sheets
# ROST4.xlsx         Consolidated Balance Sheets
# ROST5.xlsx         Consolidated_Balance_Sheets
# SJM2.xlsx          Consolidated Balance Sheets
# SO1.xlsx       Consolidated Balance Sheets - S
# SO2.xlsx           Consolidated Balance Sheets
# SO3.xlsx           Consolidated Balance Sheets
# SO4.xlsx           Consolidated Balance Sheets
# SO5.xlsx           Consolidated_Balance_Sheets
# TAP1.xlsx          CONSOLIDATED BALANCE SHEETS
# TAP2.xlsx          CONSOLIDATED BALANCE SHEETS
# TAP4.xlsx          CONSOLIDATED_BALANCE_SHEETS
# TGT1.xlsx      Consolidated Statements of Fina
# TGT2.xlsx      Consolidated Statements of Fina
# TGT3.xlsx      Consolidated Statements of Fina
# TGT4.xlsx      Consolidated Statements of Fina
# TGT5.xlsx       Consolidated_Statements_of_Fin
# TJX1.xlsx          Consolidated Balance Sheets
# TJX2.xlsx          Consolidated Balance Sheets
# TJX3.xlsx          Consolidated Balance Sheets
# TJX4.xlsx          Consolidated Balance Sheets
# TJX5.xlsx          Consolidated_Balance_Sheets
# TSLA1.xlsx         Consolidated Balance Sheets
# TSLA2.xlsx         Consolidated Balance Sheets
# TSLA3.xlsx         Consolidated Balance Sheets
# TSLA4.xlsx         Consolidated Balance Sheets
# TSLA5.xlsx         Consolidated Balance Sheets
# UPS1.xlsx          CONSOLIDATED BALANCE SHEETS
# UPS2.xlsx          CONSOLIDATED BALANCE SHEETS
# UPS3.xlsx          CONSOLIDATED BALANCE SHEETS
# UPS4.xlsx          CONSOLIDATED BALANCE SHEETS
# UPS5.xlsx          CONSOLIDATED_BALANCE_SHEETS
# VZ1.xlsx           Consolidated Balance Sheets
# VZ2.xlsx           Consolidated Balance Sheets
# VZ3.xlsx           Consolidated Balance Sheets
# VZ4.xlsx           Consolidated Balance Sheets
# VZ5.xlsx           Consolidated_Balance_Sheets
# WAB1.xlsx          CONSOLIDATED BALANCE SHEETS
# WAB2.xlsx          CONSOLIDATED BALANCE SHEETS
# WAB3.xlsx          CONSOLIDATED BALANCE SHEETS
# WAB4.xlsx          CONSOLIDATED BALANCE SHEETS
# WAB5.xlsx          CONSOLIDATED_BALANCE_SHEETS
# WEC1.xlsx          Consolidated Balance Sheets
# WEC2.xlsx          Consolidated Balance Sheets
# WEC3.xlsx          Consolidated Balance Sheets
# WEC4.xlsx          Consolidated Balance Sheets
# WEC5.xlsx          Consolidated_Balance_Sheets
# WMT1.xlsx          Consolidated Balance Sheets
# WMT2.xlsx          Consolidated Balance Sheets
# WMT3.xlsx          Consolidated Balance Sheets
# WMT4.xlsx          Consolidated Balance Sheets
# WMT5.xlsx          Consolidated_Balance_Sheets
# WYNN1.xlsx         Consolidated Balance Sheets
# WYNN2.xlsx         Consolidated Balance Sheets
# WYNN3.xlsx         Consolidated Balance Sheets
# WYNN4.xlsx         Consolidated Balance Sheets
# WYNN5.xlsx         CONSOLIDATED_BALANCE_SHEETS
# ADM1.xlsx          Consolidated Balance Sheets
# ADM2.xlsx          Consolidated Balance Sheets
# ADM3.xlsx          Consolidated Balance Sheets
# ADM4.xlsx          Consolidated Balance Sheets
# ADM5.xlsx          Consolidated_Balance_Sheets
#
#                                         Income  \
# ADBE1.xlsx     Consolidated Statements of Inco
# ADBE2.xlsx     Consolidated Statements of Inco
# ADBE3.xlsx     Consolidated Statements of Inco
# ADBE4.xlsx     Consolidated Statements of Inco
# ADBE5.xlsx      Consolidated_Statements_of_Inc
# AME1.xlsx      Consolidated Statement of Incom
# AME2.xlsx      Consolidated Statement of Incom
# AME3.xlsx      Consolidated Statement of Incom
# AME4.xlsx      Consolidated Statement of Incom
# AME5.xlsx       Consolidated_Statement_of_Inco
# AMGN1.xlsx     Consolidated Statements of Inco
# AMGN2.xlsx     Consolidated Statements of Inco
# AMGN3.xlsx     Consolidated Statements of Inco
# AMGN4.xlsx     Consolidated Statements of Inco
# AMGN5.xlsx      Consolidated_Statements_of_Inc
# ANET1.xlsx     Consolidated Statements of Oper
# ANET2.xlsx     Consolidated Statements of Oper
# ANET3.xlsx     Consolidated Statements of Inco
# ANET4.xlsx     Consolidated Statements of Inco
# ANET5.xlsx      Consolidated_Statements_of_Inc
# BBY1.xlsx      Consolidated Statements of Earn
# BBY2.xlsx      Consolidated Statements of Earn
# BBY3.xlsx      CONSOLIDATED STATEMENTS OF EARN
# BBY4.xlsx      CONSOLIDATED STATEMENTS OF EARN
# BBY5.xlsx       CONSOLIDATED_STATEMENTS_OF_EAR
# BG1.xlsx       CONSOLIDATED STATEMENTS OF INCO
# BG2.xlsx       CONSOLIDATED STATEMENTS OF INCO
# BG3.xlsx       CONSOLIDATED STATEMENTS OF INCO
# BG4.xlsx       CONSOLIDATED STATEMENTS OF INCO
# BG5.xlsx        CONSOLIDATED_STATEMENTS_OF_INC
# BIIB1.xlsx     Consolidated Statements of Inco
# BIIB2.xlsx     Consolidated Statements of Inco
# BIIB3.xlsx     Consolidated Statements of Inco
# BIIB4.xlsx     Consolidated Statements of Inco
# BIIB5.xlsx      Consolidated_Statements_of_Inc
# BWA1.xlsx      CONSOLIDATED STATEMENTS OF OPER
# BWA2.xlsx      CONSOLIDATED STATEMENTS OF OPER
# CAT1.xlsx      Consolidated Results of Operati
# CAT2.xlsx      Consolidated Results of Operati
# CAT3.xlsx      Consolidated Results of Operati
# CAT4.xlsx      Consolidated Results of Operati
# CAT5.xlsx       Consolidated_Results_of_Operat
# CHTR1.xlsx     CONSOLIDATED STATEMENTS OF OPER
# CHTR2.xlsx     CONSOLIDATED STATEMENTS OF OPER
# CHTR3.xlsx     CONSOLIDATED STATEMENTS OF OPER
# CHTR4.xlsx     CONSOLIDATED STATEMENTS OF OPER
# CHTR5.xlsx      CONSOLIDATED_STATEMENTS_OF_OPE
# CMCSA1.xlsx    Consolidated Statement of Incom
# CMCSA2.xlsx    Consolidated Statement of Incom
# CMCSA3.xlsx    Consolidated Statement of Incom
# CMCSA4.xlsx    Consolidated Statement of Incom
# CMCSA5.xlsx     Consolidated_Statement_of_Inco
# COST1.xlsx     Consolidated Statements Of Inco
# COST2.xlsx     Consolidated Statements Of Inco
# COST3.xlsx     Consolidated Statements Of Inco
# COST4.xlsx     Consolidated Statements Of Inco
# COST5.xlsx      Consolidated_Statements_Of_Inc
# CPB1.xlsx      Consolidated Statements of Earn
# CPB2.xlsx      Consolidated Statements of Earn
# CPB3.xlsx      Consolidated Statements of Earn
# CRM1.xlsx      Consolidated Statements of Oper
# CRM2.xlsx      Consolidated Statements of Oper
# CRM4.xlsx      Consolidated Statements of Oper
# CRM5.xlsx       Consolidated_Statements_of_Ope
# CSCO1.xlsx     Consolidated Statements of Oper
# CSCO2.xlsx     Consolidated Statements of Oper
# CSCO3.xlsx     Consolidated Statements of Oper
# CSCO4.xlsx     Consolidated Statements Of Oper
# CSCO5.xlsx      Consolidated_Statements_Of_Ope
# D1.xlsx        Consolidated Statements of Inco
# D2.xlsx        Consolidated Statements of Inco
# D3.xlsx        Consolidated Statements of Inco
# D4.xlsx        Consolidated Statements of Inco
# D5.xlsx         Consolidated_Statements_of_Inc
# DG1.xlsx       CONSOLIDATED STATEMENTS OF INCO
# DG2.xlsx       CONSOLIDATED STATEMENTS OF INCO
# DG3.xlsx       CONSOLIDATED STATEMENTS OF INCO
# DG4.xlsx       CONSOLIDATED STATEMENTS OF INCO
# DG5.xlsx        CONSOLIDATED_STATEMENTS_OF_INC
# DLTR1.xlsx      CONSOLIDATED INCOME STATEMENTS
# DLTR2.xlsx     CONSOLIDATED STATEMENTS OF OPER
# DLTR3.xlsx      CONSOLIDATED INCOME STATEMENTS
# DLTR4.xlsx      CONSOLIDATED INCOME STATEMENTS
# DLTR5.xlsx      CONSOLIDATED_INCOME_STATEMENTS
# EIX1.xlsx      Consolidated Statements of Inco
# EIX2.xlsx      Consolidated Statements of Inco
# EIX3.xlsx      Consolidated Statements of Inco
# EIX4.xlsx      Consolidated Statements of Inco
# EIX5.xlsx       Consolidated_Statements_of_Inc
# EMR1.xlsx      Consolidated Statements Of Earn
# EMR2.xlsx      Consolidated Statements Of Earn
# EMR3.xlsx      Consolidated Statements Of Earn
# EMR4.xlsx      Consolidated Statements Of Earn
# EMR5.xlsx       Consolidated_Statements_Of_Ear
# FDX1.xlsx      Consolidated Statements of Inco
# FDX2.xlsx      Consolidated Statements of Inco
# FDX3.xlsx      Consolidated Statements of Inco
# FDX4.xlsx      Consolidated Statements of Inco
# FDX5.xlsx       Consolidated_Statements_of_Inc
# FE1.xlsx       Consolidated Statements of Inco
# FE2.xlsx       Consolidated Statements of Inco
# FE3.xlsx       Consolidated Statements of Inco
# FE4.xlsx       Consolidated Statements of Inco
# FE5.xlsx        Consolidated_Statements_of_Inc
# FE6.xlsx        Consolidated_Statements_of_Inc
# FFIV1.xlsx      Consolidated Income Statements
# FFIV2.xlsx      Consolidated Income Statements
# FFIV3.xlsx      Consolidated Income Statements
# FFIV4.xlsx      Consolidated Income Statements
# FFIV5.xlsx      Consolidated_Income_Statements
# GILD1.xlsx     CONSOLIDATED STATEMENTS OF INCO
# GILD2.xlsx     Consolidated Statements of Inco
# GILD3.xlsx     Consolidated Statements of Inco
# GILD4.xlsx     Consolidated Statements of Inco
# GILD5.xlsx      Consolidated_Statements_of_Inc
# GM1.xlsx        Consolidated Income Statements
# GM2.xlsx        Consolidated Income Statements
# GM3.xlsx        Consolidated Income Statements
# GM4.xlsx        Consolidated Income Statements
# GM5.xlsx        Consolidated_Income_Statements
# INCY1.xlsx     CONSOLIDATED STATEMENTS OF OPER
# INCY2.xlsx     CONSOLIDATED STATEMENTS OF OPER
# INCY3.xlsx     CONSOLIDATED STATEMENTS OF OPER
# INCY4.xlsx     CONSOLIDATED STATEMENTS OF OPER
# INCY5.xlsx      CONSOLIDATED_STATEMENTS_OF_OPE
# JNPR1.xlsx     Consolidated Statements of Oper
# JNPR2.xlsx     Consolidated Statements of Oper
# JNPR3.xlsx     Consolidated Statements of Oper
# JNPR4.xlsx     Consolidated Statements of Oper
# JNPR5.xlsx      Consolidated_Statements_of_Ope
# KO3.xlsx       CONSOLIDATED STATEMENTS OF INCO
# KO4.xlsx       CONSOLIDATED STATEMENTS OF INCO
# KO5.xlsx       CONSOLIDATED STATEMENTS OF INCO
# KR1.xlsx       CONSOLIDATED STATEMENTS OF OPER
# KR2.xlsx       CONSOLIDATED STATEMENTS OF OPER
# KR3.xlsx       CONSOLIDATED STATEMENTS OF OPER
# KR4.xlsx        CONSOLIDATED_STATEMENTS_OF_OPE
# LNT1.xlsx      Consolidated Statements Of Inco
# LNT2.xlsx      Consolidated Statements Of Inco
# LNT3.xlsx      Consolidated Statements Of Inco
# LNT4.xlsx      Consolidated Statements Of Inco
# LNT5.xlsx       Consolidated_Statements_Of_Inc
# LVS1.xlsx      CONSOLIDATED STATEMENTS OF OPER
# LVS2.xlsx      CONSOLIDATED STATEMENTS OF OPER
# LVS3.xlsx      CONSOLIDATED STATEMENTS OF OPER
# LVS4.xlsx      CONSOLIDATED STATEMENTS OF OPER
# LVS5.xlsx       CONSOLIDATED_STATEMENTS_OF_OPE
# MDLZ1.xlsx     Consolidated Statements of Earn
# MDLZ2.xlsx     Consolidated Statements of Earn
# MDLZ3.xlsx      Consolidated_Statements_of_Ear
# MGM1.xlsx      CONSOLIDATED STATEMENTS OF OPER
# MGM2.xlsx      Consolidated Statements of Oper
# MGM3.xlsx      Consolidated Statements of Oper
# MGM4.xlsx      Consolidated Statements of Oper
# MGM5.xlsx       Consolidated_Statements_Of_Ope
# MLM1.xlsx      Consolidated Statements of Earn
# MLM2.xlsx      Consolidated Statements of Earn
# MLM3.xlsx      Consolidated Statements of Earn
# MLM4.xlsx      Consolidated Statements of Earn
# MLM5.xlsx       Consolidated_Statements_of_Ear
# MSI1.xlsx      Consolidated Statements Of Oper
# MSI2.xlsx      Consolidated Statements Of Oper
# MSI3.xlsx      Consolidated Statements Of Oper
# MSI4.xlsx      Consolidated Statements Of Oper
# MSI5.xlsx       Consolidated_Statements_Of_Ope
# NKE1.xlsx      Consolidated Statements of Inco
# NKE2.xlsx      Consolidated Statements of Inco
# NKE3.xlsx      Consolidated Statements of Inco
# NKE4.xlsx      Consolidated Statements Of Inco
# NKE5.xlsx       Consolidated_Statements_Of_Inc
# ORCL1.xlsx     CONSOLIDATED STATEMENTS OF OPER
# ORCL2.xlsx     CONSOLIDATED STATEMENTS OF OPER
# ORCL3.xlsx     CONSOLIDATED STATEMENTS OF OPER
# ORCL4.xlsx     CONSOLIDATED STATEMENTS OF OPER
# ORCL5.xlsx      CONSOLIDATED_STATEMENTS_OF_OPE
# PCAR1.xlsx     Consolidated Statements of Inco
# PCAR2.xlsx     Consolidated Statements of Inco
# PCAR3.xlsx     Consolidated Statements of Inco
# PCAR4.xlsx     Consolidated Statements of Inco
# PCAR5.xlsx      Consolidated_Statements_of_Inc
# PEG1.xlsx      Consolidated Statements Of Oper
# PEG2.xlsx      Consolidated Statements Of Oper
# PEG3.xlsx      Consolidated Statements Of Oper
# PEG4.xlsx      Consolidated Statements Of Oper
# PEG5.xlsx       Consolidated_Statements_Of_Ope
# Pepsico1.xlsx  Consolidated Statement of Incom
# Pepsico2.xlsx  Consolidated Statement of Incom
# Pepsico3.xlsx  Consolidated Statement of Incom
# PPL1.xlsx      CONSOLIDATED STATEMENTS OF INCO
# PPL2.xlsx      CONSOLIDATED STATEMENTS OF INCO
# PPL3.xlsx      CONSOLIDATED STATEMENTS OF INCO
# PPL4.xlsx      CONSOLIDATED STATEMENTS OF INCO
# PPL5.xlsx       CONSOLIDATED_STATEMENTS_OF_INC
# REGN1.xlsx     CONSOLIDATED STATEMENTS OF OPER
# REGN2.xlsx     CONSOLIDATED STATEMENTS OF OPER
# REGN3.xlsx     CONSOLIDATED STATEMENTS OF OPER
# REGN4.xlsx     CONSOLIDATED STATEMENTS OF OPER
# REGN5.xlsx      CONSOLIDATED_STATEMENTS_OF_OPE
# RL1.xlsx       Consolidated Statements of Oper
# RL2.xlsx       Consolidated Statements of Oper
# RL3.xlsx       Consolidated Statements of Oper
# RL4.xlsx       Consolidated Statements of Inco
# RL5.xlsx        Consolidated_Statements_of_Inc
# ROK1.xlsx      Consolidated Statement of Opera
# ROK2.xlsx      Consolidated Statement of Opera
# ROk3.xlsx      Consolidated Statement of Opera
# ROK4.xlsx      Consolidated Statement of Opera
# ROK5.xlsx       Consolidated_Statement_of_Oper
# ROST1.xlsx     Consolidated Statements of Earn
# ROST2.xlsx     Consolidated Statements of Earn
# ROST3.xlsx     Consolidated Statements of Earn
# ROST4.xlsx     Consolidated Statements of Earn
# ROST5.xlsx      Consolidated_Statements_of_Ear
# SJM2.xlsx      Statements of Consolidated Inco
# SO1.xlsx       Consolidated Statements of Inco
# SO2.xlsx       Consolidated Statements of Inco
# SO3.xlsx       Consolidated Statements of Inco
# SO4.xlsx       Consolidated Statements of Inco
# SO5.xlsx        Consolidated_Statements_of_Inc
# TAP1.xlsx      CONSOLIDATED STATEMENTS OF OPER
# TAP2.xlsx      CONSOLIDATED STATEMENTS OF OPER
# TAP4.xlsx       CONSOLIDATED_STATEMENTS_OF_OPE
# TGT1.xlsx      Consolidated Statements of Oper
# TGT2.xlsx      Consolidated Statements of Oper
# TGT3.xlsx      Consolidated Statements of Oper
# TGT4.xlsx      Consolidated Statements of Oper
# TGT5.xlsx       Consolidated_Statements_of_Ope
# TJX1.xlsx      Consolidated Statements of Earn
# TJX2.xlsx      Consolidated Statements of Earn
# TJX3.xlsx      Consolidated Statements of Earn
# TJX4.xlsx      Consolidated Statements of Earn
# TJX5.xlsx       Consolidated_Statements_of_Ear
# TSLA1.xlsx     Consolidated Statements of Oper
# TSLA2.xlsx     Consolidated Statements of Oper
# TSLA3.xlsx     Consolidated Statements of Oper
# TSLA4.xlsx     Consolidated Statements of Oper
# TSLA5.xlsx     Consolidated Statements of Oper
# UPS1.xlsx      STATEMENTS OF CONSOLIDATED INCO
# UPS2.xlsx      STATEMENTS OF CONSOLIDATED INCO
# UPS3.xlsx      STATEMENTS OF CONSOLIDATED INCO
# UPS4.xlsx      STATEMENTS OF CONSOLIDATED INCO
# UPS5.xlsx       STATEMENTS_OF_CONSOLIDATED_INC
# VZ1.xlsx       Consolidated Statements of Inco
# VZ2.xlsx       Consolidated Statements of Inco
# VZ3.xlsx       Consolidated Statements of Inco
# VZ4.xlsx       Consolidated Statements of Inco
# VZ5.xlsx        Consolidated_Statements_of_Inc
# WAB1.xlsx      CONSOLIDATED STATEMENTS OF INCO
# WAB2.xlsx      CONSOLIDATED STATEMENTS OF INCO
# WAB3.xlsx      CONSOLIDATED STATEMENTS OF INCO
# WAB4.xlsx      CONSOLIDATED STATEMENTS OF INCO
# WAB5.xlsx       CONSOLIDATED_STATEMENTS_OF_INC
# WEC1.xlsx       Consolidated Income Statements
# WEC2.xlsx       Consolidated Income Statements
# WEC3.xlsx       Consolidated Income Statements
# WEC4.xlsx       Consolidated Income Statements
# WEC5.xlsx       Consolidated_Income_Statements
# WMT1.xlsx      Consolidated Statements of Inco
# WMT2.xlsx      Consolidated Statements of Inco
# WMT3.xlsx      Consolidated Statements of Inco
# WMT4.xlsx      Consolidated Statements of Inco
# WMT5.xlsx       Consolidated_Statements_Of_Inc
# WYNN1.xlsx     Consolidated Statements of Inco
# WYNN2.xlsx     Consolidated Statements of Inco
# WYNN3.xlsx     Consolidated Statements of Inco
# WYNN4.xlsx     Consolidated Statements of Inco
# WYNN5.xlsx      CONSOLIDATED_STATEMENTS_OF_INC
# ADM1.xlsx      Consolidated Statements Of Earn
# ADM2.xlsx      Consolidated Statements Of Earn
# ADM3.xlsx      Consolidated Statements Of Earn
# ADM4.xlsx      Consolidated Statements Of Earn
# ADM5.xlsx       Consolidated_Statements_Of_Ear
#
#                                           Cash
# ADBE1.xlsx     Consolidated Statements of Cash
# ADBE2.xlsx     Consolidated Statements of Cash
# ADBE3.xlsx     Consolidated Statements of Cash
# ADBE4.xlsx     Consolidated Statements of Cash
# ADBE5.xlsx      Consolidated_Statements_of_Cas
# AME1.xlsx      Consolidated Statement of Cash
# AME2.xlsx      Consolidated Statement of Cash
# AME3.xlsx      Consolidated Statement of Cash
# AME4.xlsx      Consolidated Statement of Cash
# AME5.xlsx       Consolidated_Statement_of_Cash
# AMGN1.xlsx     Consolidated Statements of Cash
# AMGN2.xlsx     Consolidated Statements of Cash
# AMGN3.xlsx     Consolidated Statements of Cash
# AMGN4.xlsx     Consolidated Statements of Cash
# AMGN5.xlsx      Consolidated_Statements_of_Cas
# ANET1.xlsx     Consolidated Statements of Cash
# ANET2.xlsx     Consolidated Statements of Cash
# ANET3.xlsx     Consolidated Statements of Cash
# ANET4.xlsx     Consolidated Statements of Cash
# ANET5.xlsx      Consolidated_Statements_of_Cas
# BBY1.xlsx      Consolidated Statements of Cash
# BBY2.xlsx      Consolidated Statements of Cash
# BBY3.xlsx      CONSOLIDATED STATEMENTS OF CASH
# BBY4.xlsx      CONSOLIDATED STATEMENTS OF CASH
# BBY5.xlsx       CONSOLIDATED_STATEMENTS_OF_CAS
# BG1.xlsx       CONSOLIDATED STATEMENTS OF CASH
# BG2.xlsx       CONSOLIDATED STATEMENTS OF CASH
# BG3.xlsx       CONSOLIDATED STATEMENTS OF CASH
# BG4.xlsx       CONSOLIDATED STATEMENTS OF CASH
# BG5.xlsx        CONSOLIDATED_STATEMENTS_OF_CAS
# BIIB1.xlsx     Consolidated Statements of Cash
# BIIB2.xlsx     Consolidated Statements of Cash
# BIIB3.xlsx     Consolidated Statements of Cash
# BIIB4.xlsx     Consolidated Statements of Cash
# BIIB5.xlsx      Consolidated_Statements_of_Cas
# BWA1.xlsx      CONSOLIDATED STATEMENTS OF CASH
# BWA2.xlsx      CONSOLIDATED STATEMENTS OF CASH
# CAT1.xlsx      Consolidated Statement of Cash
# CAT2.xlsx      Consolidated Statement of Cash
# CAT3.xlsx      Consolidated Statement of Cash
# CAT4.xlsx      Consolidated Statement of Cash
# CAT5.xlsx       Consolidated_Statement_of_Cash
# CHTR1.xlsx     CONSOLIDATED STATEMENTS OF CASH
# CHTR2.xlsx     CONSOLIDATED STATEMENTS OF CASH
# CHTR3.xlsx     CONSOLIDATED STATEMENTS OF CASH
# CHTR4.xlsx     CONSOLIDATED STATEMENTS OF CASH
# CHTR5.xlsx      CONSOLIDATED_STATEMENTS_OF_CAS
# CMCSA1.xlsx    Consolidated Statement of Cash
# CMCSA2.xlsx    Consolidated Statement of Cash
# CMCSA3.xlsx    Consolidated Statement of Cash
# CMCSA4.xlsx    Consolidated Statement of Cash
# CMCSA5.xlsx     Consolidated_Statement_of_Cash
# COST1.xlsx     Consolidated Statements Of Cash
# COST2.xlsx     Consolidated Statements Of Cash
# COST3.xlsx     Consolidated Statements Of Cash
# COST4.xlsx     Consolidated Statements Of Cash
# COST5.xlsx      Consolidated_Statements_Of_Cas
# CPB1.xlsx      Consolidated Statements of Cash
# CPB2.xlsx      Consolidated Statements of Cash
# CPB3.xlsx      Consolidated Statements of Cash
# CRM1.xlsx      Consolidated Statements of Cash
# CRM2.xlsx      Consolidated Statements of Cash
# CRM4.xlsx      Consolidated Statements of Cash
# CRM5.xlsx       Consolidated_Statements_of_Cas
# CSCO1.xlsx     Consolidated Statements of Cash
# CSCO2.xlsx     Consolidated Statements of Cash
# CSCO3.xlsx     Consolidated Statements of Cash
# CSCO4.xlsx     Consolidated Statements Of Cash
# CSCO5.xlsx      Consolidated_Statements_Of_Cas
# D1.xlsx        Consolidated Statements of Cash
# D2.xlsx        Consolidated Statements of Cash
# D3.xlsx        Consolidated Statements of Cash
# D4.xlsx        Consolidated Statements of Cash
# D5.xlsx         Consolidated_Statements_of_Cas
# DG1.xlsx       CONSOLIDATED STATEMENTS OF CASH
# DG2.xlsx       CONSOLIDATED STATEMENTS OF CASH
# DG3.xlsx       CONSOLIDATED STATEMENTS OF CASH
# DG4.xlsx       CONSOLIDATED STATEMENTS OF CASH
# DG5.xlsx        CONSOLIDATED_STATEMENTS_OF_CAS
# DLTR1.xlsx     CONSOLIDATED STATEMENTS OF CASH
# DLTR2.xlsx     CONSOLIDATED STATEMENTS OF CASH
# DLTR3.xlsx     CONSOLIDATED STATEMENTS OF CASH
# DLTR4.xlsx     CONSOLIDATED STATEMENTS OF CASH
# DLTR5.xlsx      CONSOLIDATED_STATEMENTS_OF_CAS
# EIX1.xlsx      Consolidated Statements of Cash
# EIX2.xlsx      Consolidated Statements of Cash
# EIX3.xlsx      Consolidated Statements of Cash
# EIX4.xlsx      Consolidated Statements of Cash
# EIX5.xlsx       Consolidated_Statements_of_Cas
# EMR1.xlsx      Consolidated Statements Of Cash
# EMR2.xlsx      Consolidated Statements Of Cash
# EMR3.xlsx      Consolidated Statements Of Cash
# EMR4.xlsx      Consolidated Statements Of Cash
# EMR5.xlsx       Consolidated_Statements_Of_Cas
# FDX1.xlsx      Consolidated Statements of Cash
# FDX2.xlsx      Consolidated Statements of Cash
# FDX3.xlsx      Consolidated Statements of Cash
# FDX4.xlsx      Consolidated Statements of Cash
# FDX5.xlsx       Consolidated_Statements_of_Cas
# FE1.xlsx       Consolidated Statements of Cash
# FE2.xlsx       Consolidated Statements of Cash
# FE3.xlsx       Consolidated Statements of Cash
# FE4.xlsx       Consolidated Statements of Cash
# FE5.xlsx        Consolidated_Statements_of_Cas
# FE6.xlsx        Consolidated_Statements_of_Cas
# FFIV1.xlsx     Consolidated Statements Of Cash
# FFIV2.xlsx     Consolidated Statements Of Cash
# FFIV3.xlsx     Consolidated Statements Of Cash
# FFIV4.xlsx     Consolidated Statements Of Cash
# FFIV5.xlsx      Consolidated_Statements_Of_Cas
# GILD1.xlsx     CONSOLIDATED STATEMENTS OF CASH
# GILD2.xlsx     Consolidated Statements of Cash
# GILD3.xlsx     Consolidated Statements of Cash
# GILD4.xlsx     Consolidated Statements of Cash
# GILD5.xlsx      Consolidated_Statements_of_Cas
# GM1.xlsx       Consolidated Statements Of Cash
# GM2.xlsx       Consolidated Statements Of Cash
# GM3.xlsx       Consolidated Statements Of Cash
# GM4.xlsx       Consolidated Statements Of Cash
# GM5.xlsx        Consolidated_Statements_Of_Cas
# INCY1.xlsx     CONSOLIDATED STATEMENTS OF CASH
# INCY2.xlsx     CONSOLIDATED STATEMENTS OF CASH
# INCY3.xlsx     CONSOLIDATED STATEMENTS OF CASH
# INCY4.xlsx     CONSOLIDATED STATEMENTS OF CASH
# INCY5.xlsx      CONSOLIDATED_STATEMENTS_OF_CAS
# JNPR1.xlsx     Consolidated Statements of Cash
# JNPR2.xlsx     Consolidated Statements of Cash
# JNPR3.xlsx     Consolidated Statements of Cash
# JNPR4.xlsx     Consolidated Statements of Cash
# JNPR5.xlsx      Consolidated_Statements_of_Cas
# KO3.xlsx       CONSOLIDATED STATEMENTS OF CASH
# KO4.xlsx       CONSOLIDATED STATEMENTS OF CASH
# KO5.xlsx       CONSOLIDATED STATEMENTS OF CASH
# KR1.xlsx       CONSOLIDATED STATEMENTS OF CASH
# KR2.xlsx       CONSOLIDATED STATEMENTS OF CASH
# KR3.xlsx       CONSOLIDATED STATEMENTS OF CASH
# KR4.xlsx        CONSOLIDATED_STATEMENTS_OF_CAS
# LNT1.xlsx      Consolidated Statements Of Cash
# LNT2.xlsx      Consolidated Statements Of Cash
# LNT3.xlsx      Consolidated Statements Of Cash
# LNT4.xlsx      Consolidated Statements Of Cash
# LNT5.xlsx       Consolidated_Statements_Of_Cas
# LVS1.xlsx      CONSOLIDATED STATEMENTS OF CASH
# LVS2.xlsx      CONSOLIDATED STATEMENTS OF CASH
# LVS3.xlsx      CONSOLIDATED STATEMENTS OF CASH
# LVS4.xlsx      CONSOLIDATED STATEMENTS OF CASH
# LVS5.xlsx       CONSOLIDATED_STATEMENTS_OF_CAS
# MDLZ1.xlsx     Consolidated Statements of Cash
# MDLZ2.xlsx     Consolidated Statements of Cash
# MDLZ3.xlsx      Consolidated_Statements_of_Cas
# MGM1.xlsx      CONSOLIDATED STATEMENTS OF CASH
# MGM2.xlsx      Consolidated Statements of Cash
# MGM3.xlsx      Consolidated Statements of Cash
# MGM4.xlsx      Consolidated Statements of Cash
# MGM5.xlsx       Consolidated_Statements_Of_Cas
# MLM1.xlsx      Consolidated Statements of Cash
# MLM2.xlsx      Consolidated Statements of Cash
# MLM3.xlsx      Consolidated Statements of Cash
# MLM4.xlsx      Consolidated Statements of Cash
# MLM5.xlsx       Consolidated_Statements_of_Cas
# MSI1.xlsx      Consolidated Statements of Cash
# MSI2.xlsx      Consolidated Statements of Cash
# MSI3.xlsx      Consolidated Statements of Cash
# MSI4.xlsx      Consolidated Statements of Cash
# MSI5.xlsx       Consolidated_Statements_Of_Cas
# NKE1.xlsx      Consolidated Statements of Cash
# NKE2.xlsx      Consolidated Statements of Cash
# NKE3.xlsx      Consolidated Statements of Cash
# NKE4.xlsx      Consolidated Statements of Cash
# NKE5.xlsx       Consolidated_Statements_of_Cas
# ORCL1.xlsx     CONSOLIDATED STATEMENTS OF CASH
# ORCL2.xlsx     CONSOLIDATED STATEMENTS OF CASH
# ORCL3.xlsx     CONSOLIDATED STATEMENTS OF CASH
# ORCL4.xlsx     CONSOLIDATED STATEMENTS OF CASH
# ORCL5.xlsx      CONSOLIDATED_STATEMENTS_OF_CAS
# PCAR1.xlsx     Consolidated Statements of Cash
# PCAR2.xlsx     Consolidated Statements of Cash
# PCAR3.xlsx     Consolidated Statements of Cash
# PCAR4.xlsx     Consolidated Statements of Cash
# PCAR5.xlsx      Consolidated_Statements_of_Cas
# PEG1.xlsx      Consolidated Statements Of Cash
# PEG2.xlsx      Consolidated Statements Of Cash
# PEG3.xlsx      Consolidated Statements Of Cash
# PEG4.xlsx      Consolidated Statements Of Cash
# PEG5.xlsx       Consolidated_Statements_Of_Cas
# Pepsico1.xlsx  Consolidated Statement of Cash
# Pepsico2.xlsx  Consolidated Statement of Cash
# Pepsico3.xlsx  Consolidated Statement of Cash
# PPL1.xlsx      CONSOLIDATED STATEMENTS OF CASH
# PPL2.xlsx      CONSOLIDATED STATEMENTS OF CASH
# PPL3.xlsx      CONSOLIDATED STATEMENTS OF CASH
# PPL4.xlsx      CONSOLIDATED STATEMENTS OF CASH
# PPL5.xlsx       CONSOLIDATED_STATEMENTS_OF_CAS
# REGN1.xlsx     CONSOLIDATED STATEMENTS OF CASH
# REGN2.xlsx     CONSOLIDATED STATEMENTS OF CASH
# REGN3.xlsx     CONSOLIDATED STATEMENTS OF CASH
# REGN4.xlsx     CONSOLIDATED STATEMENTS OF CASH
# REGN5.xlsx      CONSOLIDATED_STATEMENTS_OF_CAS
# RL1.xlsx       Consolidated Statements of Cash
# RL2.xlsx       Consolidated Statements of Cash
# RL3.xlsx       Consolidated Statements of Cash
# RL4.xlsx       Consolidated Statements of Cash
# RL5.xlsx        Consolidated_Statements_of_Cas
# ROK1.xlsx      Consolidated Statement of Cash
# ROK2.xlsx      Consolidated Statement of Cash
# ROk3.xlsx      Consolidated Statement of Cash
# ROK4.xlsx      Consolidated Statement of Cash
# ROK5.xlsx       Consolidated_Statement_of_Cash
# ROST1.xlsx     Consolidated Statements of Cash
# ROST2.xlsx     Consolidated Statements of Cash
# ROST3.xlsx     Consolidated Statements of Cash
# ROST4.xlsx     Consolidated Statements of Cash
# ROST5.xlsx      Consolidated_Statements_of_Cas
# SJM2.xlsx      Statements of Consolidated Cash
# SO1.xlsx       Consolidated Statements of Cash
# SO2.xlsx       Consolidated Statements of Cash
# SO3.xlsx       Consolidated Statements of Cash
# SO4.xlsx       Consolidated Statements of Cash
# SO5.xlsx        Consolidated_Statements_of_Cas
# TAP1.xlsx      CONSOLIDATED STATEMENTS OF CASH
# TAP2.xlsx      CONSOLIDATED STATEMENTS OF CASH
# TAP4.xlsx       CONSOLIDATED_STATEMENTS_OF_CAS
# TGT1.xlsx      Consolidated Statements of Cash
# TGT2.xlsx      Consolidated Statements of Cash
# TGT3.xlsx      Consolidated Statements of Cash
# TGT4.xlsx      Consolidated Statements of Cash
# TGT5.xlsx       Consolidated_Statements_of_Cas
# TJX1.xlsx      Consolidated Statements of Cash
# TJX2.xlsx      Consolidated Statements of Cash
# TJX3.xlsx      Consolidated Statements of Cash
# TJX4.xlsx      Consolidated Statements of Cash
# TJX5.xlsx       Consolidated_Statements_of_Cas
# TSLA1.xlsx     Consolidated Statements of Cash
# TSLA2.xlsx     Consolidated Statements of Cash
# TSLA3.xlsx     Consolidated Statements of Cash
# TSLA4.xlsx     Consolidated Statements of Cash
# TSLA5.xlsx     Consolidated Statements of Cash
# UPS1.xlsx      STATEMENTS OF CONSOLIDATED CASH
# UPS2.xlsx      STATEMENTS OF CONSOLIDATED CASH
# UPS3.xlsx      STATEMENTS OF CONSOLIDATED CASH
# UPS4.xlsx      STATEMENTS OF CONSOLIDATED CASH
# UPS5.xlsx       STATEMENTS_OF_CONSOLIDATED_CAS
# VZ1.xlsx       Consolidated Statements of Cash
# VZ2.xlsx       Consolidated Statements of Cash
# VZ3.xlsx       Consolidated Statements of Cash
# VZ4.xlsx       Consolidated Statements of Cash
# VZ5.xlsx        Consolidated_Statements_of_Cas
# WAB1.xlsx      CONSOLIDATED STATEMENTS OF CASH
# WAB2.xlsx      CONSOLIDATED STATEMENTS OF CASH
# WAB3.xlsx      CONSOLIDATED STATEMENTS OF CASH
# WAB4.xlsx      CONSOLIDATED STATEMENTS OF CASH
# WAB5.xlsx       CONSOLIDATED_STATEMENTS_OF_CAS
# WEC1.xlsx      Consolidated Statements of Cash
# WEC2.xlsx      Consolidated Statements of Cash
# WEC3.xlsx      Consolidated Statements of Cash
# WEC4.xlsx      Consolidated Statements of Cash
# WEC5.xlsx       Consolidated_Statements_of_Cas
# WMT1.xlsx      Consolidated Statements of Cash
# WMT2.xlsx      Consolidated Statements of Cash
# WMT3.xlsx      Consolidated Statements of Cash
# WMT4.xlsx      Consolidated Statements of Cash
# WMT5.xlsx       Consolidated_Statements_Of_Cas
# WYNN1.xlsx     Consolidated Statements of Cash
# WYNN2.xlsx     Consolidated Statements of Cash
# WYNN3.xlsx     Consolidated Statements of Cash
# WYNN4.xlsx     Consolidated Statements of Cash
# WYNN5.xlsx      CONSOLIDATED_STATEMENTS_OF_CAS
# ADM1.xlsx      Consolidated Statements Of Cash
# ADM2.xlsx      Consolidated Statements Of Cash
# ADM3.xlsx      Consolidated Statements Of Cash
# ADM4.xlsx      Consolidated Statements Of Cash
# ADM5.xlsx       Consolidated_Statements_Of_Cas

# %%
def clean_table (table):
    
    df = table.copy()  
    
    df.replace(u'\xa0','', regex=True, inplace=True)
    
    # Replace empty string with nan
    df.replace("^$",np.nan, regex=True, inplace=True)
    
    # Remove [n]
    
    for i in range(1,len(df.columns)):
      if df[df.columns[i]].dtype == object:
        df[df.columns[i]].replace("^\[\d\]", np.nan, regex=True, inplace=True)

    # Remove footnotes embedded in table
    
    df.drop(df.loc[df[df.columns[0]].str.contains(r"^\[\d?\]$", case=False, regex=True,na=False)].index,inplace=True)
    
    # Replace nan in first column with ''
    
    df[df.columns[0]].replace(np.nan,'',inplace=True)
    
    #Remove blank columns and rows
    
    df.dropna(axis=1, how='all', inplace=True)
    df.dropna(axis=0, how='all', inplace=True)
    
    if len(df.columns) > 5:
      # Take the first and the last 3 columns
        
      a = df.iloc[:,:1]
      b = df.iloc[:,-3:]
      df = pd.concat([a,b], axis=1)
    
    #Remove comments in brankets eg (Notes 1) and spurious characters
    
    df[df.columns[0]].replace(r"[\s]?\(.*\)", "", regex=True, inplace=True)
    df[df.columns[0]].replace(r"â€™","", regex=True, inplace=True)
    
    # Deal with situation where column labels are of type date time. Extract year and convert to str
  
    col = list(df.columns[0:])
    
    for i in range(0,len(col)):
      if type(col[i]) is datetime.datetime :
        col[i] = col[i].strftime('%Y')
    
    # Set columns to extraxted year which will be of type string
    # If we don't do this, the following if condition will not work.
    
    df.columns = col
        
    # If none of the columns contain a 4 digit number to signify year then take column headings from first row
    
    if df.columns.str.contains(r"\d\d\d\d", case=False, regex=True,na=False).sum() == 0:
        
      df.iloc[0].fillna('', axis=0, inplace=True)
      
      # Deal with the situation where the first row is read in as date time
    
      for i in range(0,len(df.iloc[0])):
        if type(df.iloc[0][i]) is datetime.datetime :
          df.iloc[0][i] = df.iloc[0][i].strftime('%Y')
            
      df.iloc[0] = df.iloc[0].astype('string')
      col = list(df.iloc[0])
    
      # Drop the first row
    
      df.drop(index=df.index[0], axis=0, inplace=True)
        
    col[0] = 'Index'
    
    # Extraxt year if there is a match
    
    for i in range(1,len(col)):
      res = re.search('(20[0-9][0-9])', col[i])

      if res:
        col[i] = res.group(0)
    
    df.columns = col  
    
    # Remove footnotes embedded in table
    
    df.drop(df.loc[df[df.columns[0]].str.contains(r"^\[\d?\]$", case=False, regex=True,na=False)].index,inplace=True)

    df.dropna(axis=1, how='all', inplace=True)
    df.dropna(axis=0, how='all', inplace=True)
    
     # Make sure that first column doesn't have any nulls
  
    df[df.columns[0]].fillna('', inplace=True)
    
    # Set index to first column
    
    df.set_index(df.columns[0], inplace=True)
    
    #Replace single quote with nan
    
    df.replace("'",np.nan, inplace=True)
    
    # Remove rows which contain otherwise specified
    
    df = df.loc[~df.index.str.contains(rf"unless otherwise",case=False, regex=True,na=False)]

    # Show first row as a validation check
    
    print(pd.DataFrame(df.iloc[0]).T)
    
    return df

# %%
def get_line_items(t):
 
  
  heading = []
  line_item = []
    
  for index, row in t.iterrows():
    
    if row.replace('', np.nan).isna().all():
      # Blank row, so assume heading
    
      heading.append(index)
    else:    
      line_item.append(index)

  return {'heading' : heading,
          'line_item' : line_item}

# %%
def get_spreadsheet(company,ticker,file, type):
    
  rootdir = "C:/Users/priye/Desktop/Dissertation/DATA/"

  dirname = rootdir + ticker
  path = dirname + '/' + file

  xl_file = pd.ExcelFile(path)
  table = xl_file.parse(company.loc[file,type],parse_dates=False)

  return table

# %%
rootdir = "C:/Users/priye/Desktop/Dissertation/DATA/"

headings = []
line_items = []
balance_sheets = {}

for d in listdir(rootdir):
    
  sheets = []
  dirname = rootdir + d
  for f in listdir(dirname):
    if f.endswith('xlsx'):
      print(f)
      table = get_spreadsheet(company,d,f,'Balance')
      t = clean_table(table)
      sheets.append(t)
        
      l_dict = get_line_items(t)      
      headings = headings + l_dict['heading']
      line_items = line_items + l_dict['line_item']
  balance_sheets[d] = sheets

# Remove duplicates from headings and line items

unique_list = set(headings)
headings = list(unique_list)

unique_list = set(line_items)
line_items = list(unique_list)

table_labels = {'headings' : headings,
                'line_items' : line_items}
# Out:
# ADBE1.xlsx
#                 2022 2021
# Current assets:  NaN  NaN
# ADBE2.xlsx
#                 2020 2019
# Current assets:  NaN  NaN
# ADBE3.xlsx
#                 2018 2017
# Current assets:  NaN  NaN
# ADBE4.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# ADBE5.xlsx
#                 2014 2013
# Current assets:  NaN  NaN
# ADM1.xlsx
#                2022 2021
# Current Assets  NaN  NaN
# ADM2.xlsx
#                 2020  2019
# Current Assets   NaN   NaN
# ADM3.xlsx
#                 2018  2017
# Current Assets   NaN   NaN
# ADM4.xlsx
#                 2018  2017
# Current Assets   NaN   NaN
# ADM5.xlsx
#                 2014  2013
# Current Assets   NaN   NaN
# AME1.xlsx
#                 2022 2021
# Current assets:  NaN  NaN
# AME2.xlsx
#                  2020  2019
# Current assets:   NaN   NaN
# AME3.xlsx
#                  2018  2017
# Current assets:   NaN   NaN
# AME4.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# AME5.xlsx
#                 2014 2013
# Current assets:  NaN  NaN
# AMGN1.xlsx
#                 2022 2021
# Current assets:  NaN  NaN
# AMGN2.xlsx
#                 2020 2019
# Current assets:  NaN  NaN
# AMGN3.xlsx
#                 2018 2017
# Current assets:  NaN  NaN
# AMGN4.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# AMGN5.xlsx
#                 2014 2013
# Current assets:  NaN  NaN
# ANET1.xlsx
#                 2022 2021
# CURRENT ASSETS:  NaN  NaN
# ANET2.xlsx
#                 2020 2019
# CURRENT ASSETS:  NaN  NaN
# ANET3.xlsx
#                 2018 2017
# CURRENT ASSETS:  NaN  NaN
# ANET4.xlsx
#                 2016 2015
# CURRENT ASSETS:  NaN  NaN
# ANET5.xlsx
#                 2014 2013
# CURRENT ASSETS:  NaN  NaN
# BBY1.xlsx
#                2023 2022
# Current assets  NaN  NaN
# BBY2.xlsx
#                2021 2020
# Current assets  NaN  NaN
# BBY3.xlsx
#                 2019  2018
# Current assets   NaN   NaN
# BBY4.xlsx
#                2017 2016
# CURRENT ASSETS  NaN  NaN
# BBY5.xlsx
#                2015 2014
# CURRENT ASSETS  NaN  NaN
# BG1.xlsx
#                 2022 2021
# Current assets:  NaN  NaN
# BG2.xlsx
#                  2020  2019
# Current assets:   NaN   NaN
# BG3.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# BG4.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# BG5.xlsx
#                 2014 2013
# Current assets:  NaN  NaN
# BIIB1.xlsx
#                 2022 2021
# Current assets:  NaN  NaN
# BIIB2.xlsx
#                 2020 2019
# Current assets:  NaN  NaN
# BIIB3.xlsx
#                 2018 2017
# Current assets:  NaN  NaN
# BIIB4.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# BIIB5.xlsx
#                 2014 2013
# Current assets:  NaN  NaN
# CAT1.xlsx
#                 2022 2021
# Current assets:  NaN  NaN
# CAT2.xlsx
#                  2020  2019
# Current assets:   NaN   NaN
# CAT3.xlsx
#                 2018 2017
# Current assets:  NaN  NaN
# CAT4.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# CAT5.xlsx
#                 2014 2013 2012
# Current assets:  NaN  NaN  NaN
# CHTR1.xlsx
#                 2022 2021
# CURRENT ASSETS:  NaN  NaN
# CHTR2.xlsx
#                  2020  2019
# CURRENT ASSETS:   NaN   NaN
# CHTR3.xlsx
#                  2018  2017
# CURRENT ASSETS:   NaN   NaN
# CHTR4.xlsx
#                  2016  2015
# CURRENT ASSETS:   NaN   NaN
# CHTR5.xlsx
#                  2014  2013
# CURRENT ASSETS:   NaN   NaN
# CMCSA1.xlsx
#                 2022 2021
# Current Assets:  NaN  NaN
# CMCSA2.xlsx
#                 2020 2019
# Current Assets:  NaN  NaN
# CMCSA3.xlsx
#                 2018 2017
# Current Assets:  NaN  NaN
# CMCSA4.xlsx
#                 2016 2015
# Current Assets:  NaN  NaN
# CMCSA5.xlsx
#                 2014 2013
# Current Assets:  NaN  NaN
# COST1.xlsx
#                2022 2021
# CURRENT ASSETS  NaN  NaN
# COST2.xlsx
#                 2020  2019
# CURRENT ASSETS   NaN   NaN
# COST3.xlsx
#                2018 2017
# CURRENT ASSETS  NaN  NaN
# COST4.xlsx
#                2016 2015
# CURRENT ASSETS  NaN  NaN
# COST5.xlsx
#                2014 2013
# CURRENT ASSETS  NaN  NaN
# CPB1.xlsx
#                2022 2021
# Current assets  NaN  NaN
# CPB2.xlsx
#                2019 2018
# Current assets  NaN  NaN
# CPB3.xlsx
#                2016 2015
# Current assets  NaN  NaN
# CSCO1.xlsx
#                 2022 2021
# Current assets:  NaN  NaN
# CSCO2.xlsx
#                 2020 2019
# Current assets:  NaN  NaN
# CSCO3.xlsx
#                 2018 2017
# Current assets:  NaN  NaN
# CSCO4.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# CSCO5.xlsx
#                 2014 2013
# Current assets:  NaN  NaN
# DG1.xlsx
#                 2023 2022
# Current assets:  NaN  NaN
# DG2.xlsx
#                 2021 2020
# Current assets:  NaN  NaN
# DG3.xlsx
#                 2019 2018
# Current assets:  NaN  NaN
# DG4.xlsx
#                 2017 2016
# Current assets:  NaN  NaN
# DG5.xlsx
#                 2015 2014
# Current assets:  NaN  NaN
# DLTR1.xlsx
#                 2023 2022
# Current assets:  NaN  NaN
# DLTR2.xlsx
#                 2021 2020
# Current assets:  NaN  NaN
# DLTR3.xlsx
#                 2019 2018
# Current assets:  NaN  NaN
# DLTR4.xlsx
#                 2017 2016
# Current assets:  NaN  NaN
# DLTR5.xlsx
#                 2015 2014
# Current assets:  NaN  NaN
# FFIV1.xlsx
#        2022 2021
# ASSETS  NaN  NaN
# FFIV2.xlsx
#        2020 2019
# ASSETS  NaN  NaN
# FFIV3.xlsx
#        2018 2017
# ASSETS  NaN  NaN
# FFIV4.xlsx
#        2016 2015
# ASSETS  NaN  NaN
# FFIV5.xlsx
#        2014 2013
# ASSETS  NaN  NaN
# GILD1.xlsx
#                 2022 2021
# Current assets:  NaN  NaN
# GILD2.xlsx
#                 2020 2019
# Current assets:  NaN  NaN
# GILD3.xlsx
#                2018 2017
# Current assets  NaN  NaN
# GILD4.xlsx
#                2016 2015
# Current assets  NaN  NaN
# GILD5.xlsx
#                            2014 2013
# Assets, Current [Abstract]  NaN  NaN
# GM1.xlsx
#                2022 2021
# Current Assets  NaN  NaN
# GM2.xlsx
#                2020 2019
# Current Assets  NaN  NaN
# GM3.xlsx
#                2018 2017
# Current Assets  NaN  NaN
# GM4.xlsx
#                           2016 2015
# Current Assets [Abstract]  NaN  NaN
# GM5.xlsx
#        2014 2013
# ASSETS  NaN  NaN
# INCY1.xlsx
#                 2022 2021
# Current assets:  NaN  NaN
# INCY2.xlsx
#                 2020 2019
# Current assets:  NaN  NaN
# INCY3.xlsx
#                 2018 2017
# Current assets:  NaN  NaN
# INCY4.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# INCY5.xlsx
#                 2014 2013
# Current assets:  NaN  NaN
# JNPR1.xlsx
#                 2022 2021
# Current assets:  NaN  NaN
# JNPR2.xlsx
#                 2020 2019
# Current assets:  NaN  NaN
# JNPR3.xlsx
#                 2018 2017
# Current assets:  NaN  NaN
# JNPR4.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# JNPR5.xlsx
#                 2014 2013
# Current assets:  NaN  NaN
# KO3.xlsx
#                 2015  2014
# CURRENT ASSETS   NaN   NaN
# KO4.xlsx
#                 2018  2017
# CURRENT ASSETS   NaN   NaN
# KO5.xlsx
#                 2021  2020
# CURRENT ASSETS   NaN   NaN
# KR1.xlsx
#                2022 2021
# Current assets  NaN  NaN
# KR2.xlsx
#                2020 2019
# Current assets  NaN  NaN
# KR3.xlsx
#                2018 2017
# Current assets  NaN  NaN
# KR4.xlsx
#                2014 2013
# Current assets  NaN  NaN
# LNT1.xlsx
#                 2022 2021
# Current assets:  NaN  NaN
# LNT2.xlsx
#                 2020 2019
# Current assets:  NaN  NaN
# LNT3.xlsx
#                 2018 2017
# Current assets:  NaN  NaN
# LNT4.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# LNT5.xlsx
#                 2014 2013
# Current assets:  NaN  NaN
# LVS1.xlsx
#                 2022 2021
# Current assets:  NaN  NaN
# LVS2.xlsx
#                 2020 2019
# Current assets:  NaN  NaN
# LVS3.xlsx
#                 2018 2017
# Current assets:  NaN  NaN
# LVS4.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# LVS5.xlsx
#                 2014 2013
# Current assets:  NaN  NaN
# MDLZ1.xlsx
#        2022 2021
# ASSETS  NaN  NaN
# MDLZ2.xlsx
#        2019 2018
# ASSETS  NaN  NaN
# MDLZ3.xlsx
#        2013 2012
# ASSETS  NaN  NaN
# MGM1.xlsx
#                2022 2021
# Current assets  NaN  NaN
# MGM2.xlsx
#                2020 2019
# Current assets  NaN  NaN
# MGM3.xlsx
#                2018 2017
# Current assets  NaN  NaN
# MGM4.xlsx
#                2016 2015
# Current assets  NaN  NaN
# MGM5.xlsx
#                2014 2013
# Current assets  NaN  NaN
# MLM1.xlsx
#                 2022 2021
# Current Assets:  NaN  NaN
# MLM2.xlsx
#                 2020 2019
# Current Assets:  NaN  NaN
# MLM3.xlsx
#                 2018 2017
# Current Assets:  NaN  NaN
# MLM4.xlsx
#                 2016 2015
# Current Assets:  NaN  NaN
# MLM5.xlsx
#                 2014 2013
# Current Assets:  NaN  NaN
# MSI1.xlsx
#        2022 2021
# ASSETS  NaN  NaN
# MSI2.xlsx
#         2020  2019
# ASSETS   NaN   NaN
# MSI3.xlsx
#         2018  2017
# ASSETS   NaN   NaN
# MSI4.xlsx
#         2016  2015
# ASSETS   NaN   NaN
# MSI5.xlsx
#         2014  2013
# ASSETS   NaN   NaN
# NKE1.xlsx
#                 2022 2021
# Current assets:  NaN  NaN
# NKE2.xlsx
#                 2020 2019
# Current assets:  NaN  NaN
# NKE3.xlsx
#                 2018 2017
# Current assets:  NaN  NaN
# NKE4.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# NKE5.xlsx
#                 2014 2013
# Current assets:  NaN  NaN
# ORCL1.xlsx
#                 2022 2021
# Current assets:  NaN  NaN
# ORCL2.xlsx
#                  2020  2019
# Current assets:   NaN   NaN
# ORCL3.xlsx
#                 2018 2017
# Current assets:  NaN  NaN
# ORCL4.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# ORCL5.xlsx
#                 2014 2013
# Current assets:  NaN  NaN
# PCAR1.xlsx
#        2022 2021
# ASSETS  NaN  NaN
# PCAR2.xlsx
#        2020 2019
# ASSETS  NaN  NaN
# PCAR3.xlsx
#         2018  2017
# ASSETS   NaN   NaN
# PCAR4.xlsx
#         2016  2015
# ASSETS   NaN   NaN
# PCAR5.xlsx
#        2014 2013
# ASSETS  NaN  NaN
# PEG1.xlsx
#                2022 2021
# CURRENT ASSETS  NaN  NaN
# PEG2.xlsx
#                2020 2019
# CURRENT ASSETS  NaN  NaN
# PEG3.xlsx
#                2018 2017
# CURRENT ASSETS  NaN  NaN
# PEG4.xlsx
#                2016 2015
# CURRENT ASSETS  NaN  NaN
# PEG5.xlsx
#                2014 2013
# CURRENT ASSETS  NaN  NaN
# Pepsico1.xlsx
#        2022 2021
# ASSETS  NaN  NaN
# Pepsico2.xlsx
#        2019 2018
# ASSETS  NaN  NaN
# Pepsico3.xlsx
#        2015 2014
# ASSETS  NaN  NaN
# REGN1.xlsx
#                 2022 2021
# Current assets:  NaN  NaN
# REGN2.xlsx
#                 2020 2019
# Current assets:  NaN  NaN
# REGN3.xlsx
#                 2018 2017
# Current assets:  NaN  NaN
# REGN4.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# REGN5.xlsx
#                 2014 2013
# Current assets:  NaN  NaN
# RL1.xlsx
#                 2022 2021
# Current assets:  NaN  NaN
# RL2.xlsx
#                 2020 2019
# Current assets:  NaN  NaN
# RL3.xlsx
#                 2018 2017
# Current assets:  NaN  NaN
# RL4.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# RL5.xlsx
#                 2014 2013
# Current assets:  NaN  NaN
# ROK1.xlsx
#                2022 2021
# Current assets  NaN  NaN
# ROK2.xlsx
#                 2020 2019
# Current assets:  NaN  NaN
# ROk3.xlsx
#                  2018  2017
# Current assets:   NaN   NaN
# ROK4.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# ROK5.xlsx
#                 2014 2013
# Current assets:  NaN  NaN
# ROST1.xlsx
#                2023 2022
# Current Assets  NaN  NaN
# ROST2.xlsx
#                2021 2020
# Current Assets  NaN  NaN
# ROST3.xlsx
#                2019 2018
# Current Assets  NaN  NaN
# ROST4.xlsx
#                2017 2016
# Current Assets  NaN  NaN
# ROST5.xlsx
#                2015 2014
# Current Assets  NaN  NaN
# TAP1.xlsx
#                2022 2021
# Current assets  NaN  NaN
# TAP2.xlsx
#                 2019 2018
# Current assets:  NaN  NaN
# TAP4.xlsx
#                 2013 2012
# Current assets:  NaN  NaN
# TGT1.xlsx
#        2023 2022
# Assets  NaN  NaN
# TGT2.xlsx
#         2021  2020
# Assets   NaN   NaN
# TGT3.xlsx
#        2019 2018
# Assets  NaN  NaN
# TGT4.xlsx
#         2017  2016
# Assets   NaN   NaN
# TGT5.xlsx
#         2015  2014
# Assets   NaN   NaN
# TJX1.xlsx
#                2023 2022
# Current Assets  NaN  NaN
# TJX2.xlsx
#                2021 2020
# Current Assets  NaN  NaN
# TJX3.xlsx
#                2019 2018
# Current Assets  NaN  NaN
# TJX4.xlsx
#                2017 2016
# Current Assets  NaN  NaN
# TJX5.xlsx
#                2015 2014
# Current Assets  NaN  NaN
# TSLA1.xlsx
#                2022 2021
# Current assets  NaN  NaN
# TSLA2.xlsx
#                2020 2019
# Current assets  NaN  NaN
# TSLA3.xlsx
#                2019 2018
# Current assets  NaN  NaN
# TSLA4.xlsx
#                2018 2017
# Current assets  NaN  NaN
# TSLA5.xlsx
#                2015 2014
# Current assets  NaN  NaN
# VZ1.xlsx
#                2022 2021
# Current assets  NaN  NaN
# VZ2.xlsx
#                2020 2019
# Current assets  NaN  NaN
# VZ3.xlsx
#                2018 2017
# Current assets  NaN  NaN
# VZ4.xlsx
#                2016 2015
# Current assets  NaN  NaN
# VZ5.xlsx
#                2014 2013
# Current assets  NaN  NaN
# WAB1.xlsx
#        2022 2021
# Assets  NaN  NaN
# WAB2.xlsx
#                2020 2019
# Current Assets  NaN  NaN
# WAB3.xlsx
#                2018 2017
# Current Assets  NaN  NaN
# WAB4.xlsx
#                 2016  2015
# Current Assets   NaN   NaN
# WAB5.xlsx
#                2014 2013
# Current Assets  NaN  NaN
# WEC1.xlsx
#                2022 2021
# Current assets  NaN  NaN
# WEC2.xlsx
#                2020 2019
# Current assets  NaN  NaN
# WEC3.xlsx
#                2018 2017
# Current assets  NaN  NaN
# WEC4.xlsx
#                2016 2015
# Current assets  NaN  NaN
# WEC5.xlsx
#                               2014 2013
# Property, Plant and Equipment  NaN  NaN
# WMT1.xlsx
#                 2023 2022
# Current assets:  NaN  NaN
# WMT2.xlsx
#                 2021 2020
# Current assets:  NaN  NaN
# WMT3.xlsx
#                 2019 2018
# Current assets:  NaN  NaN
# WMT4.xlsx
#                 2017 2016
# Current assets:  NaN  NaN
# WMT5.xlsx
#                 2015 2014
# Current assets:  NaN  NaN
# WYNN1.xlsx
#                 2022 2021
# Current assets:  NaN  NaN
# WYNN2.xlsx
#                 2020 2019
# Current assets:  NaN  NaN
# WYNN3.xlsx
#                 2018 2017
# Current assets:  NaN  NaN
# WYNN4.xlsx
#                 2016 2015
# Current assets:  NaN  NaN
# WYNN5.xlsx
#                 2014 2013
# Current assets:  NaN  NaN

# %%
def save_line_items(table_labels):
    
  with open('CSV/balance_headings.csv', 'w',encoding='utf-8') as f:
      
    # using csv.writer method from CSV package
    write = csv.writer(f)
      
    write.writerow(table_labels['headings'])
    
  with open('CSV/balance_line_items.csv', 'w',encoding='utf-8') as f:
      
    # using csv.writer method from CSV package
    write = csv.writer(f)
      
    write.writerow(table_labels['line_items'])

# %%
def save_balance_sheets(balance_sheets):
  with open('pickle/balance_sheets.pkl', 'wb') as fp:
    pickle.dump(balance_sheets, fp)

# %%
def save_table_labels(table_labels):

  with open('pickle/cash_table_labels.pkl', 'wb') as fp:
    pickle.dump(table_labels, fp)

# %%
save_line_items(table_labels)

# %%
save_table_labels(table_labels)

# %%
save_balance_sheets(balance_sheets)
