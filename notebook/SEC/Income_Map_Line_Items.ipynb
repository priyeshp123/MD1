# %%
import pandas as pd
import numpy as np
import pandas as pd
import openpyexcel
from openpyexcel import workbook, load_workbook
from openpyxl.worksheet.table import Table, TableStyleInfo
from openpyexcel.utils import get_column_letter
from itertools import islice
from os import listdir
import re
import csv
import datetime
import pickle

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 100)
pd.options.display.float_format = '{:.0f}'.format

# %% [markdown]
# # Map Line Items

# %%
df = pd.read_csv('CSV/income_map_line_items.csv')

# %%
df.set_index('line_item', inplace=True)

# %%
# Keep These lines

df[df.index.str.contains(r"(consoilidated)?Net Income",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"share|attributable|discontinued|equity",case=False, regex=True, na=False)] = 'NI'

df[df.index.str.contains(r"Total revenue",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"net|cost|gross|share|attributable|discontinued|equity",case=False, regex=True, na=False)] = 'TR'

df[df.index.str.contains(r"Total revenue.*(?:net|gross)",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"cost|share|attributable|discontinued|equity",case=False, regex=True, na=False)] = 'TR'

df[df.index.str.contains(r"gross.*profit",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"cost|share|attributable|discontinued|equity",case=False, regex=True, na=False)] = 'GP'

df[df.index.str.contains(r"profit",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"gross|cost|share|sharing|attributable|discontinued|equity",case=False, regex=True, na=False)] = 'OIL'

df[df.index.str.contains(r"admin",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"gross|cost|share|sharing|attributable|discontinued|equity",case=False, regex=True, na=False)] = 'SGA'

df[df.index.str.contains(r"operating",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"revenues|income|admin|pension|attributable|discontinued|loss|gains|profit",case=False, regex=True, na=False)] = 'OE'

# %%
#Income Sheet Mappings:

#TR     Total Revenue
#TGR    Total Gross Revenue
#TCR    Total Cost of Revenue
#GP     Gross Profit
#OE     Operating Expenses
#SGA    Selling, general administrative
#OIL    Operating Income or loss
#NI     Net Income

# %%
# Save to file

def save_line_items(df):
    
  df.to_csv('CSV/income_map_line_items.csv')

# %%
#Check rows which are not set to type 

df[df['type'].isna()]
# Out:
#                                                                             type
# line_item
# Equity in net income (losses) of investees, net                              NaN
# Income from Equity Method Investments                                        NaN
# Weighted average shares outstanding - assuming dilution                      NaN
# Net income (loss) attributable to MGM Resorts International                  NaN
# Gains on sales of investments in affiliates                                  NaN
# ...                                                                          ...
# Sanofi collaboration revenue                                                 NaN
# Other (expense) income , net                                                 NaN
# Total on-premise software revenues                                           NaN
# Cost of product revenues (including definite-lived intangible amortization)  NaN
# Total other income (expenses), net                                           NaN
#
# [946 rows x 1 columns]

# %%
# Select data which have a type set

df = df[~df['type'].isna()]

# %%
save_line_items(df)

# %% [markdown]
# # Map Headings

# %%
df = pd.read_csv('CSV/income_map_headings.csv')

# %%
df.set_index('heading', inplace=True)
df
# Out:
#                                                                                                      type
# heading
# Weighted average shares outstanding, basic:                                                             X
# COST OF SALES:                                                                                        NaN
# Net income per share attributable to common stockholders:                                             NaN
# Weighted-average common shares outstanding:                                                           NaN
# Diluted Earnings Per Common Share                                                                     NaN
# Net income attributable to Wynn Resorts, Limited:                                                     NaN
# Public Service Electric and Gas Company                                                               NaN
# Income Statement [Abstract]                                                                           NaN
# Weighted average outstanding shares:                                                                  NaN
# Expenses                                                                                              NaN
# Per Share - Assuming Dilution                                                                         NaN
# Entertainment, Retail and Other [Member]                                                              NaN
# Net income (loss) per common share:                                                                   NaN
# CONDENSED CONSOLIDATED STATEMENTS OF INCOME                                                           NaN
# Cost of revenue:                                                                                      NaN
# Rooms                                                                                                 NaN
# Per Share - Basic                                                                                     NaN
# Net Earnings (Loss) Attributable to Martin Marietta Per Common Share (see Note A)                     NaN
# Net loss attributable to Wynn Resorts, Limited:                                                       NaN
# Other expenses:                                                                                       NaN
# Net income attributable to common stockholders:                                                       NaN
# Financial Products                                                                                    NaN
# Service revenues and other                                                                            NaN
# Product sales [Member]                                                                                NaN
# Shares used in computing net income (loss) per share:                                                 NaN
# Revenues:                                                                                             NaN
# Products and solutions                                                                                NaN
# Weighted average number of common shares outstanding:                                                 NaN
# Net income (loss) per share of common stock attributable to MGM Resorts International                 NaN
# Basic earnings (loss) per share attributable to Best Buy Co., Inc. shareholders                       NaN
# Other income and expenses                                                                             NaN
# Costs and Expenses:                                                                                   NaN
# Basic earnings / (loss) per share                                                                     NaN
# Transmission Affiliate [Member]                                                                       NaN
# Amounts attributable to Motorola Solutions, Inc. common stockholders:                                 NaN
# Shares used in the calculation of earnings per share:                                                 NaN
# Operating revenues:                                                                                   NaN
# Earnings per common share:                                                                            NaN
# LOSS PER COMMON SHARE, BASIC AND DILUTED                                                              NaN
# Weighted Average Number of Common Shares Outstanding                                                  NaN
# Energy Generation and Storage [Member]                                                                NaN
# Cost of revenues:                                                                                     NaN
# Net Income Per Share                                                                                  NaN
# [1]Profit attributable to common shareholders.[2]Diluted by assumed exercise of stock-based compe...  NaN
# Net income (loss) per share:                                                                          NaN
# Weighted-average shares outstanding (000)                                                             NaN
# Other income (expense), net:                                                                          NaN
# Earnings per common share-basic                                                                       NaN
# Net sales                                                                                             NaN
# Earnings (loss) per common share-diluted                                                              NaN
# Other income (expense)                                                                                NaN
# Earnings per common share—diluted                                                                     NaN
# Operating costs:                                                                                      NaN
# Basic earnings per share                                                                              NaN
# Weighted average shares outstanding:                                                                  NaN
# NET INCOME PER COMMON SHARE ATTRIBUTABLE TO COSTCO:                                                   NaN
# Amounts attributable to common shareowners:                                                           NaN
# Earnings (loss) per common share:                                                                     NaN
# Other | Product and service, other                                                                    NaN
# Basic                                                                                                 NaN
# Power [Member]                                                                                        NaN
# GM Financial                                                                                          NaN
# Diluted (loss)/earnings per share                                                                     NaN
# Rooms [Member]                                                                                        NaN
# Non-operating income (expense)                                                                        NaN
# Shares used in calculation (000's)                                                                    NaN
# Other income (expense), net                                                                           NaN
# Weighted average shares used in computing net loss per share of common stock                          NaN
# Sales                                                                                                 NaN
# Revenues                                                                                              NaN
# Per share data:                                                                                       NaN
# All other excluding Financial Products                                                                NaN
# Product [Member]                                                                                      NaN
# Cost of collaboration and contract manufacturing                                                      NaN
# OPERATING EXPENSES                                                                                    NaN
# Basic:                                                                                                NaN
# Basic earnings per share:                                                                             NaN
# Net revenues:                                                                                         NaN
# Share-based Payment Arrangement [Member]                                                              NaN
# Weighted Average Common Shares Outstanding (Diluted)                                                  NaN
# OPERATING EXPENSES:                                                                                   NaN
# Net product sales                                                                                     NaN
# Collaboration and contract manufacturing                                                              NaN
# Product royalty revenues                                                                              NaN
# Non-operating income (expense):                                                                       NaN
# Earnings per weighted average common share attributable to Alliant Energy common shareowners:         NaN
# Casino [Member]                                                                                       NaN
# Consolidated Statements of Earnings [Abstract]                                                        NaN
# Weighted-average common shares outstanding (in millions)                                              NaN
# Other income (expense):                                                                               NaN
# Earnings per common share-diluted                                                                     NaN
# Revenue:                                                                                              NaN
# OTHER INCOME (EXPENSES):                                                                              NaN
# Net income per share of common stock attributable to common stockholders                              NaN
# Other Income (Expense):                                                                               NaN
# Net sales:                                                                                            NaN
# Revenues from anti-cd20 therapeutic programs                                                          NaN
# Automotive [Member]                                                                                   NaN
# Costs and Expenses [Abstract]                                                                         NaN
# Service [Member]                                                                                      NaN
# WPL [Member]                                                                                          NaN
# Diluted net income (loss) attributable to Molson Coors Beverage Company per share:                    NaN
# Weighted average shares used in computing net income (loss) per share of common stock                 NaN
# Financial Service [Member]                                                                            NaN
# Cloud and on-premises software revenues                                                               NaN
# Products and Services                                                                                 NaN
# Membership fees                                                                                       NaN
# Operating Expenses [Abstract]                                                                         NaN
# EARNINGS PER SHARE:                                                                                   NaN
# Net Earnings (Loss) Attributable to Martin Marietta                                                   NaN
# Provision for income taxes:                                                                           NaN
# Service                                                                                               NaN
# Product                                                                                               NaN
# Cost of sales:                                                                                        NaN
# IPL [Member]                                                                                          NaN
# Costs and expenses                                                                                    NaN
# Food and Beverage [Member]                                                                            NaN
# Convention, Retail and Other [Member]                                                                 NaN
# Earnings Per Share (Basic)                                                                            NaN
# Revenue from anti-CD20 therapeutic programs                                                           NaN
# Interest expense and other:                                                                           NaN
# Weighted average shares outstanding (000)                                                             NaN
# Weighted average shares outstanding, diluted:                                                         NaN
# Diluted                                                                                               NaN
# EARNINGS (LOSS) PER COMMON SHARE ATTRIBUTABLE TO CHARTER SHAREHOLDERS:                                NaN
# Net income (loss) attributable to Wynn Resorts, Limited:                                              NaN
# OTHER INCOME (EXPENSE)                                                                                NaN
# Other comprehensive income:                                                                           NaN
# OTHER EXPENSES:                                                                                       NaN
# NBCUniversal Media, LLC [Member]                                                                      NaN
# Cost of net revenues                                                                                  NaN
# [1]Our snack product categories include biscuits &amp; baked snacks, chocolate and gum &amp; cand...  NaN
# Entertainment, retail and other                                                                       NaN
# REVENUE:                                                                                              NaN
# NBCUniversal Media LLC [Member]                                                                       NaN
# Product, net                                                                                          NaN
# Mall [Member]                                                                                         NaN
# Casino                                                                                                NaN
# Basic net income (loss) attributable to Molson Coors Beverage Company per share:                      NaN
# Bayer                                                                                                 NaN
# Cost of sales                                                                                         NaN
# Weighted average common shares outstanding:                                                           NaN
# CONSOLIDATED STATEMENTS OF OPERATIONS                                                                 NaN
# Sanofi                                                                                                NaN
# Statements of Comprehensive Income                                                                    NaN
# Automotive Sales [Member]                                                                             NaN
# Diluted:                                                                                              NaN
# Machinery, Energy & Transportation                                                                    NaN
# Net Income Attributable to PepsiCo per Common Share                                                   NaN
# Earnings (loss) per share:                                                                            NaN
# Net income per share:                                                                                 NaN
# Net sales and revenue                                                                                 NaN
# CONSOLIDATED STATEMENTS OF INCOME                                                                     NaN
# Weighted-average shares used in computing net income per share attributable to common stockholders:   NaN
# Other [Member]                                                                                        NaN
# Operating Revenues                                                                                    NaN
# Wireless equipment                                                                                    NaN
# Food and beverage                                                                                     NaN
# Other (income) and deductions:                                                                        NaN
# Earnings per common share—basic                                                                       NaN
# Other comprehensive income (loss):                                                                    NaN
# Weighted average shares used in computing net income per share of common stock                        NaN
# REVENUE                                                                                               NaN
# Net income (loss) per share of common stock attributable to common stockholders                       NaN
# Other costs and expenses:                                                                             NaN
# Basic Earnings Per Common Share                                                                       NaN
# Diluted earnings / (loss) per share                                                                   NaN
# Other comprehensive income (loss), net of tax:                                                        NaN
# Operating Expenses                                                                                    NaN
# WEIGHTED AVERAGE COMMON SHARES OUTSTANDING:                                                           NaN
# Other revenue                                                                                         NaN
# Interest:                                                                                             NaN
# Net loss per share of common stock attributable to common stockholders                                NaN
# Weighted Average Number of Common Shares Outstanding:                                                 NaN
# GM Financial [Member]                                                                                 NaN
# Operating costs and expenses:                                                                         NaN
# Weighted Average Common Shares Outstanding (Millions)                                                 NaN
# Basic Earnings per Common Share                                                                       NaN
# Automotive                                                                                            NaN
# PSE&G [Member]                                                                                        NaN
# Product sales                                                                                         NaN
# Other revenues                                                                                        NaN
# Costs and expenses:                                                                                   NaN
# COSTS AND EXPENSES:                                                                                   NaN
# Milestone and contract revenues                                                                       NaN
# Earnings per share:                                                                                   NaN
# Earnings per share                                                                                    NaN
# Net revenues                                                                                          NaN
# Utility:                                                                                              NaN
# Diluted earnings per share:                                                                           NaN
# Earnings Per Share (Diluted)                                                                          NaN
# [1]Include after-tax impairments of $92 million related to certain Energy Holdings investments an...  NaN
# Financial Services                                                                                    NaN
# Shares used in computing net income per share:                                                        NaN
# Weighted-average common shares outstanding                                                            NaN
# Weighted average shares outstanding                                                                   NaN
# Weighted Average Number of Shares Outstanding, Diluted [Abstract]                                     NaN
# Other                                                                                                 NaN
# Bayer | Product and service, other                                                                    NaN
# Product revenues, net                                                                                 NaN
# Diluted Earnings per Common Share                                                                     NaN
# Amounts attributable to Molson Coors Beverage Company                                                 NaN
# Cost of revenues                                                                                      NaN
# Automotive Revenues [Member]                                                                          NaN
# Diluted earnings per share                                                                            NaN
# Weighted-average shares used in calculating:                                                          NaN
# Revenues from anti-CD20 therapeutic programs                                                          NaN
# Diluted earnings (loss) per share attributable to Best Buy Co., Inc. shareholders                     NaN
# Net (loss) income per share:                                                                          NaN
# Sanofi | Product and service, other                                                                   NaN
# [1]Exclusive of amortization of intangible assets, which is shown separately.                         NaN
# Basic (loss)/earnings per share                                                                       NaN
# Weighted-average common shares outstanding (millions)                                                 NaN
# EARNINGS PER COMMON SHARE ATTRIBUTABLE TO CHARTER SHAREHOLDERS:                                       NaN
# Truck, Parts and Other                                                                                NaN
# Hardware revenues:                                                                                    NaN
# Reimbursed costs                                                                                      NaN
# Earnings Per Share [Abstract]                                                                         NaN
# Earnings per weighted average common share attributable to Alliant Energy common shareowners (bas...  NaN
# Costs and Expenses                                                                                    NaN
# Earnings (loss) per share - basic and diluted:                                                        NaN
# Weighted average common shares outstanding                                                            NaN
# Expenses:                                                                                             NaN
# Net Earnings Attributable to Martin Marietta Per Common Share (see Note A)                            NaN
# Revenues [Abstract]                                                                                   NaN
# Operating expenses                                                                                    NaN
# Other collaboration revenue                                                                           NaN
# Weighted Average Common Shares Outstanding (Basic)                                                    NaN
# Services                                                                                              NaN
# Food and Beverage                                                                                     NaN
# Sales and revenues:                                                                                   NaN
# Freight                                                                                               NaN
# Net income per common share:                                                                          NaN
# Services And Other [Member]                                                                           NaN
# Shares used in per-share calculation:                                                                 NaN
# Diluted net income per common share:                                                                  NaN
# Earnings (loss) per share                                                                             NaN
# [1]In 2022, we recognized a loss of $4 million (including $3 million of premium and other costs) ...  NaN
# Royalty, contract and other revenues                                                                  NaN
# Operating expenses:                                                                                   NaN
# Basic net income per common share:                                                                    NaN
# [1] Prior period results have been adjusted to reflect the three -for-one stock split effected in...  NaN
# Earnings (loss) per common share-basic                                                                NaN
# Service and other                                                                                     NaN
# Weighted-Average Common Shares Outstanding                                                            NaN
# Cost and expenses:                                                                                    NaN
# Sanofi collaboration revenue                                                                          NaN
# Cost and expense:                                                                                     NaN
# Reimbursed Costs [Member]                                                                             NaN
# Equipment                                                                                             NaN
# Other income and expenses:                                                                            NaN
# PSEG Power LLC                                                                                        NaN
# Net loss per share of common stock attributable to MGM Resorts International                          NaN

# %%
#Income Sheet Mappings for headings:

#SR   Sales Revenue
#OE   Operating Expenses

# %%
# Keep these lines - Used to set type in headings

def set_headings_type:

df[df.index.str.contains(r"(?:cost|expense)",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"hardware|royalty|other|reimbursed|admin|contract|cloud|anti|collab|attributable|discontinued|loss|gains|profit",case=False, regex=True, na=False)] = 'OE'

# %%
df[df.index.str.contains(r"(?:cost|expense)",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"hardware|royalty|other|reimbursed|admin|contract|cloud|anti|collab|attributable|discontinued|loss|gains|profit",case=False, regex=True, na=False)] = 'OE'

# %%
# Save to file

def save_headings(df):
    
  df.to_csv('CSV/income_map_headings.csv')

# %%
save_headings(df)

# %% [markdown]
# # Create Mapping for Heading and Line Items

# %%
income_table_map = {'CFOA': ['NI'],
                    'No Heading': ['CEY']}

# %%
df_heading = pd.read_csv('CSV/income_map_headings.csv')
df_heading.set_index('heading', inplace=True)

df_line_item = pd.read_csv('CSV/income_map_line_items.csv')
df_line_item.set_index('line_item', inplace=True)

# %%
x = df_heading.to_dict()
income_heading_lookup = x['type']
income_heading_lookup

x = df_line_item.to_dict()
income_line_item_lookup = x['type']
income_line_item_lookup
# Out:
# {'Net (income) loss attributable to noncontrolling interests and redeemable noncontrolling interests': 'X',
#  'Administrative expenses': 'SGA',
#  'Total net revenues': 'TNR',
#  'Total operating costs': 'OE',
#  'Other Cost and Expense, Operating': 'OE',
#  'GM Financial interest, operating and other expenses': 'OE',
#  'Consolidated net income (loss)': 'NI',
#  'Net Income (Loss)': 'NI',
#  'Total cost and expenses': 'OE',
#  'OPERATING EXPENSES:': 'OE',
#  'Operating costs and expenses (excluding depreciation and amortization)': 'OE',
#  'Operating, general and administrative': 'SGA',
#  'NET INCOME FROM CONTINUING OPERATIONS': 'NI',
#  'Consolidated profit before taxes': 'OIL',
#  'Other operating and administrative': 'SGA',
#  'Selling, general and administrative': 'SGA',
#  'Consolidated net income': 'NI',
#  'Non-operating items from unconsolidated affiliates': 'OE',
#  'Operating overhead expense': 'OE',
#  'Consolidated profit before tax': 'OIL',
#  'Operating expenses:': 'OE',
#  'Net income (loss)': 'NI',
#  'Selling, general and administrative expense, net': 'SGA',
#  'Net income (loss) from continuing operations': 'NI',
#  'Net income including noncontrolling interests': 'NI',
#  'General and administrative': 'SGA',
#  'Operating earnings': 'OE',
#  'Total Operating Expenses': 'OE',
#  'Total revenues, gross': 'TR',
#  'Total operating expenses': 'OE',
#  'OPERATING EXPENSES': 'OE',
#  'Total other operating expenses, net': 'OE',
#  'Selling, general, and administrative': 'SGA',
#  'NET INCOME, BASIC': 'NI',
#  'Total sales and revenues': 'TR',
#  'Selling, general and administrative expense (including net gain on sale of divested businesses of $0, $1,774 and $1,007, respectively)': 'SGA',
#  'Gross Profit': 'GP',
#  'Profit (loss) of consolidated companies': 'OIL',
#  'Profit (loss) of consolidated and affiliated companies': 'OIL',
#  'Selling, general and administrative expenses, excluding Goodwill impairment and Receivable impairment': 'SGA',
#  'Total revenue': 'TR',
#  'NET INCOME, DILUTED': 'NI',
#  'Total costs and expenses': 'OE',
#  'Net income (loss) including noncontrolling interests': 'NI',
#  'Consolidated Net Income': 'NI',
#  'NET INCOME': 'NI',
#  'Total cost of revenue': 'TCR',
#  'Selling, General and Administrative Expense': 'SGA',
#  'Operating expenses': 'OE',
#  'Profit': 'OIL',
#  'Total cost of revenues': 'TCR',
#  'Gross profit': 'GP',
#  'Total Revenues': 'TR',
#  'Selling, general and administrative expenses': 'SGA',
#  'Operating, selling, general and administrative expenses': 'SGA',
#  'Other operating charges': 'OE',
#  'Automotive selling, general and administrative expense': 'SGA',
#  'GM Financial operating and other expenses': 'OE',
#  'Net income': 'NI',
#  'Total selling and administrative expense': 'SGA',
#  'Net Income': 'NI',
#  'Total operating costs and expenses': 'OE',
#  'Total revenues, net': 'TR',
#  'Selling, general and administrative expenses(a)': 'SGA',
#  'Other operating expenses, net': 'OE',
#  'Automotive and other selling, general and administrative expense': 'SGA',
#  'GROSS PROFIT': 'GP',
#  'Profit of consolidated and affiliated companies': 'OIL',
#  'Selling, general and administrative expenses, excluding Goodwill impairment': 'SGA',
#  'Operating costs and expenses (exclusive of items shown separately below)': 'OE',
#  'CONSOLIDATED NET INCOME': 'NI',
#  'Profit of consolidated companies': 'OIL',
#  'Profit (loss)': 'OIL',
#  'Marketing, general and administrative expenses': 'SGA',
#  'Selling, general and administrative expense': 'SGA',
#  'Total revenues': 'TR'}

# %% [markdown]
# # Combine Lookups for heading and line items into one dictionary and save

# %%
income_lookup = {'heading': income_heading_lookup,
               'line_item' : income_line_item_lookup}

# %%
# Save to file

with open('income_map_lookup.pkl', 'wb') as fp:
  pickle.dump(income_lookup, fp)
