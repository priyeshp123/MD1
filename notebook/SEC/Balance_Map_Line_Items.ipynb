# %%
import pandas as pd
import numpy as np
import pandas as pd
import openpyexcel
from openpyexcel import workbook, load_workbook
from openpyxl.worksheet.table import Table, TableStyleInfo
from openpyexcel.utils import get_column_letter
from itertools import islice
from os import listdir
import re
import csv
import datetime
import pickle

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 100)
pd.options.display.float_format = '{:.0f}'.format

# %% [markdown]
# # Map Line Items

# %%
df = pd.read_csv('CSV/balance_line_items.csv')

# %%
df.set_index('line_item', inplace=True)
df
# Out:
#                                                                                                      type
# line_item
# Investment securities                                                                                   X
# Other Assets                                                                                          NaN
# Deferred revenue from Sanofi                                                                          NaN
# Plant, property and equipment, net                                                                    NaN
# Other long-term assets, net                                                                           NaN
# ...                                                                                                   ...
# Common stock, par value $.01 per share, authorized 600,000,000 shares, issued and outstanding 207...  NaN
# Common stock, $1 par value - authorized 1.2 billion shares; issued 355.2 million and 354.3 millio...  NaN
# Paid-in capital                                                                                       NaN
# Total Biogen Inc. shareholders’ equity                                                                NaN
# Property, plant and equipment, net of accumulated depreciation of $36,164 and $34,253, respectively   NaN
#
# [1185 rows x 1 columns]

# %%
# Keep These lines - Used to set type in line items

def set_line_item_type():
    
df[df.index.str.contains(r"Total.*assets",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"current|other|non|deferred|discontinued",case=False, regex=True, na=False)] = 'TA'

df[df.index.str.contains(r"Total.*current.*assets",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"other|non|deferred|discontinued",case=False, regex=True, na=False)] = 'TCA'

df[df.index.str.contains(r"Total.*liabilities$",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"capitalization|long|current|other|non|deferred|discontinued",case=False, regex=True, na=False)] = 'TL'

df[df.index.str.contains(r"Total.*current.*liabilities$",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"capitalization|long|other|non|deferred|discontinued",case=False, regex=True, na=False)] = 'TCL'

df[df.index.str.contains(r"Total non.*current.*liabilities$",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"capitalization|long|other|deferred|discontinued",case=False, regex=True, na=False)] = 'TNCL'

df[df.index.str.contains(r"Total.*liabilities.*shareholder.*$",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"capitalization|long|other|deferred|discontinued",case=False, regex=True, na=False)] = 'TLSE'

df[df.index.str.contains(r"Total shareholder.*$",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"capitalization|long|other|deferred|discontinued",case=False, regex=True, na=False)] = 'TSE'

df[df.index.str.contains(r".*Intangible",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"capitalization|long|other|deferred|discontinued",case=False, regex=True, na=False)] = 'IA'

df[df.index.str.contains(r"Cash",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"hedges|restricted|obligation|long|other|deferred|discontinued",case=False, regex=True, na=False)] = 'TC'

df[df.index.str.contains(r"property",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"hedges|lease|restricted|gross|obligation|leases|other|deferred|discontinued",case=False, regex=True, na=False)] = 'NPPE'

df[df.index.str.contains(r"Total non",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"hedges|leases|other|deferred|liabilities|discontinued",case=False, regex=True, na=False)] = 'TNCA'

df[df.index.str.contains(r"Debt",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"hedges|leases|other|deferred|long|non|short|due|VIE|year|securities",case=False, regex=True, na=False)] = 'D'

df[df.index.str.contains(r"short.*Debt",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"hedges|leases|other|deferred|long|non|VIE|year|securities",case=False, regex=True, na=False)] = 'STD'

df[df.index.str.contains(r"long.*Debt",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"interest|leases|other|deferred|short|non|VIE|year|securities",case=False, regex=True, na=False)] = 'LTD'

df[df.index.str.contains(r"property",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"interest|leases|other|deferred|short|non|VIE|year|securities",case=False, regex=True, na=False)] = 'NPPE'

# %%
#Balance Sheet Mappings:
    
#TA   Total Assets
#TCA  Total Current Assets
#TL   Total Liabilities
#TCL  Total Current Liabilities
#TNCL Total Non Current Liabilities
#TLSE Total Liabilities and Shareholder Equity
#TSE  Total Shareholder Equity
#IA   Intangible assets
#TC   Total Cash
#NPPE Net property, plant and equipment
#TNCA Total non current assets
#D    Debt
#STD  Short term debt
#LTD  Long term debt

# %%
df[df.index.str.contains(r"property",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"interest|leases|other|deferred|short|non|VIE|year|securities",case=False, regex=True, na=False)] = 'NPPE'

# %%
# Out:
#                        type
# line_item
# ('Net revenues', nan)   NaN
# ('Net Revenue', nan)    NaN
# ('Net revenues:', nan)  NaN

# %%
# Save to file

def save_line_items(df):
    
  df.to_csv('CSV/balance_map_line_items.csv')

# %%
#Check rows which are not set to type 

df[df['type'].isna()]
# Out:
#                                                                                                      type
# line_item
# Other Assets                                                                                          NaN
# Deferred revenue from Sanofi                                                                          NaN
# Plant, property and equipment, net                                                                    NaN
# Other long-term assets, net                                                                           NaN
# Accrued salaries, benefits and payroll taxes                                                          NaN
# ...                                                                                                   ...
# Common stock, par value $.01 per share, authorized 600,000,000 shares, issued and outstanding 207...  NaN
# Common stock, $1 par value - authorized 1.2 billion shares; issued 355.2 million and 354.3 millio...  NaN
# Paid-in capital                                                                                       NaN
# Total Biogen Inc. shareholders’ equity                                                                NaN
# Property, plant and equipment, net of accumulated depreciation of $36,164 and $34,253, respectively   NaN
#
# [1098 rows x 1 columns]

# %%
# Select data which have a type set

df = df[~df['type'].isna()]

# %%
save_line_items(df)

# %% [markdown]
# # Map Headings

# %%
df = pd.read_csv('CSV/balance_headings.csv')

# %%
df.set_index('heading', inplace=True)
df
# Out:
#                                                                                                      type
# heading
# Current liabilities [Abstract]                                                                          X
# Best Buy Co., Inc. Shareholders Equity                                                                NaN
# NONCURRENT LIABILITIES                                                                                NaN
# Other Assets                                                                                          NaN
# Retained Earnings [Member]                                                                            NaN
# Best Buy Co., Inc. Shareholders’ Equity                                                               NaN
# CURRENT LIABILITIES                                                                                   NaN
# Class A common stock, par value $.01 per share; 104.9 million and 102.9 million shares issued; 47...  NaN
# Preferred stock, 1,000,000 shares authorized, no shares issued                                        NaN
# Automotive [Member]                                                                                   NaN
# Investments                                                                                           NaN
# LIABILITIES AND EQUITY                                                                                NaN
# NONCURRENT ASSETS                                                                                     NaN
# Property under capital lease and financing obligations:                                               NaN
# Oracle Corporation stockholders' equity:                                                              NaN
# Liabilities, Noncurrent [Abstract]                                                                    NaN
# Long-Term Liabilities                                                                                 NaN
# LONG-TERM DEBT                                                                                        NaN
# Class A common stock, par value $.01 per share; 102.0 million and 101.5 million shares issued; 55...  NaN
# Class A Convertible Common Stock                                                                      NaN
# Sanofi                                                                                                NaN
# Additional Paid-in Capital [Member]                                                                   NaN
# Solar Energy Systems [Member]                                                                         NaN
# Contingencies and Commitments                                                                         NaN
# Other Intangible Assets                                                                               NaN
# Assets, Noncurrent [Abstract]                                                                         NaN
# Preferred Stock                                                                                       NaN
# Shareholders equity                                                                                   NaN
# CURRENT ASSETS:                                                                                       NaN
# SHAREHOLDERS’ EQUITY                                                                                  NaN
# Power [Member]                                                                                        NaN
# Equity                                                                                                NaN
# Stockholders' deficit:                                                                                NaN
# STOCKHOLDER'S EQUITY                                                                                  NaN
# Deferred Charges and Other Assets                                                                     NaN
# Class A exchangeable shares                                                                           NaN
# Class A Common Stock                                                                                  NaN
# [1] Prior period results have been adjusted to reflect the three -for-one stock split effected in...  NaN
# WPL [Member]                                                                                          NaN
# Shareholders' equity:                                                                                 NaN
# Long-term liabilities                                                                                 NaN
# NBCUniversal Media, LLC [Member]                                                                      NaN
# Class A common stock, voting                                                                          NaN
# Stockholders' Equity                                                                                  NaN
# Commitments and Contingencies                                                                         NaN
# Class B Exchangeable Shares                                                                           NaN
# Stockholders' equity                                                                                  NaN
# Current Liabilities:                                                                                  NaN
# Common Stock                                                                                          NaN
# Series preferred stock                                                                                NaN
# Non-current assets:                                                                                   NaN
# Variable Interest Entity                                                                              NaN
# OTHER LIABILITIES                                                                                     NaN
# Common Class B                                                                                        NaN
# SHAREHOLDERS' EQUITY                                                                                  NaN
# Other assets                                                                                          NaN
# Current Liabilities                                                                                   NaN
# Biogen Inc. shareholders’ equity                                                                      NaN
# Property and Equipment                                                                                NaN
# Cisco shareholders’ equity:                                                                           NaN
# Operating Permits                                                                                     NaN
# Class B exchangeable shares                                                                           NaN
# Operating Lease Vehicles [Member]                                                                     NaN
# ASSETS                                                                                                NaN
# Contingencies and commitments                                                                         NaN
# Capital stock:                                                                                        NaN
# PepsiCo Common Shareholders’ Equity                                                                   NaN
# Preferred stock, no par value - authorized 1.0 million shares, none issued                            NaN
# Long-term debt due after one year:                                                                    NaN
# Non-current assets [Abstract]                                                                         NaN
# Common Stock, no par value                                                                            NaN
# LIABILITIES AND SHAREHOLDERS EQUITY                                                                   NaN
# SHAREHOLDERS' EQUITY:                                                                                 NaN
# Temporary Equity [Abstract]                                                                           NaN
# Property, Plant and Equipment                                                                         NaN
# Accounts and other receivables                                                                        NaN
# Gift Card [Member]                                                                                    NaN
# IPL [Member]                                                                                          NaN
# Long-term debt due within one year:                                                                   NaN
# Stockholders’ Equity                                                                                  NaN
# Stockholders Equity                                                                                   NaN
# Campbell Soup Company shareholders' equity                                                            NaN
# Class B common stock, non-voting                                                                      NaN
# Investments and Other Assets                                                                          NaN
# GM Financial                                                                                          NaN
# COMMITMENTS AND CONTINGENT LIABILITIES                                                                NaN
# Shareowners’ equity:                                                                                  NaN
# Stockholders' equity:                                                                                 NaN
# LIABILITIES                                                                                           NaN
# AOCI Attributable to Parent [Member]                                                                  NaN
# Class A common stock, $0.01 par value—authorized, 7,500,000,000 shares; issued, 5,083,466,045 and...  NaN
# INVESTMENT IN CABLE PROPERTIES:                                                                       NaN
# Other assets:                                                                                         NaN
# Class B Common Stock                                                                                  NaN
# SHAREOWNERS' EQUITY                                                                                   NaN
# Financial Products                                                                                    NaN
# Preferred shares, $100 par per share, 5 shares authorized and unissued                                NaN
# Public Service Electric and Gas Company                                                               NaN
# Treasury Stock [Member]                                                                               NaN
# STOCKHOLDERS' EQUITY:                                                                                 NaN
# Long-term liabilities:                                                                                NaN
# Assets                                                                                                NaN
# STOCKHOLDERS EQUITY:                                                                                  NaN
# Commitments and contingent liabilities                                                                NaN
# Class A Special Common Stock [Member]                                                                 NaN
# Financial Services                                                                                    NaN
# Convertible Preferred Stock                                                                           NaN
# Non-current Liabilities                                                                               NaN
# Capitalization                                                                                        NaN
# Shareholders’ Equity                                                                                  NaN
# Short-term borrowings:                                                                                NaN
# Common shareholders' equity                                                                           NaN
# Class B common stock, par value $.01 per share; 24.9 million issued and outstanding; 25.9 million...  NaN
# Non-current Assets                                                                                    NaN
# Property and equipment                                                                                NaN
# Class B common stock, par value $.01 per share; 26.9 million and 29.9 million shares issued and o...  NaN
# Common equity:                                                                                        NaN
# Current assets                                                                                        NaN
# Current Assets [Abstract]                                                                             NaN
# Preferred stock, 1,000 shares authorized                                                              NaN
# Other liabilities:                                                                                    NaN
# Class A common stock, par value $.01 per share; 101.0 million and 100.0 million shares issued; 57...  NaN
# Class A common stock, par value $.01 per share; 98.0 million and 93.6 million shares issued; 61.8...  NaN
# Deferred Revenue [Member]                                                                             NaN
# OTHER ASSETS                                                                                          NaN
# Assets, Current [Abstract]                                                                            NaN
# LIABILITIES AND STOCKHOLDERS’ EQUITY                                                                  NaN
# Other                                                                                                 NaN
# Inventories:                                                                                          NaN
# Current Assets:                                                                                       NaN
# [1]Net of unamortized debt discounts and issuance costs.                                              NaN
# Investments:                                                                                          NaN
# Property under capital leases:                                                                        NaN
# Commitments and contingencies                                                                         NaN
# GM Financial [Member]                                                                                 NaN
# [1] Includes a basis difference of approximately $419 million as of December 31, 2022 and $475 mi...  NaN
# EQUITY                                                                                                NaN
# Deferred Credits and Other Liabilities                                                                NaN
# Equity:                                                                                               NaN
# Common Class A                                                                                        NaN
# LIABILITIES AND STOCKHOLDERS' EQUITY                                                                  NaN
# Common stock issued, Class B                                                                          NaN
# Shareholders' equity                                                                                  NaN
# CURRENT LIABILITIES:                                                                                  NaN
# Class A Common Stock [Member]                                                                         NaN
# Automotive                                                                                            NaN
# Non-current liabilities [Abstract]                                                                    NaN
# Cisco stockholders’ equity:                                                                           NaN
# Juniper Networks stockholders' equity:                                                                NaN
# Current liabilities:                                                                                  NaN
# Preferred stock, $0.001 par value; 5,000,000 shares authorized; none issued or outstanding as of ...  NaN
# Class B common stock, par value $.01 per share; 25.9 million shares issued and outstanding            NaN
# Stockholders equity:                                                                                  NaN
# Long-term assets                                                                                      NaN
# CURRENT ASSETS                                                                                        NaN
# Shareholders’ equity:                                                                                 NaN
# Shareholders Equity                                                                                   NaN
# Stockholders’ equity:                                                                                 NaN
# Machinery, Energy & Transportation                                                                    NaN
# NBCUniversal Media LLC [Member]                                                                       NaN
# Class B common stock, par value $.01 per share; 24.9 million shares issued and outstanding            NaN
# Class B Common Stock [Member]                                                                         NaN
# STOCKHOLDERS’ EQUITY:                                                                                 NaN
# Accounts and other receivables:                                                                       NaN
# Property and equipment:                                                                               NaN
# Class A Stock                                                                                         NaN
# COMMITMENTS AND CONTINGENCIES                                                                         NaN
# Cisco shareholders equity:                                                                            NaN
# Accumulated other comprehensive loss                                                                  NaN
# Preferred stock, $0.01 par value; authorized: 5,000,000 shares; none issued                           NaN
# Current assets:                                                                                       NaN
# Current Liabilities [Abstract]                                                                        NaN
# PSEG Power LLC                                                                                        NaN
# Long-term debt including obligations under capital leases and financing obligations                   NaN
# Property, Plant, and Equipment                                                                        NaN
# Shareholders equity:                                                                                  NaN
# Liabilities                                                                                           NaN
# Biogen Idec Inc. shareholders' equity                                                                 NaN
# Stockholders' Equity [Abstract]                                                                       NaN
# Shareholders' investment                                                                              NaN
# PSE&G [Member]                                                                                        NaN
# Liabilities and shareholders' investment                                                              NaN
# PROPERTY AND EQUIPMENT                                                                                NaN
# Preferred stock                                                                                       NaN
# THE COCA-COLA COMPANY SHAREOWNERS' EQUITY                                                             NaN
# Shareowners' equity:                                                                                  NaN
# Capital stock                                                                                         NaN
# Shareholders’ equity                                                                                  NaN
# ClassA common stock, par value $.01 per share; 106.9 million and 106.1 million shares issued; 45....  NaN
# Truck, Parts and Other                                                                                NaN
# Current Assets                                                                                        NaN
# Series A Preferred Stock [Member]                                                                     NaN
# Equity [Abstract]                                                                                     NaN
# Current liabilities                                                                                   NaN
# Shareowners’ equity                                                                                   NaN
# Molson Coors Beverage Company stockholders' equity                                                    NaN
# LIABILITIES AND SHAREHOLDERS’ EQUITY                                                                  NaN
# Non-current liabilities:                                                                              NaN

# %%
#Balance Sheet Mappings for headings:

#CA   Current Assets
#CL   Liabilities
#PE   Property and Equipment
#SB   Short term borrowings
#LDY  Long term debt due within one year
#LD   Long term debt
#SI   Shareholders Investments
#SE   Shareholder Equity

# %%
# Keep these lines - Used to set type in headings

def set_headings():
    
df[df.index.str.contains(r"Asset",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"long|other|non|deferred|discontinued",case=False, regex=True, na=False)] = 'CA'

df[df.index.str.contains(r"liabilities",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"long|other|non|deferred|shareholder|equity|discontinued",case=False, regex=True, na=False)] = 'CL'

df[df.index.str.contains(r"property",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"long|other|non|deferred|lease|shareholder|equity|discontinued",case=False, regex=True, na=False)] = 'PE'

df[df.index.str.contains(r"short.*borrowings",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"long|other|non|deferred|lease|shareholder|equity|discontinued",case=False, regex=True, na=False)] = 'SB'

df[df.index.str.contains(r"long.*debt.*within",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"other|non|deferred|lease|shareholder|equity|discontinued",case=False, regex=True, na=False)] = 'LDY'

df[df.index.str.contains(r"investments",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"GAAP|within|other|non|deferred|lease|discontinued",case=False, regex=True, na=False)] = 'SI'

df[df.index.str.contains(r"equity",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"GAAP|within|other|non|deferred|lease|discontinued",case=False, regex=True, na=False)] = 'SE'
# Out:
#   File "<ipython-input-12-62590dbd654e>", line 6
#     ~ df.index.str.contains(r"adjustments|discontinued|change|reconciliation",case=False, regex=True, na=False)] =
#                                                                                                                   ^
# SyntaxError: invalid syntax

# %%
df[df.index.str.contains(r"equity",case=False, regex=True, na=False) & \
   ~ df.index.str.contains(r"GAAP|within|other|non|deferred|lease|discontinued",case=False, regex=True, na=False)]

# %%
# Save to file

def save_headings(df):
    
  df.to_csv('CSV/balance_map_headings.csv')

# %%
#Check rows which are not set to type 

df[df['type'].isna()]
# Out:
#                                                                                                      type
# heading
# NONCURRENT LIABILITIES                                                                                NaN
# Other Assets                                                                                          NaN
# Retained Earnings [Member]                                                                            NaN
# Class A common stock, par value $.01 per share; 104.9 million and 102.9 million shares issued; 47...  NaN
# Preferred stock, 1,000,000 shares authorized, no shares issued                                        NaN
# Automotive [Member]                                                                                   NaN
# NONCURRENT ASSETS                                                                                     NaN
# Property under capital lease and financing obligations:                                               NaN
# Liabilities, Noncurrent [Abstract]                                                                    NaN
# Long-Term Liabilities                                                                                 NaN
# Class A common stock, par value $.01 per share; 102.0 million and 101.5 million shares issued; 55...  NaN
# Class A Convertible Common Stock                                                                      NaN
# Sanofi                                                                                                NaN
# Additional Paid-in Capital [Member]                                                                   NaN
# Solar Energy Systems [Member]                                                                         NaN
# Contingencies and Commitments                                                                         NaN
# Other Intangible Assets                                                                               NaN
# Assets, Noncurrent [Abstract]                                                                         NaN
# Preferred Stock                                                                                       NaN
# Power [Member]                                                                                        NaN
# Stockholders' deficit:                                                                                NaN
# Deferred Charges and Other Assets                                                                     NaN
# Class A exchangeable shares                                                                           NaN
# Class A Common Stock                                                                                  NaN
# [1] Prior period results have been adjusted to reflect the three -for-one stock split effected in...  NaN
# WPL [Member]                                                                                          NaN
# Long-term liabilities                                                                                 NaN
# NBCUniversal Media, LLC [Member]                                                                      NaN
# Class A common stock, voting                                                                          NaN
# Commitments and Contingencies                                                                         NaN
# Class B Exchangeable Shares                                                                           NaN
# Common Stock                                                                                          NaN
# Series preferred stock                                                                                NaN
# Non-current assets:                                                                                   NaN
# Variable Interest Entity                                                                              NaN
# OTHER LIABILITIES                                                                                     NaN
# Common Class B                                                                                        NaN
# Other assets                                                                                          NaN
# Operating Permits                                                                                     NaN
# Class B exchangeable shares                                                                           NaN
# Operating Lease Vehicles [Member]                                                                     NaN
# Contingencies and commitments                                                                         NaN
# Capital stock:                                                                                        NaN
# Preferred stock, no par value - authorized 1.0 million shares, none issued                            NaN
# Non-current assets [Abstract]                                                                         NaN
# Common Stock, no par value                                                                            NaN
# Accounts and other receivables                                                                        NaN
# Gift Card [Member]                                                                                    NaN
# IPL [Member]                                                                                          NaN
# Class B common stock, non-voting                                                                      NaN
# Investments and Other Assets                                                                          NaN
# GM Financial                                                                                          NaN
# AOCI Attributable to Parent [Member]                                                                  NaN
# Class A common stock, $0.01 par value—authorized, 7,500,000,000 shares; issued, 5,083,466,045 and...  NaN
# INVESTMENT IN CABLE PROPERTIES:                                                                       NaN
# Other assets:                                                                                         NaN
# Class B Common Stock                                                                                  NaN
# Financial Products                                                                                    NaN
# Preferred shares, $100 par per share, 5 shares authorized and unissued                                NaN
# Public Service Electric and Gas Company                                                               NaN
# Treasury Stock [Member]                                                                               NaN
# Long-term liabilities:                                                                                NaN
# Class A Special Common Stock [Member]                                                                 NaN
# Financial Services                                                                                    NaN
# Convertible Preferred Stock                                                                           NaN
# Non-current Liabilities                                                                               NaN
# Capitalization                                                                                        NaN
# Class B common stock, par value $.01 per share; 24.9 million issued and outstanding; 25.9 million...  NaN
# Non-current Assets                                                                                    NaN
# Class B common stock, par value $.01 per share; 26.9 million and 29.9 million shares issued and o...  NaN
# Preferred stock, 1,000 shares authorized                                                              NaN
# Other liabilities:                                                                                    NaN
# Class A common stock, par value $.01 per share; 101.0 million and 100.0 million shares issued; 57...  NaN
# Class A common stock, par value $.01 per share; 98.0 million and 93.6 million shares issued; 61.8...  NaN
# Deferred Revenue [Member]                                                                             NaN
# OTHER ASSETS                                                                                          NaN
# Other                                                                                                 NaN
# Inventories:                                                                                          NaN
# [1]Net of unamortized debt discounts and issuance costs.                                              NaN
# Property under capital leases:                                                                        NaN
# Commitments and contingencies                                                                         NaN
# GM Financial [Member]                                                                                 NaN
# [1] Includes a basis difference of approximately $419 million as of December 31, 2022 and $475 mi...  NaN
# Deferred Credits and Other Liabilities                                                                NaN
# Common Class A                                                                                        NaN
# Common stock issued, Class B                                                                          NaN
# Class A Common Stock [Member]                                                                         NaN
# Automotive                                                                                            NaN
# Non-current liabilities [Abstract]                                                                    NaN
# Preferred stock, $0.001 par value; 5,000,000 shares authorized; none issued or outstanding as of ...  NaN
# Class B common stock, par value $.01 per share; 25.9 million shares issued and outstanding            NaN
# Long-term assets                                                                                      NaN
# Machinery, Energy & Transportation                                                                    NaN
# NBCUniversal Media LLC [Member]                                                                       NaN
# Class B common stock, par value $.01 per share; 24.9 million shares issued and outstanding            NaN
# Class B Common Stock [Member]                                                                         NaN
# Accounts and other receivables:                                                                       NaN
# Class A Stock                                                                                         NaN
# COMMITMENTS AND CONTINGENCIES                                                                         NaN
# Accumulated other comprehensive loss                                                                  NaN
# Preferred stock, $0.01 par value; authorized: 5,000,000 shares; none issued                           NaN
# PSEG Power LLC                                                                                        NaN
# Long-term debt including obligations under capital leases and financing obligations                   NaN
# Shareholders' investment                                                                              NaN
# PSE&G [Member]                                                                                        NaN
# Liabilities and shareholders' investment                                                              NaN
# Preferred stock                                                                                       NaN
# Capital stock                                                                                         NaN
# ClassA common stock, par value $.01 per share; 106.9 million and 106.1 million shares issued; 45....  NaN
# Truck, Parts and Other                                                                                NaN
# Series A Preferred Stock [Member]                                                                     NaN
# Non-current liabilities:                                                                              NaN

# %%
# Select data which have a type set

df = df[~df['type'].isna()]
df
# Out:
#                                                    type
# heading
# Current liabilities [Abstract]                       CL
# Best Buy Co., Inc. Shareholders Equity               SE
# Best Buy Co., Inc. Shareholders’ Equity              SE
# CURRENT LIABILITIES                                  CL
# Investments                                          SI
# LIABILITIES AND EQUITY                               SE
# Oracle Corporation stockholders' equity:             SE
# LONG-TERM DEBT                                       LD
# Shareholders equity                                  SE
# CURRENT ASSETS:                                      CA
# SHAREHOLDERS’ EQUITY                                 SE
# Equity                                               SE
# STOCKHOLDER'S EQUITY                                 SE
# Shareholders' equity:                                SE
# Stockholders' Equity                                 SE
# Stockholders' equity                                 SE
# Current Liabilities:                                 CL
# SHAREHOLDERS' EQUITY                                 SE
# Current Liabilities                                  CL
# Biogen Inc. shareholders’ equity                     SE
# Property and Equipment                               PE
# Cisco shareholders’ equity:                          SE
# ASSETS                                               CA
# PepsiCo Common Shareholders’ Equity                  SE
# Long-term debt due after one year:                   LD
# LIABILITIES AND SHAREHOLDERS EQUITY                  SE
# SHAREHOLDERS' EQUITY:                                SE
# Temporary Equity [Abstract]                          SE
# Property, Plant and Equipment                        PE
# Long-term debt due within one year:                 LDY
# Stockholders’ Equity                                 SE
# Stockholders Equity                                  SE
# Campbell Soup Company shareholders' equity           SE
# COMMITMENTS AND CONTINGENT LIABILITIES               CL
# Shareowners’ equity:                                 SE
# Stockholders' equity:                                SE
# LIABILITIES                                          CL
# SHAREOWNERS' EQUITY                                  SE
# STOCKHOLDERS' EQUITY:                                SE
# Assets                                               CA
# STOCKHOLDERS EQUITY:                                 SE
# Commitments and contingent liabilities               CL
# Shareholders’ Equity                                 SE
# Short-term borrowings:                               SB
# Common shareholders' equity                          SE
# Property and equipment                               PE
# Common equity:                                       SE
# Current assets                                       CA
# Current Assets [Abstract]                            CA
# Assets, Current [Abstract]                           CA
# LIABILITIES AND STOCKHOLDERS’ EQUITY                 SE
# Current Assets:                                      CA
# Investments:                                         SI
# EQUITY                                               SE
# Equity:                                              SE
# LIABILITIES AND STOCKHOLDERS' EQUITY                 SE
# Shareholders' equity                                 SE
# CURRENT LIABILITIES:                                 CL
# Cisco stockholders’ equity:                          SE
# Juniper Networks stockholders' equity:               SE
# Current liabilities:                                 CL
# Stockholders equity:                                 SE
# CURRENT ASSETS                                       CA
# Shareholders’ equity:                                SE
# Shareholders Equity                                  SE
# Stockholders’ equity:                                SE
# STOCKHOLDERS’ EQUITY:                                SE
# Property and equipment:                              PE
# Cisco shareholders equity:                           SE
# Current assets:                                      CA
# Current Liabilities [Abstract]                       CL
# Property, Plant, and Equipment                       PE
# Shareholders equity:                                 SE
# Liabilities                                          CL
# Biogen Idec Inc. shareholders' equity                SE
# Stockholders' Equity [Abstract]                      SE
# PROPERTY AND EQUIPMENT                               PE
# THE COCA-COLA COMPANY SHAREOWNERS' EQUITY            SE
# Shareowners' equity:                                 SE
# Shareholders’ equity                                 SE
# Current Assets                                       CA
# Equity [Abstract]                                    SE
# Current liabilities                                  CL
# Shareowners’ equity                                  SE
# Molson Coors Beverage Company stockholders' equity   SE
# LIABILITIES AND SHAREHOLDERS’ EQUITY                 SE

# %%
save_headings(df)

# %%
#Balance SHeet Mappings for line items:
    
#TA   Total Assets
#TCA  Total Current Assets
#TL   Total Liabilities
#TCL  Total Current Liabilities
#TNCL Total Non Current Liabilities
#TLSE Total Liabilities and Shareholder Equity
#TSE  Total Shareholder Equity
#IA   Intangible assets
#TC   Total Cash
#NPPE Net property, plant and equipment
#TNCA Total non current assets
#D    Debt
#STD  Short term debt
#LTD  Long term debt

#Balance Sheet Mappings for headings:

#CA   Current Assets
#CL   Liabilities
#PE   Property and Equipment
#SB   Short term borrowings
#LDY  Long term debt due within one year
#LD   Long term debt
#SI   Shareholders Investments
#SE   Shareholder Equity

# %% [markdown]
# # Create mapping for Headings and Line Items

# %%
cash_table_map = {'CA':  ['TA','TCA','TNCA'],
                  'CL':  ['TL','TCL','TNCL','TLSE'],
                  'PE':  ['NPPE'],
                  'LDY': ['STD'],
                  'LD':  ['LTD'],
                  'SI':  ['TSE','TLSE'],
                  'SE':  ['TSE','TLSE'],
                  'No Heading': ['D']}

# %% [markdown]
# # Create lookup for Headings

# %%
df
# Out:
#                                                                                                       type
# heading
# Adjustments to reconcile consolidated net earnings to net cash provided by operating activities:      ARNI
# Investing Activities                                                                                   CIA
# Cash flows from operating activities:                                                                 CFOA
# Cash Flows from Financing Activities                                                                   CFA
# Operating activities:                                                                                 CFOA
# Adjustments to arrive at cash provided by operating activities:                                       ARNI
# CASH PROVIDED BY / (USED IN) OPERATING ACTIVITIES                                                     CFOA
# Significant Non-cash Investing and Financing Activity                                                  CFA
# Changes in Operating Assets and Liabilities [Abstract]                                                COAL
# Adjustments to reconcile net income (loss) to net cash flows from operating activities:               ARNI
# Changes in operating assets and liabilities net of effects from mergers and disposals of businesses:  COAL
# Cash flows used in investing activities:                                                               CIA
# Cash Flows from Operating Activities                                                                  CFOA
# Adjustments to reconcile net income to net cash from operating activities:                            ARNI
# Changes in operating assets and liabilities, net of acquired assets and liabilities:                  COAL
# Changes in operating assets and liabilities net of effects from acquisitions of businesses:           COAL
# Adjustments to reconcile earnings (loss) from continuing operations to net cash provided by (used...  ARNI
# Adjustments to Reconcile Net Income to Net Cash Flows from Operating Activities:                      ARNI
# Operating Activities                                                                                  CFOA
# Adjustments to reconcile net income to net cash provided by operating activities:                     ARNI
# Cash used by investing activities:                                                                     CIA
# Changes in operating assets and liabilities, net of effects of acquisitions and divestitures:         COAL
# Changes in operating assets and liabilities net of effects from mergers and disposals of business:    COAL
# Cash flows from investing activities                                                                   CIA
# Adjustments to reconcile Net earnings (loss) to Net cash provided by operating activities:            ARNI
# Cash provided (used) by financing activities:                                                          CFA
# Adjustments to reconcile consoliated net income to net cash provided by operating activities:         ARNI
# Changes in operating assets and liabilities, net:                                                     COAL
# Changes in operating assets and liabilities, net of amounts acquired:                                 COAL
# Cash flows from financing activities from continuing operations:                                       CFA
# Investing                                                                                              CIA
# Operating                                                                                             CFOA
# Significant non-cash investing and financing activities:                                               CFA
# Adjustments to arrive at cash provided by operating activities                                        ARNI
# Adjustments to reconcile net income to cash provided by (used for) operating activities:              ARNI
# Cash Flows from Operating Activities:                                                                 CFOA
# Adjustments to reconcile net income including noncontrolling interests to net cash provided by op...  ARNI
# Cash Flows From Investing Activities                                                                   CIA
# CASH FLOWS FROM OPERATING ACTIVITIES:                                                                 CFOA
# Adjustments to reconcile income from continuing operations to net cash provided by operating acti...  ARNI
# Operating activities                                                                                  CFOA
# CASH FLOWS FROM INVESTING ACTIVITIES                                                                   CIA
# CASH PROVIDED BY / (USED IN) INVESTING ACTIVITIES                                                      CIA
# Adjustments to reconcile net earnings to net cash provided by (used in) operating activities          ARNI
# Operating Activities:                                                                                 CFOA
# Investing activities:                                                                                  CIA
# Changes in operating assets and liabilities net of effects from mergers of businesses:                COAL
# Adjustments to reconcile net earnings to total cash provided by operating activities                  ARNI
# OPERATING ACTIVITIES                                                                                  CFOA
# CASH PROVIDED BY / (USED IN) FINANCING ACTIVITIES                                                      CFA
# Adjustments to reconcile net income (loss) to net cash provided by (used in) operating activities:    ARNI
# Cash provided (used) by investing activities:                                                          CIA
# CASH FLOWS FROM INVESTING ACTIVITIES [Abstract]                                                        CIA
# Cash Flows From Investing Activities:                                                                  CIA
# Changes in operating assets and liabilities                                                           COAL
# Cash Flows From Operating Activities                                                                  CFOA
# Cash Flows from Financing Activities:                                                                  CFA
# Adjustments to reconcile net income to net cash provided by (used in) operating activities:           ARNI
# Non-cash investing activity:                                                                           CIA
# Non-cash investing and financing activities                                                            CFA
# Adjustments to reconcile Net earnings to Net cash provided by operating activities:                   ARNI
# Cash flows from financing activities:                                                                  CFA
# Financing Activities:                                                                                  CFA
# Adjustments to reconcile net loss to net cash flows from operating activities:                        ARNI
# Adjustments to reconcile net income to net cash flow from operating activities:                       ARNI
# INVESTING ACTIVITIES:                                                                                  CIA
# Cash flows from (used for) investing activities:                                                       CIA
# Adjustments to reconcile net loss to net cash used in operating activities:                           ARNI
# CASH FLOWS FROM FINANCING ACTIVITIES [Abstract]                                                        CFA
# Adjustments to reconcile net earnings (loss) to total cash provided by operating activities           ARNI
# Change in operating assets and liabilities, net of effects of acquisitions and divestitures:          COAL
# Adjustments to reconcile net income to net cash flows from operating activities:                      ARNI
# Adjustments to reconcile net earnings including noncontrolling interests to net cash provided by ...  ARNI
# CASH PROVIDED BY/(USED IN) OPERATING ACTIVITIES                                                       CFOA
# Net Cash Provided by (Used in) Operating Activities [Abstract]                                        CFOA
# Adjustments to reconcile net income to net cash flows from (used for) operating activities:           ARNI
# FINANCING ACTIVITIES                                                                                   CFA
# Cash Flows from Investing Activities:                                                                  CIA
# Cash Flows From Financing Activities                                                                   CFA
# Change in operating assets and liabilities:                                                           COAL
# FINANCING ACTIVITIES:                                                                                  CFA
# Adjustments to Reconcile Net Income to Net Cash Provided by Operating Activities [Abstract]           ARNI
# Cash used by financing activities:                                                                     CFA
# Financing                                                                                              CFA
# Financing Cash Flows                                                                                   CFA
# CASH PROVIDED BY/(USED IN) INVESTING ACTIVITIES                                                        CIA
# Adjustments to reconcile net earnings to operating cash flows:                                        ARNI
# Adjustments to reconcile net loss to net cash (used in) provided by operating activities:             ARNI
# Adjustments to reconcile net income to net cash generated from operating activities:                  ARNI
# Changes in operating assets and liabilities, excluding the effects of acquisitions:                   COAL
# OPERATING ACTIVITIES:                                                                                 CFOA
# Cash flows from investing activities from continuing operations:                                       CIA
# Adjustments to reconcile net income (loss) to net cash used in operating activities:                  ARNI
# Cash flows from financing activities                                                                   CFA
# INVESTING ACTIVITIES                                                                                   CIA
# CASH FLOWS FROM OPERATING ACTIVITIES [Abstract]                                                       CFOA
# Cash flow from investing activities:                                                                   CIA
# Non-cash investing and financing activities:                                                           CFA
# CASH PROVIDED BY/(USED IN) FINANCING ACTIVITIES                                                        CFA
# Cash Flows From Financing Activities:                                                                  CFA
# Adjustments to reconcile consolidated net income to net cash provided by operating activities:        ARNI
# Cash flows from operating activities                                                                  CFOA
# Non-cash investing activities:                                                                         CIA
# Cash flow from operating activities:                                                                  CFOA
# Investing Cash Flows                                                                                   CIA
# Cash Flows from Investing Activities                                                                   CIA
# Cash flow from financing activities:                                                                   CFA
# CASH FLOWS FROM OPERATING ACTIVITIES                                                                  CFOA
# Net Cash Provided by (Used in) Financing Activities [Abstract]                                         CFA
# Cash Flows From Operating Activities:                                                                 CFOA
# Adjustments to reconcile earnings (loss) from continuing operations to net cash provided by opera...  ARNI
# Adjustments to reconcile net income to total operating activities:                                    ARNI
# Cash flows from investing activities:                                                                  CIA
# Changes in operating assets and liabilities, net of acquisitions                                      COAL
# Net Cash Provided by (Used in) Investing Activities [Abstract]                                         CIA
# Changes in operating assets and liabilities, net of effects from acquisitions and dispositions:       COAL
# Cash flows used for investing activities:                                                              CIA
# Non-cash investing and financing transactions:                                                         CFA
# Adjustments to reconcile net income (loss) to net cash (used in) provided by operating activities:    ARNI
# Changes in operating assets and liabilities:                                                          COAL
# Adjustments to reconcile net earnings to total cash provided by operating activities:                 ARNI
# Investing activities                                                                                   CIA
# Changes in operating assets and liabilities, net of acquired assets and assumed liabilities:          COAL
# Adjustments to reconcile net earnings to net cash provided by operating activities:                   ARNI
# Adjustments to reconcile net earnings to operating cash flow                                          ARNI
# Adjustments to reconcile net loss to net cash provided by (used in) operating activities:             ARNI
# Cash (used) provided by investing activities:                                                          CIA
# Changes in operating assets and liabilities, net of acquisitions:                                     COAL
# Changes in operating accounts:                                                                        COAL
# Financing activities:                                                                                  CFA
# Adjustments to reconcile net income (loss) to net cash generated from (used in) operating activit...  ARNI
# Adjustments to reconcile net income (loss) to net cash provided by (used in) operating activities     ARNI
# Adjustments to reconcile consolidated net income to net cash flows from operating activities:         ARNI
# Changes in operating assets and liabilities (excluding effects of the acquisition of businesses):     COAL
# Cash flows from (used for) operating activities:                                                      CFOA
# Cash flows from operating activities from continuing operations:                                      CFOA
# Financing Activities                                                                                   CFA
# CASH FLOWS FROM FINANCING ACTIVITIES                                                                   CFA
# Changes in operating assets and liabilities, net of effect of business combinations:                  COAL
# Financing activities                                                                                   CFA
# Changes in operating assets and liabilities, net of acquisitions and dispositions                     COAL
# CASH FLOWS FROM FINANCING ACTIVITIES:                                                                  CFA
# Investing Activities:                                                                                  CIA
# Changes in operating assets and liabilities, net of effects from acquisitions:                        COAL
# Cash flows from (used for) financing activities:                                                       CFA
# CASH FLOWS FROM INVESTING ACTIVITIES:                                                                  CIA
# Adjustments to reconcile net income (loss) to net cash provided by operating activities:              ARNI

# %%
x = df.to_dict()
balance_heading_lookup = x['type']
balance_heading_lookup
# Out:
# {'Current liabilities [Abstract]': 'CL',
#  'Best Buy Co., Inc. Shareholders Equity': 'SE',
#  'Best Buy Co., Inc. Shareholders’ Equity': 'SE',
#  'CURRENT LIABILITIES': 'CL',
#  'Investments': 'SI',
#  'LIABILITIES AND EQUITY': 'SE',
#  "Oracle Corporation stockholders' equity:": 'SE',
#  'LONG-TERM DEBT': 'LD',
#  'Shareholders equity': 'SE',
#  'CURRENT ASSETS:': 'CA',
#  'SHAREHOLDERS’ EQUITY': 'SE',
#  'Equity': 'SE',
#  "STOCKHOLDER'S EQUITY": 'SE',
#  "Shareholders' equity:": 'SE',
#  "Stockholders' Equity": 'SE',
#  "Stockholders' equity": 'SE',
#  'Current Liabilities:': 'CL',
#  "SHAREHOLDERS' EQUITY": 'SE',
#  'Current Liabilities': 'CL',
#  'Biogen Inc. shareholders’ equity': 'SE',
#  'Property and Equipment': 'PE',
#  'Cisco shareholders’ equity:': 'SE',
#  'ASSETS': 'CA',
#  'PepsiCo Common Shareholders’ Equity': 'SE',
#  'Long-term debt due after one year:': 'LD',
#  'LIABILITIES AND SHAREHOLDERS EQUITY': 'SE',
#  "SHAREHOLDERS' EQUITY:": 'SE',
#  'Temporary Equity [Abstract]': 'SE',
#  'Property, Plant and Equipment': 'PE',
#  'Long-term debt due within one year:': 'LDY',
#  'Stockholders’ Equity': 'SE',
#  'Stockholders Equity': 'SE',
#  "Campbell Soup Company shareholders' equity": 'SE',
#  'COMMITMENTS AND CONTINGENT LIABILITIES': 'CL',
#  'Shareowners’ equity:': 'SE',
#  "Stockholders' equity:": 'SE',
#  'LIABILITIES': 'CL',
#  "SHAREOWNERS' EQUITY": 'SE',
#  "STOCKHOLDERS' EQUITY:": 'SE',
#  'Assets': 'CA',
#  'STOCKHOLDERS EQUITY:': 'SE',
#  'Commitments and contingent liabilities': 'CL',
#  'Shareholders’ Equity': 'SE',
#  'Short-term borrowings:': 'SB',
#  "Common shareholders' equity": 'SE',
#  'Property and equipment': 'PE',
#  'Common equity:': 'SE',
#  'Current assets': 'CA',
#  'Current Assets [Abstract]': 'CA',
#  'Assets, Current [Abstract]': 'CA',
#  'LIABILITIES AND STOCKHOLDERS’ EQUITY': 'SE',
#  'Current Assets:': 'CA',
#  'Investments:': 'SI',
#  'EQUITY': 'SE',
#  'Equity:': 'SE',
#  "LIABILITIES AND STOCKHOLDERS' EQUITY": 'SE',
#  "Shareholders' equity": 'SE',
#  'CURRENT LIABILITIES:': 'CL',
#  'Cisco stockholders’ equity:': 'SE',
#  "Juniper Networks stockholders' equity:": 'SE',
#  'Current liabilities:': 'CL',
#  'Stockholders equity:': 'SE',
#  'CURRENT ASSETS': 'CA',
#  'Shareholders’ equity:': 'SE',
#  'Shareholders Equity': 'SE',
#  'Stockholders’ equity:': 'SE',
#  'STOCKHOLDERS’ EQUITY:': 'SE',
#  'Property and equipment:': 'PE',
#  'Cisco shareholders equity:': 'SE',
#  'Current assets:': 'CA',
#  'Current Liabilities [Abstract]': 'CL',
#  'Property, Plant, and Equipment': 'PE',
#  'Shareholders equity:': 'SE',
#  'Liabilities': 'CL',
#  "Biogen Idec Inc. shareholders' equity": 'SE',
#  "Stockholders' Equity [Abstract]": 'SE',
#  'PROPERTY AND EQUIPMENT': 'PE',
#  "THE COCA-COLA COMPANY SHAREOWNERS' EQUITY": 'SE',
#  "Shareowners' equity:": 'SE',
#  'Shareholders’ equity': 'SE',
#  'Current Assets': 'CA',
#  'Equity [Abstract]': 'SE',
#  'Current liabilities': 'CL',
#  'Shareowners’ equity': 'SE',
#  "Molson Coors Beverage Company stockholders' equity": 'SE',
#  'LIABILITIES AND SHAREHOLDERS’ EQUITY': 'SE'}

# %% [markdown]
# # Create Lookup for Line Items

# %%
df = pd.read_csv('CSV/balance_map_line_items.csv')
df.set_index('line_item', inplace=True)
df
# Out:
#                                                                                                       type
# line_item
# Investment securities                                                                                    X
# Plant, property and equipment, net                                                                    NPPE
# Long-term debt due currently                                                                           LTD
# Property, plant and equipment, net of accumulated depreciation of $2,694.5 and $2,172.0, respecti...  NPPE
# Debt and capital lease obligations                                                                       D
# Total shareholders' investment                                                                         TSE
# Property, Plant and Equipment, Net                                                                    NPPE
# Property and equipment, gross                                                                         NPPE
# Cash and temporary cash investments                                                                     TC
# Total non-current liabilities                                                                         TNCL
# Property, net of accumulated depreciation                                                             NPPE
# Intangible assets, net                                                                                  IA
# Long-term Debt and Lease Obligation                                                                    LTD
# Long-term debt, net                                                                                    LTD
# Property and equipment, net                                                                           NPPE
# Total Liabilities, Temporary Equity, and Shareholders’ Equity                                         TLSE
# Total shareholders’ equity                                                                             TSE
# Property, plant and equipment — net                                                                   NPPE
# Gross property and equipment                                                                          NPPE
# TOTAL LIABILITIES AND SHAREHOLDERS’ EQUITY                                                            TLSE
# TOTAL LIABILITIES AND SHAREHOLDERS EQUITY                                                             TLSE
# Identifiable intangible assets, net                                                                     IA
# TOTAL CASH, CASH EQUIVALENTS AND SHORT-TERM INVESTMENTS                                                 TC
# Property and equipment                                                                                NPPE
# Property, plant and equipment, net of accumulated depreciation of $3,690.6 and $3,192.1, respecti...  NPPE
# Long-term debt                                                                                         LTD
# Property, net                                                                                         NPPE
# Property, plant and equipment and right of use assets, net                                            NPPE
# Property, plant, and equipment, net of accumulated depreciation and amortization of $10,383.8 and...  NPPE
# Indefinite-Lived Intangible Assets                                                                      IA
# Total Noncurrent Liabilities                                                                          TNCL
# Property under capital lease and financing obligations, net                                           NPPE
# Gross Property, Plant, and Equipment                                                                  NPPE
# TOTAL CURRENT LIABILITIES                                                                              TCL
# Amortizable Intangible Assets, net                                                                      IA
# Total shareholders' equity                                                                             TSE
# Total Long-Term Debt                                                                                   LTD
# Plant, property and equipment                                                                         NPPE
# Short-term Debt                                                                                        STD
# Property, plant and equipment, net of accumulated depreciation of $4,765.0 and $4,194.1, respecti...  NPPE
# Total Current Assets                                                                                   TCA
# TOTAL CURRENT ASSETS                                                                                   TCA
# Property, plant, and equipment, at cost, net of accumulated depreciation and amortization             NPPE
# Total Shareholders' Equity - The Kroger Co.                                                            TSE
# Total current assets                                                                                   TCA
# Total Assets                                                                                            TA
# Total current liabilities                                                                              TCL
# Current portion of long-term debt                                                                      LTD
# LONG-TERM DEBT, excluding current portion                                                              LTD
# Total liabilities and shareholders equity                                                             TLSE
# Current maturities of discharged long-term debt                                                        LTD
# Property, plant, and equipment, net of accumulated depreciation of $8,515.9 and $8,618.5, respect...  NPPE
# Long-Term Debt                                                                                         LTD
# Property, Plant and Equipment, net                                                                    NPPE
# Trade name intangible asset                                                                             IA
# Property under capital lease                                                                          NPPE
# Cash and cash equivalents, including short-term investments of $1,110 and $3,008                        TC
# Cash and short-term investments                                                                         TC
# Long-term debt, excluding current portion                                                              LTD
# Total Cash, Cash Equivalents and Short-Term Investments                                                 TC
# Property, plant and equipment, net                                                                    NPPE
# Total Shareholders Equity                                                                              TSE
# Segregated cash and investments                                                                         TC
# Total shareholders equity                                                                              TSE
# TOTAL ASSETS                                                                                            TA
# Total Liabilities and Shareholders Equity                                                             TLSE
# Total Shareholders’ Equity                                                                             TSE
# Indefinite-lived Intangible Assets                                                                      IA
# Total Shareholders’ Equity - The Kroger Co.                                                            TSE
# Property, plant and equipment, net of accumulated depreciation of $6,025.4 and $5,363.8, respecti...  NPPE
# Tradename intangible asset                                                                              IA
# Long-term debt, less current portion                                                                   LTD
# Goodwill and intangible assets, net                                                                     IA
# Property, plant and equipment, net of accumulated depreciation of $23,075 and $18,077, respectively   NPPE
# Cashandcashequivalents                                                                                  TC
# Total liabilities                                                                                       TL
# Property, plant and equipment                                                                         NPPE
# Short-term debt                                                                                        STD
# Debt, Current                                                                                            D
# Property, plant, and equipment, net of accumulated depreciation and amortization of $9,364.7 and ...  NPPE
# Total liabilities and shareholders' investment                                                        TLSE
# Long-term debt, net, excluding current portion                                                         LTD
# Current maturities of long-term debt                                                                   LTD
# Purchased intangible assets, net                                                                        IA
# Property, plant and equipment - net                                                                   NPPE
# Total liabilities and shareholders' equity                                                            TLSE
# Property, plant and equipment, net of accumulated depreciation of $31,639 and $27,656, respectively   NPPE
# Cash and cash equivalents, including short-term investments of $1,520 and $3                            TC
# Intangibles, net                                                                                        IA
# PROPERTY, PLANT AND EQUIPMENT                                                                         NPPE
# Long-term Debt and Lease Obligation, Current                                                           LTD
# Long-Term Debt Obligations                                                                             LTD
# TOTAL LIABILITIES                                                                                       TL
# TOTAL LIABILITIES AND SHAREHOLDERS' EQUITY                                                            TLSE
# Total non-current assets                                                                              TNCA
# Total noncurrent assets                                                                               TNCA
# Current portion long-term debt                                                                         LTD
# Total noncurrent liabilities                                                                          TNCL
# Long-term Debt, net                                                                                    LTD
# Total assets                                                                                            TA
# Total Noncurrent Assets                                                                               TNCA
# LONG-TERM DEBT                                                                                         LTD
# Debt                                                                                                     D
# Total cash and cash equivalents                                                                         TC
# Property under capital lease and financing obligations                                                NPPE
# Property, plant and equipment, net of accumulated depreciation of $5,484 and $4,787, respectively     NPPE
# PROPERTY, PLANT AND EQUIPMENT - net                                                                   NPPE
# Cash and Cash Equivalents                                                                               TC
# Total Liabilities                                                                                       TL
# Nonamortizable Intangible Assets                                                                        IA
# Net Property, Plant and Equipment                                                                     NPPE
# Short-term debt obligations                                                                            STD
# Property, plant, and equipment, net                                                                   NPPE
# Debt and capital lease obligations, current                                                              D
# Intangibles, Net                                                                                        IA
# Total Current Liabilities                                                                              TCL
# Net Property, Plant, and Equipment                                                                    NPPE
# Property and Equipment, net                                                                           NPPE
# Cash and equivalents                                                                                    TC
# Intangible assets                                                                                       IA
# Property, plant and equipment, net of accumulated depreciation of $11,103 and $6,518, respectively    NPPE
# Cash and cash equivalents                                                                               TC
# Property, plant, and equipment, net of accumulated depreciation of $8,214.6 and $7,919.1, respect...  NPPE
# Net property and equipment                                                                            NPPE
# Acquisition-related intangible assets, net                                                              IA
# Total liabilities and shareholders’ equity                                                            TLSE
# Property, plant and equipment, net of accumulated depreciation of $36,164 and $34,253, respectively   NPPE

# %%
x = df.to_dict()
balance_line_item_lookup = x['type']
balance_line_item_lookup
# Out:
# {'Investment securities': 'X',
#  'Plant, property and equipment, net': 'NPPE',
#  'Long-term debt due currently': 'LTD',
#  'Property, plant and equipment, net of accumulated depreciation of $2,694.5 and $2,172.0, respectively': 'NPPE',
#  'Debt and capital lease obligations': 'D',
#  "Total shareholders' investment": 'TSE',
#  'Property, Plant and Equipment, Net': 'NPPE',
#  'Property and equipment, gross': 'NPPE',
#  'Cash and temporary cash investments': 'TC',
#  'Total non-current liabilities': 'TNCL',
#  'Property, net of accumulated depreciation': 'NPPE',
#  'Intangible assets, net': 'IA',
#  'Long-term Debt and Lease Obligation': 'LTD',
#  'Long-term debt, net': 'LTD',
#  'Property and equipment, net': 'NPPE',
#  'Total Liabilities, Temporary Equity, and Shareholders’ Equity': 'TLSE',
#  'Total shareholders’ equity': 'TSE',
#  'Property, plant and equipment — net': 'NPPE',
#  'Gross property and equipment': 'NPPE',
#  'TOTAL LIABILITIES AND SHAREHOLDERS’ EQUITY': 'TLSE',
#  'TOTAL LIABILITIES AND SHAREHOLDERS EQUITY': 'TLSE',
#  'Identifiable intangible assets, net': 'IA',
#  'TOTAL CASH, CASH EQUIVALENTS AND SHORT-TERM INVESTMENTS': 'TC',
#  'Property and equipment': 'NPPE',
#  'Property, plant and equipment, net of accumulated depreciation of $3,690.6 and $3,192.1, respectively': 'NPPE',
#  'Long-term debt': 'LTD',
#  'Property, net': 'NPPE',
#  'Property, plant and equipment and right of use assets, net': 'NPPE',
#  'Property, plant, and equipment, net of accumulated depreciation and amortization of $10,383.8 and $9,889.3, respectively': 'NPPE',
#  'Indefinite-Lived Intangible Assets': 'IA',
#  'Total Noncurrent Liabilities': 'TNCL',
#  'Property under capital lease and financing obligations, net': 'NPPE',
#  'Gross Property, Plant, and Equipment': 'NPPE',
#  'TOTAL CURRENT LIABILITIES': 'TCL',
#  'Amortizable Intangible Assets, net': 'IA',
#  "Total shareholders' equity": 'TSE',
#  'Total Long-Term Debt': 'LTD',
#  'Plant, property and equipment': 'NPPE',
#  'Short-term Debt': 'STD',
#  'Property, plant and equipment, net of accumulated depreciation of $4,765.0 and $4,194.1, respectively': 'NPPE',
#  'Total Current Assets': 'TCA',
#  'TOTAL CURRENT ASSETS': 'TCA',
#  'Property, plant, and equipment, at cost, net of accumulated depreciation and amortization': 'NPPE',
#  "Total Shareholders' Equity - The Kroger Co.": 'TSE',
#  'Total current assets': 'TCA',
#  'Total Assets': 'TA',
#  'Total current liabilities': 'TCL',
#  'Current portion of long-term debt': 'LTD',
#  'LONG-TERM DEBT, excluding current portion': 'LTD',
#  'Total liabilities and shareholders equity': 'TLSE',
#  'Current maturities of discharged long-term debt': 'LTD',
#  'Property, plant, and equipment, net of accumulated depreciation of $8,515.9 and $8,618.5, respectively': 'NPPE',
#  'Long-Term Debt': 'LTD',
#  'Property, Plant and Equipment, net': 'NPPE',
#  'Trade name intangible asset': 'IA',
#  'Property under capital lease': 'NPPE',
#  'Cash and cash equivalents, including short-term investments of $1,110 and $3,008': 'TC',
#  'Cash and short-term investments': 'TC',
#  'Long-term debt, excluding current portion': 'LTD',
#  'Total Cash, Cash Equivalents and Short-Term Investments': 'TC',
#  'Property, plant and equipment, net': 'NPPE',
#  'Total Shareholders Equity': 'TSE',
#  'Segregated cash and investments': 'TC',
#  'Total shareholders equity': 'TSE',
#  'TOTAL ASSETS': 'TA',
#  'Total Liabilities and Shareholders Equity': 'TLSE',
#  'Total Shareholders’ Equity': 'TSE',
#  'Indefinite-lived Intangible Assets': 'IA',
#  'Total Shareholders’ Equity - The Kroger Co.': 'TSE',
#  'Property, plant and equipment, net of accumulated depreciation of $6,025.4 and $5,363.8, respectively': 'NPPE',
#  'Tradename intangible asset': 'IA',
#  'Long-term debt, less current portion': 'LTD',
#  'Goodwill and intangible assets, net': 'IA',
#  'Property, plant and equipment, net of accumulated depreciation of $23,075 and $18,077, respectively': 'NPPE',
#  'Cashandcashequivalents': 'TC',
#  'Total liabilities': 'TL',
#  'Property, plant and equipment': 'NPPE',
#  'Short-term debt': 'STD',
#  'Debt, Current': 'D',
#  'Property, plant, and equipment, net of accumulated depreciation and amortization of $9,364.7 and $8,878.7, respectively': 'NPPE',
#  "Total liabilities and shareholders' investment": 'TLSE',
#  'Long-term debt, net, excluding current portion': 'LTD',
#  'Current maturities of long-term debt': 'LTD',
#  'Purchased intangible assets, net': 'IA',
#  'Property, plant and equipment - net': 'NPPE',
#  "Total liabilities and shareholders' equity": 'TLSE',
#  'Property, plant and equipment, net of accumulated depreciation of $31,639 and $27,656, respectively': 'NPPE',
#  'Cash and cash equivalents, including short-term investments of $1,520 and $3': 'TC',
#  'Intangibles, net': 'IA',
#  'PROPERTY, PLANT AND EQUIPMENT': 'NPPE',
#  'Long-term Debt and Lease Obligation, Current': 'LTD',
#  'Long-Term Debt Obligations': 'LTD',
#  'TOTAL LIABILITIES': 'TL',
#  "TOTAL LIABILITIES AND SHAREHOLDERS' EQUITY": 'TLSE',
#  'Total non-current assets': 'TNCA',
#  'Total noncurrent assets': 'TNCA',
#  'Current portion long-term debt': 'LTD',
#  'Total noncurrent liabilities': 'TNCL',
#  'Long-term Debt, net': 'LTD',
#  'Total assets': 'TA',
#  'Total Noncurrent Assets': 'TNCA',
#  'LONG-TERM DEBT': 'LTD',
#  'Debt': 'D',
#  'Total cash and cash equivalents': 'TC',
#  'Property under capital lease and financing obligations': 'NPPE',
#  'Property, plant and equipment, net of accumulated depreciation of $5,484 and $4,787, respectively': 'NPPE',
#  'PROPERTY, PLANT AND EQUIPMENT - net': 'NPPE',
#  'Cash and Cash Equivalents': 'TC',
#  'Total Liabilities': 'TL',
#  'Nonamortizable Intangible Assets': 'IA',
#  'Net Property, Plant and Equipment': 'NPPE',
#  'Short-term debt obligations': 'STD',
#  'Property, plant, and equipment, net': 'NPPE',
#  'Debt and capital lease obligations, current': 'D',
#  'Intangibles, Net': 'IA',
#  'Total Current Liabilities': 'TCL',
#  'Net Property, Plant, and Equipment': 'NPPE',
#  'Property and Equipment, net': 'NPPE',
#  'Cash and equivalents': 'TC',
#  'Intangible assets': 'IA',
#  'Property, plant and equipment, net of accumulated depreciation of $11,103 and $6,518, respectively': 'NPPE',
#  'Cash and cash equivalents': 'TC',
#  'Property, plant, and equipment, net of accumulated depreciation of $8,214.6 and $7,919.1, respectively': 'NPPE',
#  'Net property and equipment': 'NPPE',
#  'Acquisition-related intangible assets, net': 'IA',
#  'Total liabilities and shareholders’ equity': 'TLSE',
#  'Property, plant and equipment, net of accumulated depreciation of $36,164 and $34,253, respectively': 'NPPE'}

# %% [markdown]
# # Combine Lookups for heading and line items into one dictionary and save

# %%
balance_lookup = {'heading': balance_heading_lookup,
                  'line_item' : balance_line_item_lookup}

# %%
# Save to file

with open('pickle/balance_map_lookup.pkl', 'wb') as fp:
  pickle.dump(balance_lookup, fp)
