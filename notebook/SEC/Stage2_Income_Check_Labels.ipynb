# %%
import numpy as np
import pandas as pd
import time
import os
import pickle
import re

# %%
pd.set_option('display.max_rows', 700)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 200)
pd.options.display.float_format = '{:.2f}'.format

# %%
DATA_ROOT_PATH="/mnt/data/projects/MD1/data/R1000/reports/"
PROJ_ROOT_PATH="/home/priyesh/projects/MD1"

# %%
# Read from Pickle file

filepath = os.path.join(PROJ_ROOT_PATH,'pickle','clean_master_data_interim.pkl')
clean_master_data = pd.read_pickle(filepath)

# %%
def get_line_items(t):
 
  headings = []
  line_items = []
    
  for index, row in t.iterrows():
    
    if row.replace('', np.nan).isna().all():
      # Blank row, so assume heading
    
      headings.append(index)
    else:    
      line_items.append(index)

  return headings, line_items

# %%
def get_table_labels(stype):

  master_headings = []
  master_line_items = []

  ticker_list = list(clean_master_data.keys())

  for ticker in ticker_list:
    
    print(ticker)
    
    for yr in clean_master_data[ticker]:
      
      # Allow for the likelihood that statement might be missing for given ticker and yr
        
      if stype in clean_master_data[ticker][yr]:
        try:
          headings, line_items = get_line_items(clean_master_data[ticker][yr][stype]['table'])
    
          master_headings = master_headings + headings
          master_line_items = master_line_items + line_items
        except:
          print("Error : {} {}".format(ticker, yr))
          exit() 

  # Remove duplicates from headings and line items

  unique_list = set(master_headings)
  headings = list(unique_list)

  unique_list = set(master_line_items)
  line_items = list(unique_list)

  return {'headings' : headings,
          'line_items' : line_items}

# %%
table_labels = get_table_labels('income')
# Out:
# AAL
# AAP
# AAPL
# ABBV
# ABT
# ACGL
# ACHC
# ACM
# ACN
# ADBE
# ADI
# ADM
# ADP
# ADSK
# AEE
# AEP
# AES
# AFG
# AFL
# AGCO
# AGNC
# AGO
# AGR
# AIG
# AIZ
# AJG
# AKAM
# AL
# ALB
# ALGN
# ALK
# ALL
# ALLE
# ALLY
# ALNY
# ALSN
# AMAT
# AMC
# AMD
# AME
# AMED
# AMG
# AMGN
# AMH
# AMP
# AMT
# AMZN
# AN
# ANET
# ANSS
# AON
# AOS
# APD
# APH
# APTV
# AR
# ARE
# ARES
# ARMK
# ARW
# ATO
# ATR
# ATVI
# AVB
# AVT
# AWI
# AWK
# AXS
# AXTA
# AYI
# AZO
# BA
# BAC
# BAH
# BALL
# BAX
# BBY
# BC
# BDX
# BEN
# BERY
# BFAM
# BG
# BIIB
# BIO
# BK
# BKI
# BKNG
# BLD
# BLDR
# BLK
# BMRN
# BMY
# BOKF
# BR
# BRKR
# BRO
# BRX
# BSX
# BURL
# BWA
# BWXT
# BX
# BXP
# BYD
# C
# CABO
# CACC
# CACI
# CAG
# CAH
# CAR
# CASY
# CAT
# CB
# CBOE
# CBRE
# CBSH
# CC
# CCI
# CCK
# CCL
# CDNS
# CDW
# CE
# CF
# CFG
# CFR
# CG
# CGNX
# CHD
# CHDN
# CHE
# CHH
# CHK
# CHRW
# CHTR
# CIEN
# CINF
# CL
# CLH
# CLX
# CMA
# CMCSA
# CME
# CMG
# CMI
# CMS
# CNA
# CNC
# CNP
# COF
# COLB
# COLM
# COO
# MMM
# MNST
# MO
# MOH
# MORN
# MOS
# MPC
# MPW
# MPWR
# MRCY
# MRK
# MRO
# MRTX
# MS
# MSA
# MSCI
# MSFT
# MSI
# MSM
# MTB
# MTCH
# MTD
# MTG
# MTN
# MTZ
# MU
# NATI
# NBIX
# NCLH
# NCR
# NDAQ
# NDSN
# NEE
# NEM
# NEU
# NEWR
# NFG
# NFLX
# NI
# NKE
# NLY
# NNN
# NOC
# NOV
# NOW
# NRG
# NSA
# NSC
# NTAP
# NTRA
# NTRS
# NUE
# NVAX
# NVDA
# NVR
# NWL
# NWS
# NWSA
# NXST
# NYCB
# NYT
# O
# OC
# ODFL
# OGE
# OHI
# OKE
# OLED
# OLLI
# OLN
# OMC
# OMF
# ON
# ORCL
# ORI
# ORLY
# OSK
# OXY
# PACW
# PAG
# PANW
# PAYC
# PAYX
# PB
# PCAR
# PCG
# PCTY
# PDCE
# PEAK
# PEG
# PEGA
# PEN
# PENN
# PEP
# PFE
# PFG
# PG
# PGR
# PH
# PHM
# PII
# PINC
# PKG
# PKI
# PLD
# PLNT
# PLUG
# PM
# PNC
# PNFP
# PNR
# PNW
# PODD
# POOL
# POST
# PPC
# PPG
# PPL
# PRGO
# PRI
# PRU
# PSA
# PSTG
# PSX
# PTC
# PVH
# PWR
# PXD
# PYPL
# QCOM
# QRVO
# RARE
# RE
# REG
# REGN
# REXR
# RF
# RGA
# RGEN
# RH
# RJF
# RL
# RMD
# RNG
# RNR
# RRC
# RS
# RSG
# RTX
# RUN
# RYN
# SAM
# SBUX
# SCCO
# SCHW
# SCI
# SEB
# SEE
# SEIC
# SF
# SGEN
# SHW
# SIRI
# SIX
# SJM
# SKX
# SLB
# SLG
# SLGN
# SMG
# SNA
# SNPS
# SNV
# SNX
# SO
# SON
# SPB
# SPG
# SPLK
# SPR
# SQ
# SRC
# SRCL
# SRE
# SSNC
# ST
# STLD
# STT
# STWD
# STZ
# SUI
# SWK
# SWKS
# SWN
# SYF
# SYK
# SYNH
# SYY
# T
# TAP
# TDC
# TDG
# TDOC
# TDY
# TECH
# TER
# TFC
# TFSL
# TFX
# TGT
# THC
# THG
# THO
# TJX
# TKR
# TMO
# TMUS
# TNDM
# TOL
# TPR
# TPX
# TREX
# TRGP
# TRIP
# TRMB
# TROW
# TRU
# TRV
# TSCO
# TSLA
# TSN
# TT
# TTC
# TTEK
# TTWO
# TXN
# TXT
# TYL
# UA
# UAA
# UAL
# UDR
# UGI
# UHAL
# UHS
# UI
# ULTA
# UNH
# UNM
# UNP
# UNVR
# UPS
# URI
# USB
# UTHR
# V
# VAC
# VEEV
# VFC
# VIRT
# VLO
# VMC
# VMI
# VMW
# VNO
# VOYA
# VRSK
# VRSN
# VRTX
# VSAT
# VTR
# VZ
# W
# WAB
# WAL
# WAT
# WBA
# WBS
# WCC
# WDAY
# WDC
# WEC
# WELL
# WEN
# WEX
# WFC
# WHR
# WLK
# WM
# WMB
# WMT
# WPC
# WRB
# WSC
# WSM
# WSO
# WST
# WTFC
# WTM
# WTRG
# WU
# WWD
# WWE
# WY
# WYNN
# X
# XEL
# XOM
# XPO
# XRAY
# XYL
# YUM
# Z
# ZBRA
# ZG

# %%
all_table_labels = table_labels['headings'] + table_labels['line_items']
df = pd.DataFrame(all_table_labels,columns=['line_item'])

# %% [markdown]
# ### Net Sales

# %%
mask = df['line_item'].str.contains(r"^Net Sales",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Related Part",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Passenger|Hardware|Software|Excl|Less",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Service|Estate|Customer|Cons|Gross",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Multi|Fee|Interest|Dividend|Oper",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Cloud|Subs|Maint|Util|Lease|Prod",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Insur|Rent|Office|Home|Comm|non",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Automotive|Cost|Property|Broker|Ext",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Other|Deferred|Recur|Member|Gas",case=True, regex=True, na=False)
         
df[mask].reset_index()
# Out:
#    index                                            line_item
# 0   1114                                           Net Sales:
# 1   3738                                Net Sales And Revenue
# 2   4079                                            Net Sales
# 3   8501                                            Net Sales
# 4   9393                                       Net Sales Note
# 5  16277                               Net Sales And Revenues
# 6  20641  Net Sales Including Special Charges Of 29.6 In 2011

# %%
mask = df['line_item'].str.contains(r"^Net Sales",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Related Part",case=True, regex=True, na=False) & \
          df['line_item'].str.contains(r"Including",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Passenger|Hardware|Software|Excl|Less",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Service|Estate|Customer|Cons|Gross",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Multi|Fee|Interest|Dividend|Oper",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Cloud|Subs|Maint|Util|Lease|Prod",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Insur|Rent|Office|Home|Comm|non",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Automotive|Cost|Property|Broker|Ext",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Other|Deferred|Recur|Member|Gas",case=True, regex=True, na=False)
         
df[mask].reset_index()
# Out:
#    index  \
# 0   9423
# 1  11339
# 2  16592
# 3  18034
# 4  20519
#
#                                                                                              line_item
# 0  Net Sales Including Sales To Related Parties Of 23.5 Million, 68.8 Million And 43.5 Million, In ...
# 1                                            Net Sales Including Sales To Related Parties, See Note 17
# 2                                            Net Sales Including Sales To Related Parties, See Note 18
# 3             Net Sales Including Related Party Sales Of 68.8 Million In 2011 And 43.5 Million In 2010
# 4                                            Net Sales Including Sales To Related Parties, See Note 16

# %% [markdown]
# ### Revenue

# %%
mask = df['line_item'].str.contains(r"Revenues",case=True, regex=True, na=False) & \
          df['line_item'].str.contains(r"Including",case=True, regex=True, na=False) & \
          df['line_item'].str.contains(r"Related Parties",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Other",case=True, regex=True, na=False) 

df[mask].reset_index()
# Out:
#    index  \
# 0   5371
# 1  12285
# 2  14874
# 3  15747
#
#                                                                                              line_item
# 0                Revenues Including Amounts From Related Parties Of 0, 13,882 And 49,788, Respectively
# 1                          Revenues Including Amounts From Related Parties Of 13,882, In 2011, Note 19
# 2  Revenues Including Excise Taxes Includes 8,269 In 2022, 7,822 In 2021 And 7,572 In 2020 From Rel...
# 3  Revenues Including Amounts From Related Parties Of 13,882, 49,788 And 60,192 For The Years Ended...

# %% [markdown]
# ### Total Revenue

# %%
mask = df['line_item'].str.contains(r"Revenue",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Total",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Passenger|Hardware|Software|Excl|Less",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Service|Estate|Customer|Cons|Gross",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Multi|Fee|Interest|Dividend|Oper",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Cloud|Subs|Maint|Util|Lease|Net",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Insur|Rent|Office|Home|Comm|non",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Automotive|Cost|Property|Broker|Sales",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Other|Deferred|Recur|Member|Gas",case=True, regex=True, na=False)
         
df[mask].reset_index()
# Out:
#    index            line_item
# 0    213       Total Revenues
# 1   1110        Total Revenue
# 2   8980       Total Revenues
# 3   9058  Total Revenues Note
# 4  17504   Total Revenue Note
# 5  17725      Revenues, Total
# 6  18898        Total Revenue
# 7  21502       Revenue, Total

# %% [markdown]
# ### Total Net Revenue

# %%
mask = df['line_item'].str.contains(r"Revenue",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Total",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Net",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Passenger|Hardware|Software|Excl|Less",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Service|Estate|Customer|Cons|Gross",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Multi|Fee|Interest|Dividend|Oper",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Cloud|Subs|Maint|Util|Lease|Sales",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Insur|Rent|Office|Home|Comm|non",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Automotive|Cost|Property|Broker",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Other|Deferred|Recur|Member|Gas",case=True, regex=True, na=False)
         
df[mask].reset_index()
# Out:
#    index               line_item
# 0   7522  Total Net Revenue Loss
# 1  10474     Total Revenues, Net
# 2  15110       Total Net Revenue
# 3  16020      Total Revenue, Net
# 4  22095      Total Net Revenues

# %%
mask = df['line_item'].str.contains(r"Revenue",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Total",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Net",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Sales",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Passenger|Hardware|Software|Excl|Less",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Service|Estate|Customer|Cons|Gross",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Multi|Fee|Interest|Dividend|Oper",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Cloud|Subs|Maint|Util|Lease",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Insur|Rent|Office|Home|Comm|non",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Automotive|Cost|Property|Broker",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Other|Deferred|Recur|Member|Gas",case=True, regex=True, na=False)
         
df[mask].reset_index()
# Out:
#    index                         line_item
# 0  10186       Total Net Sales And Revenue
# 1  19976  Total Net Sales And Revenue Note

# %%
mask = df['line_item'].str.contains(r"Revenue",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Net",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Includes",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Total",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Passenger|Hardware|Software|Excl|Less",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Service|Estate|Customer|Cons|Gross",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Multi|Fee|Interest|Dividend|Oper",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Cloud|Subs|Maint|Util|Lease",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Insur|Rent|Office|Home|Comm|non",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Automotive|Cost|Property|Broker",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Other|Deferred|Recur|Member|Gas",case=True, regex=True, na=False)
         
df[mask].reset_index()
# Out:
#    index  \
# 0  11209
#
#                                                                                    line_item
# 0  Net Revenues Includes 3,658 In 2022, 3,330 In 2021 And 3,233 In 2020 From Related Parties

# %% [markdown]
# ### Total Operating Revenue

# %%
mask = df['line_item'].str.contains(r"Revenue",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Total",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Oper",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Passenger|Hardware|Software|Excl|Less",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Multi|Fee|Interest|Dividend|Non",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Automotive|Cost|Property|Broker",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Other|Deferred|Recur|Member|Gas|Util",case=True, regex=True, na=False)
         
df[mask].reset_index()
# Out:
#    index                 line_item
# 0   2332  Total Operating Revenues
# 1  12868   Total Operating Revenue
# 2  15694  Total Operating Revenues

# %% [markdown]
# ### Total Cost of Revenue

# %%
mask = df['line_item'].str.contains(r"Revenue",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Total",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Cost",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Passenger|Hardware|Software",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Excl|Recurr",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Service|Estate|Customer",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Multi|Fee|Interest|Dividend",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Cloud|Subs|Maint|Util|Lease",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Insur|Rent|Office|Home|Comm|non",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Automotive|Property|Broker",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Other|Deferred",case=False, regex=True, na=False)
         
df[mask].reset_index()
# Out:
#    index                line_item
# 0   8643    Total Cost Of Revenue
# 1  10950   Total Cost Of Revenues
# 2  12650   Total Costs Of Revenue
# 3  16508  Total Costs Of Revenues

# %% [markdown]
# ### Cost of Revenue

# %%
mask = df['line_item'].str.contains(r"Revenue",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"^Cost",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Total|Dep|Prod|Lic|Sup|Con|Bio",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Party|Related|Less|Rest|Land",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Passenger|Hardware|Software",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Service|Estate|Customer|Form",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Royal|Coal|Excl|Sales|Net",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Multi|Fee|Interest|Dividend",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Cloud|Subs|Maint|Util|Lease|Reimb",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Insur|Rent|Office|Home|Comm|non",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Automotive|Property|Broker",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Other|Deferred|Member|Abstract",case=False, regex=True, na=False)
         
df[mask].reset_index()
# Out:
#     index           line_item
# 0    1477     Cost Of Revenue
# 1    1657   Cost Of Revenues:
# 2    2036  Costs Of Revenues:
# 3    2050    Cost Of Revenue:
# 4    2551    Cost Of Revenues
# 5    2697   Costs Of Revenue:
# 6    5783     Cost Of Revenue
# 7   10544   Cost Of Revenues:
# 8   15910    Cost Of Revenues
# 9   18094    Cost Of Revenue.
# 10  19869    Cost Of Revenue:
# 11  20897    Costs Of Revenue
# 12  21108   Costs Of Revenues

# %%
mask = df['line_item'].str.contains(r"Revenue",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"^Cost",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Including",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Amort",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Impair",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Definite",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Other|Deferred|Member|Abstract",case=True, regex=True, na=False)
         
df[mask].reset_index()
# Out:
#    index  \
# 0   6507
# 1   9079
# 2  13303
#
#                                                                                              line_item
# 0  Cost Of Revenues Including Amortization And Impairments Of Feature Film Production Assets Of 39,...
# 1  Cost Of Revenues Including Amortization And Impairments Of Feature Film And Television Productio...
# 2  Cost Of Revenues Including Amortization And Impairments Of Feature Film Production Assets Of 8,7...

# %%
mask = df['line_item'].str.contains(r"Revenue",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"^Cost",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Excluding|Exclusive",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Amort",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Definite|Dep|Intang",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Other|Deferred|Member|Abstract",case=True, regex=True, na=False)
         
df[mask].reset_index()
# Out:
#    index                                               line_item
# 0   1220              Cost Of Revenue Exclusive Of Amortization:
# 1   2009               Cost Of Revenue Exclusive Of Amortization
# 2  12002  Cost Of Revenues Exclusive Of Amortization Shown Below
# 3  15358               Cost Of Revenue Exclusive Of Amortization
# 4  18229   Cost Of Revenue Exclusive Of Amortization Shown Below

# %%
mask = df['line_item'].str.contains(r"Revenue",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"^Cost",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Excluding|Exclusive",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Amort",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Depr",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Definite|Intang",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Other|Deferred|Member|Abstract",case=True, regex=True, na=False)
         
df[mask].reset_index()
# Out:
#    index  \
# 0   5600
# 1   5929
# 2   7773
# 3  10737
# 4  11219
# 5  12032
# 6  14703
# 7  16995
# 8  21226
#
#                                                                                      line_item
# 0                                    Costs Of Revenue, Excluding Depreciation And Amortization
# 1            Cost Of Revenue Exclusive Of Depreciation And Amortization Shown Separately Below
# 2                                  Cost Of Revenues Exclusive Of Depreciation And Amortization
# 3  Cost Of Revenue Exclusive Of Depreciation And Amortization, Which Is Shown Separately Below
# 4   Cost Of Revenues Exclusive Of Depreciation And Amortization Expense Shown Separately Below
# 5         Cost Of Revenue Exclusive Of Depreciation And Amortization As Shown Separately Below
# 6                                      Cost Of Revenue Excluding Depreciation And Amortization
# 7                                 Costs Of Revenue, Exclusive Of Depreciation And Amortization
# 8                                 Cost Of Revenues, Exclusive Of Depreciation And Amortization

# %%
mask = df['line_item'].str.contains(r"Cost Of Sales",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Total",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Part|Serv|Prod|Unit|Comm|^Dep",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Software|Chem|Mids|Auto",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Excl|Incl|Res|Rev|Online|Fuel",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Occ|Member|Ext|Energy|Type",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Other|Man|Oper|Sub|Food|Bev",case=False, regex=True, na=False)
         
df[mask].reset_index()
# Out:
#    index        line_item
# 0   1581   Cost Of Sales:
# 1   4301    Cost Of Sales
# 2  11913  Cost Of Sales-A
# 3  17679    Cost Of Sales
# 4  18124  Cost Of Sales A

# %%
mask = df['line_item'].str.contains(r"Cost Of Sales",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Excl",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Dep",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Total",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Part|Serv|Prod|Unit|Comm|^Dep",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Software|Chem|Mids|Auto",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Res|Rev|Online|Fuel",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Occ|Member|Ext|Energy|Type",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Other|Man|Oper|Sub|Food|Bev",case=False, regex=True, na=False)
         
df[mask].reset_index()
# Out:
#     index  \
# 0    1180
# 1    5837
# 2    5996
# 3    6584
# 4    6878
# 5    8041
# 6    8198
# 7   13451
# 8   13697
# 9   14137
# 10  14936
# 11  14970
# 12  17233
# 13  18326
# 14  18731
# 15  19620
# 16  20388
#
#                                                                                               line_item
# 0                                                     Cost Of Sales Excluding Depreciation Shown Below:
# 1                  Cost Of Sales Excluding Depreciation And Amortization Expense Shown Separately Below
# 2   Cost Of Sales Excludes Depreciation, Depletion And Amortization Of 3,584 In 2011, 3,145 In 2010 ...
# 3   Cost Of Sales Excludes Depreciation, Depletion, And Amortization Of 4,000 In 2017, 4,266 In 2016...
# 4                                             Cost Of Sales, Exclusive Of Depreciation And Amortization
# 5   Cost Of Sales Excludes Depreciation, Depletion And Amortization Of 5,341 In 2013, 4,504 In 2012 ...
# 6                                                   Cost Of Sales Exclusive Of Depreciation Shown Below
# 7                                                                 Cost Of Sales, Excluding Depreciation
# 8                                                      Cost Of Sales Excluding Depreciation Shown Below
# 9   Cost Of Sales Excludes Depreciation, Depletion, And Amortization Of 3,976 In 2018, 4,000 In 2017...
# 10           Cost Of Sales Exclusive Of Depreciation, Amortization And Depletion Shown Separately Below
# 11  Cost Of Sales Excludes Depreciation, Depletion, And Amortization Of 4,540 In 2015, 4,257 In 2014...
# 12                                                Cost Of Sales Excluding Depreciation And Amortization
# 13  Cost Of Sales Excludes Depreciation, Depletion And Amortization Of 4,504 In 2012, 3,584 In 2011 ...
# 14                                 Cost Of Sales Exclusive Of Depreciation And Amortization Shown Below
# 15  Cost Of Sales Excludes Depreciation, Depletion, And Amortization Of 4,266 In 2016, 4,540 In 2015...
# 16                                    Cost Of Sales Excluding Depreciation And Amortization Shown Below

# %% [markdown]
# ### Total Cost of Revenue

# %%
mask = df['line_item'].str.contains(r"Cost Of Sales",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Total",case=False, regex=True, na=False) & \
         ~df['line_item'].str.contains(r"Veh|Other|Oper|Excl",case=True, regex=True, na=False)
df[mask].reset_index()
# Out:
#    index            line_item
# 0   3341  Total Cost Of Sales
# 1   7691  Total Cost Of Sales

# %%
mask = df['line_item'].str.contains(r"Cost Of Sales",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Total",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Excl",case=False, regex=True, na=False) & \
         ~df['line_item'].str.contains(r"Veh|Other|Oper",case=True, regex=True, na=False)
df[mask].reset_index()
# Out:
#    index  \
# 0   4715
# 1  10340
# 2  12276
# 3  16370
# 4  17560
#
#                                                                                              line_item
# 0  Total Cost Of Sales, Excluding Restaurant Depreciation And Amortization Of 295.6, 283.4, 267.1, ...
# 1  Total Cost Of Sales, Excluding Restaurant Depreciation And Amortization Of 373.7, 326.9 And 295....
# 2  Total Cost Of Sales, Excluding Restaurant Depreciation And Amortization Of 326.9, 295.6, 283.4, ...
# 3                                               Total Cost Of Sales Excluding Depreciation Shown Below
# 4  Total Cost Of Sales, Excluding Restaurant Depreciation And Amortization Of 282.3, 257.5 And 219....

# %%
mask = df['line_item'].str.contains(r"Cost Of Revenue",case=True, regex=True, na=False) & \
          df['line_item'].str.contains(r"Total",case=True, regex=True, na=False) & \
          df['line_item'].str.contains(r"Excl",case=False, regex=True, na=False) & \
         ~df['line_item'].str.contains(r"Veh|Other|Oper|Non|Auto",case=True, regex=True, na=False)
df[mask].reset_index()
# Out:
#    index  \
# 0   5962
# 1  16308
#
#                                                                                             line_item
# 0                             Total Cost Of Revenues Exclusive Of Amortization Shown Separately Below
# 1  Total Cost Of Revenues Exclusive Of Acquired Intangible Assets Amortization Shown Separately Below

# %% [markdown]
# ### Selling, General, Administrative Including Stock-Based Comp

# %%
mask = df['line_item'].str.contains(r"Selling",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"General",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Admin",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Including Stock",case=False, regex=True, na=False)
       
df[mask].reset_index()
# Out:
#     index  \
# 0    4858
# 1    4959
# 2    5332
# 3    6243
# 4    7083
# 5    7335
# 6    8345
# 7    8497
# 8    9063
# 9   12475
# 10  13371
# 11  14039
# 12  15322
# 13  16788
# 14  17629
# 15  18242
# 16  18741
# 17  20335
# 18  21538
#
#                                                                                               line_item
# 0   Selling, General, Administrative And Development Expense Including Stock-Based Compensation Expe...
# 1   Selling, General, Administrative And Development Expense Including Stock-Based Compensation Expe...
# 2   Selling, General And Administrative Expenses Including Stock-Based Compensation Of 13,274 In 201...
# 3   Selling, General And Administrative Including Stock-Based Compensation And Excluding Depreciatio...
# 4   Selling, General, Administrative And Development Expense Including Stock-Based Compensation Expe...
# 5   Selling, General And Administrative Expenses Including Stock-Based Compensation Of 19,530 And 13...
# 6   Selling, General And Administrative, Including Stock-Based Compensation And Transaction Costs No...
# 7   Selling, General And Administrative Expenses Including Stock-Based Compensation Of 21,462, 19,53...
# 8   Selling, General, Administrative And Development Expense Including Stock-Based Compensation Expe...
# 9   Selling, General And Administrative Including Stock-Based Compensation Of 62,875 In 2012, 54,261...
# 10  Selling, General And Administrative Including Stock-Based Compensation Of 54,261 In 2011, 18,668...
# 11  Selling, General, Administrative And Development Expense Including Stock-Based Compensation Expe...
# 12  Selling, General And Administrative Including Stock-Based Compensation Of 27,034, 62,875 And 54,...
# 13  Selling, General And Administrative Expenses Including Stock-Based Compensation Of 7,673, 21,462...
# 14  Selling, General, Administrative And Development Expense Including Stock-Based Compensation Expe...
# 15  Selling, General, Administrative And Development Expense Including Stock-Based Compensation Expe...
# 16        Selling, General And Administrative, Including Stock-Based Compensation And Transaction Costs
# 17                              Selling, General And Administrative, Including Stock-Based Compensation
# 18  Selling, General, Administrative And Development Expense Including Stock-Based Compensation Expe...

# %%
mask = df['line_item'].str.contains(r"Selling",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"General",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Admin",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Excluding",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Dep|Amort",case=False, regex=True, na=False) & \
         ~ df['line_item'].str.contains(r"Including",case=False, regex=True, na=False) 
         
df[mask].reset_index()
# Out:
#    index  \
# 0   4793
# 1   5167
# 2  17710
#
#                                                                                                                                            line_item
# 0                                                              Selling, General And Administrative Expenses, Excluding Depreciation And Amortization
# 1                                                             Selling, General, And Administrative Expenses, Excluding Depreciation And Amortization
# 2  Selling, General And Administrative Expenses Excluding Depreciation And Amortization Expense Of 81,695, 75,211, And 56,011 Shown Separately Below

# %%
mask = df['line_item'].str.contains(r"Selling",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"General",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Admin",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Excluding",case=False, regex=True, na=False) & \
         ~df['line_item'].str.contains(r"Dep|Amort",case=False, regex=True, na=False) & \
         ~df['line_item'].str.contains(r"Including",case=False, regex=True, na=False) 
         
df[mask].reset_index()
# Out:
#    index  \
# 0   7063
# 1  10992
# 2  11618
# 3  14919
#
#                                                                                                line_item
# 0                              Selling, General And Administrative Expenses, Excluding Impairment Losses
# 1                            Selling, General And Administrative Expenses, Excluding Goodwill Impairment
# 2                          Selling, General And Administrative Expenses, Excluding Receivable Impairment
# 3  Selling, General And Administrative Expenses, Excluding Goodwill Impairment And Receivable Impairment

# %% [markdown]
# ### General And Administrative

# %%
mask = df['line_item'].str.contains(r"General And Administrative",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Incl",case=True, regex=True, na=False) & \
          df['line_item'].str.contains(r"Stock|Equity",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Dep|Selling|Excl|Member",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Party",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Asset|Total|Other|Home|Prop",case=True, regex=True, na=False) 
       
df[mask].reset_index()
# Out:
#     index  \
# 0    4084
# 1    4340
# 2    5320
# 3    5770
# 4    5844
# 5    5891
# 6    6452
# 7    8964
# 8    9163
# 9   10701
# 10  11221
# 11  12085
# 12  12257
# 13  12877
# 14  14149
# 15  14165
# 16  14486
# 17  14763
# 18  14938
# 19  20433
#
#                                                                                               line_item
# 0   General And Administrative Including 73,517, 12,778 And 13,529 Of Equity-Based Compensation In 2...
# 1   General And Administrative Including Equity-Based Compensation Expense Of 365,280, 112,252 And 9...
# 2   General And Administrative Including Equity-Based Compensation Expense Of 23,317, 20,437 And 35,...
# 3   General And Administrative Expenses Including Non-Cash Equity-Based Compensation, Net Of Capital...
# 4   General And Administrative Including Equity-Based Compensation Expense Of 70,414, 23,559 And 23,...
# 5   General And Administrative Including 250, 102 And 28 Of Non-Cash Stock-Based Compensation, Respe...
# 6   General And Administrative Expenses Including Non-Cash Equity-Based Compensation, Net Of Capital...
# 7   General And Administrative Including Equity-Based Compensation Expense Of 23,559, 23,317 And 20,...
# 8   General And Administrative Including 448, 250 And 102 For The Years Ending December 31, 2012, 20...
# 9   General And Administrative Including 12,778, 13,529 And 19,654 Of Equity-Based Compensation In 2...
# 10  General And Administrative Including Equity-Based Compensation Expense Of 365,280 And 112,252 In...
# 11                           General And Administrative Including 365,280 Of Stock Compensation In 2013
# 12  General And Administrative Including 35,111, 73,517 And 12,778 Of Equity-Based Compensation In 2...
# 13  General And Administrative Including Equity-Based Compensation Expense Of 103,445, 70,414 And 23...
# 14                               General And Administrative Including Equity-Based Compensation Expense
# 15  General And Administrative Including Equity-Based Compensation Expense Of 97,877, 102,421, And 1...
# 16  General And Administrative Expenses Including Non-Cash Stock Based Compensation, Net Of Capitali...
# 17  General And Administrative Expenses Including Non-Cash Equity-Based Compensation, Net Of Capital...
# 18  General And Administrative Expenses Including Non-Cash Stock Based Compensation, Net Of Capitali...
# 19  General And Administrative Including 34,933, 35,111 And 73,517 Of Equity-Based Compensation In 2...

# %%
mask = df['line_item'].str.contains(r"General And Admin",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Excl",case=True, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Sell|Asset",case=True, regex=True, na=False) 
       
df[mask].reset_index()
# Out:
#    index  \
# 0   8295
#
#                                                                                              line_item
# 0  General And Administrative Expenses Excluding Depreciation And Amortization Expense Reflected Below

# %% [markdown]
# ### Selling, General And Admin

# %%
mask = df['line_item'].str.contains(r"General",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Administrative",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Selling",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Including|Excluding",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"^Dep|Intangible|Amort",case=True, regex=True, na=False)
       
df[mask].reset_index()

# %%
mask = df['line_item'].str.contains(r"General",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Administrative",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Sales",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"^Dep|Home|Percent|Intan",case=True, regex=True, na=False)
       
df[mask].reset_index()

# %% [markdown]
# ## Operating Expenses

# %%
mask = df['line_item'].str.contains(r"Operat.*Expense",case=False, regex=True, na=False) & \
          df['line_item'].str.contains(r"Excl",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"Asset|Segment|Item",case=True, regex=True, na=False)
       
df[mask].reset_index()
# Out:
#    index  \
# 0   5448
# 1   7242
# 2   8734
# 3  11495
# 4  14250
# 5  15533
# 6  15580
# 7  17692
# 8  19993
#
#                                                                              line_item
# 0                 Operating Costs And Expenses Excluding Depreciation And Amortization
# 1                   Direct Operating Expenses, Excluding Depreciation And Amortization
# 2                    Operating Expenses, Excluding Depreciation And Amortization Below
# 3                  Direct Operating Expense Exclusive Of Depreciation And Amortization
# 4  Operating Expense Exclusive Of Depreciation And Amortization Shown Separately Below
# 5                     Operating Expense, Excluding Depreciation And Amortization Below
# 6                        Operating Expenses Exclusive Of Depreciation And Amortization
# 7    Operating Expenses Excluding Depreciation And Amortization Shown Separately Below
# 8   Operating Expenses Excluding Depreciation And Amortization Expense Reflected Below

# %%
mask = df['line_item'].str.contains(r"Operat.*Expense",case=False, regex=True, na=False) & \
        ~ df['line_item'].str.contains(r"
# 202  19303
# 203  19413
# 204  19655
# 205  19976
# 206  20004
# 207  20014
# 208  20059
#
#                                                                                                line_item
# 0                                                                             Operating Expense [Member]
# 1                                                                                 Non-Operating Expense:
# 2                                                                     Non-Operating Income Expense, Net:
# 3                                                                           Cost And Operating Expenses:
# 4                                                                                 Nonoperating Expenses:
# 5                                                                                     Operating Expenses
# 6                                                                       Non-Operating Income And Expense
# 7                                                                      Non-Operating Expense Income, Net
# 8                                                                         Non-Operating Expenses Income:
# 9                                                                           Non-Operating Income Expense
# 10                                                                          Nonoperating Income Expense:
# 11                                                                           Nonoperating Expense Income
# 12                                                                                 Non-Operating Expense
# 13                                                                Nonoperating Income Expense [Abstract]
# 14                                                                   Acquisition And Operating Expenses:
# 15                                                                         Costs And Operation Expenses:
# 16                                                                     Non-Operating Income Expense, Net
# 17                                                                       Operating Expenses And Charges:
# 18                                                                          Operating Costs And Expenses
# 19                                                                          Costs And Operating Expenses
# 20                                                                            Railway Operating Expenses
# 21                                                                              Total Operating Expenses
# 22                                                                            Direct Operating Expenses:
# 23                                                                          Nonoperating Expense Income:
# 24                                                                         Non-Operating Income Expense:
# 25                                                                        Non-Operating Income Expenses:
# 26                                                                         Operating Expenses [Abstract]
# 27                                                                                    Operating Expense:
# 28                                                                Total Non-Operating Income And Expense
# 29                                                                              Operating Expenses, Net:
# 30                                                               Operating Costs And Expenses [Abstract]
# 31                                                                           Railway Operating Expenses:
# 32                                                                           Nonoperating Income Expense
# 33                                                                         Nonoperating Income Expenses:
# 34                                                                          Operating Cost And Expenses:
# 35                                                                         Operating Expenses And Income
# 36                                                                         Costs And Operating Expenses:
# 37                                                                              Cruise Operating Expense
# 38                                                                          Non-Operating Expenses, Net:
# 39                                                                            Utility Operating Expenses
# 40                                                                             Operating Expense Income:
# 41                                                                               Non-Operating Expenses:
# 42                                                                         Non-Operating Expense Income:
# 43                                                                   Non-Operating Income Expenses, Net:
# 44                                                              Costs And Operation Expenses: [Abstract]
# 45                                                                                   Operating Expenses:
# 46                                                                                     Operating Expense
# 47                                                                    Non-Operating Income And Expenses:
# 48                                                                           Non-Operating Expense, Net:
# 49                                                                 Cost Of Sales And Operating Expenses:
# 50                                                                         Non-Operating Expenses Income
# 51                                                                         Operating Costs And Expenses:
# 52                                                                          Non-Operating Expense Income
# 53                                                                            Operating Expenses Income:
# 54                                                       Interest And Non-Operating Income Expenses, Net
# 55                                                -Loss Income From Operations Before Income Tax Expense
# 56                                                                              Resort Operating Expense
# 57                                                                    Operating And Maintenance Expenses
# 58   -Loss Gain On Discontinued Operations, Net Of Related Tax Benefit Expense Of 320, 2,207 And 1,57...
# 59   Loss From Operations Of Discontinued Businesses, Net Of Income Tax Expense Of 0, 2, And 21, Resp...
# 60                                                                 Miscellaneous Operating Expenses, Net
# 61                                                                         Non-Operating Pension Expense
# 62                                                  Marketing And Midstream Operating Costs And Expenses
# 63           Net Gain Loss From Discontinued Operations, Net Of Tax Expense Benefit Of 3.6, 0.8 And 34.6
# 168                                                                    Operating And Maintenance Expense
# 169                                                                   Nonoperating Income Expense, Total
# 170                                                              Total Non-Operating Income Expense, Net
# 171                                                                            Operating Expenses, Total
# 172                            -Loss Income From Continuing Operations Before Income Tax Expense Benefit
# 173                                                                    Total Operating Cost And Expenses
# 174                                                                    Non-Operating Expense Income, Net
# 175                                                                 Total Operating Costs, Expenses, Net
# 176                                        Earnings From Continuing Operations Before Income Tax Expense
# 177                                                                    Nonoperating Income Expense Total
# 178               Income Loss From Discontinued Operations, Net Of Income Tax Expense Benefit Of , 0 And
# 179  -Loss Gain On Discontinued Operations, Net Of Related Tax Benefit Expense Of 417, 801 And 2,191,...
# 180                                                                       Non-Operating Interest Expense
# 181                                                               Utilities Operating Expense, Fuel Used
# 182  Income Loss From Operations Of Discontinued Businesses, Net Of Income Tax Benefit Expense Of 24,...
# 183  Net Gain Loss From Disposal And Impairments Of Discontinued Operations, Net Of Income Tax Benefi...
# 184                                                                      Cooperative Advertising Expense
# 185                                                                     Total Railway Operating Expenses
# 186  Income Loss From Continuing Operations Before Interest Expense, Interest Income, Income Taxes, N...
# 187                                                                        Total Operating Expenses, Net
# 188                Net Loss Earnings From Discontinued Operations, Net Of Tax Expense Of  , 12.0 And 8.2
# 189                                                                          Non-Operating Expenses, Net
# 190                                                               Total Non-Operating Income And Expense
# 191              Income From Discontinued Operations Net Of Tax Expense Of 0-, 46, And 104, Respectively
# 192                                                                        Oil And Gas Operating Expense
# 193                                                                             Operating Expense Income
# 194                                                                  Operating Costs And Expenses, Total
# 195                                                                    Total Cost And Operating Expenses
# 196                          Income Loss From Discontinued Operations, Net Of Income Tax Expense Benefit
# 197  -Loss Income From Discontinued Operations, Net Of Tax Benefit Expense Of 131.5, 29.7 And 20.1, R...
# 198                                  Income Loss From Discontinued Operations, Net Of Income Tax Expense
# 199                                                                    Operation And Maintenance Expense
# 200                              -Loss Earnings From Discontinued Operations, Net Of Tax Benefit Expense
# 201                               Income From Sale Of Discontinued Operations, Net Of Income Tax Expense
# 202                                  Income From Continuing Operations Before Income Tax Expense Benefit
# 203                                                                     Nonoperating Income Expense, Net
# 204                                                                   Nonoperating Expense Income, Total
# 205                                       Nonoperating Pension And Postretirement Benefit Expense Income
# 206                                                                 Total Operating Expenses And Charges
# 207                                                                         Non-Operating Expense Income
# 208                                                   Direct Operating Expenses For Gaming Entertainment

# %% [markdown]
# ### Gross Profit

# %%
mask = df['line_item'].str.contains(r"Gross Profit",case=False, regex=True, na=False) & \
         ~ df['line_item'].str.contains(r"Member|Per|Total",case=False, regex=True, na=False)
   
df[mask].reset_index()

# %%
mask = df['line_item'].str.contains(r"Gross Profit",case=False, regex=True, na=False) & \
           df['line_item'].str.contains(r"Total",case=False, regex=True, na=False) & \
         ~ df['line_item'].str.contains(r"Member|Per",case=False, regex=True, na=False)
   
df[mask].reset_index()
# Out:
#    index            line_item
# 0  12117   Total Gross Profit
# 1  19692  Gross Profit, Total

# %% [markdown]
# # Depreciation
