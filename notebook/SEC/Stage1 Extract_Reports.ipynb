# %%
from bs4 import BeautifulSoup
from os.path import exists
import numpy as np
import pandas as pd
import requests as req
import time
import os
import lxml
import pickle

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 100)
pd.options.display.float_format = '{:.2f}'.format

# %%
DATA_ROOT_PATH="/mnt/data/projects/MD1/data/R1000/stage1/"
PROJ_ROOT_PATH="/home/priyesh/projects/MD1"

# %%
def get_report_list(soup):
    
  # Create list of reports found in XML file

  #Create a list to hold all the reports found

  report_list = []

  #Find myreports tag

  reports = soup.find('myreports')

  #Loop through each report but ignore last one. 

  for report in reports.find_all('report')[:-2]:
    
    # Create dictionary and store information required
    
    report_dict = {}
    
    report_dict['short_name'] = report.shortname.text
    report_dict['long_name'] = report.longname.text
    
    if report.htmlfilename is not None:
      report_dict['filename'] = report.htmlfilename.text.strip()
      report_dict['filetype'] = 'htm'
    elif report.xmlfilename is not None:
      report_dict['filename'] = report.xmlfilename.text.strip() 
      report_dict['filetype'] = 'xml'
    else:
      report_dict['Filename'] = np.nan
      eport_dict['filetype'] = 'notset'
    report_list.append(report_dict)

  return report_list

# %%
def find_reports(master_report_list):
    
  # Loop through master report list and store reports which match

  report_dict = {}

  for report in master_report_list:
    
   if bal_match_report(report['short_name']):
     report_dict['Balance'] = report
    
   if income_match_report(report['short_name']):
     report_dict['Income'] = report

   if cash_match_report(report['short_name']):
     report_dict['Cash'] = report

  return report_dict

# %%
def get_reports(ticker):

  '''
  Generate a dictionary for given ticker which contains list of reports for each financial year.
  
  '''

  master_report_list = {}

  filepath=os.path.join(DATA_ROOT_PATH, ticker)
 
  # iterate over sub-directories

  for d in os.listdir(filepath):
    
    if os.path.isdir(filepath+"/"+d):
      yr=d
    
      file=filepath+"/"+d+"/FilingSummary.xml"
    
      if exists(file):
        with open(file, 'r')as f:
          soup=BeautifulSoup(f,'lxml')
        
        report_list = get_report_list(soup)
        master_report_list[yr] = report_list 
        
        # Save mapping to directory
        
        tmp = pd.DataFrame.from_dict(report_list)
        tmp = tmp.set_index('filename')
        tmp.to_csv(filepath+"/"+d+"/filemap.csv",sep="!")
      else:
        print("FilingSummary.xml not found: ",ticker,d)
   
  return master_report_list

# %%
get_reports('AAL')
# Out:
# FilingSummary.xml not found:  AAL 10
# {'12': [{'short_name': 'Document And Entity Information',
#    'long_name': '00090 - Document - Document And Entity Information',
#    'filename': 'R1.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Consolidated Statements Of Operations',
#    'long_name': '00100 - Statement - Consolidated Statements Of Operations',
#    'filename': 'R2.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Consolidated Statements Of Operations (Parenthetical)',
#    'long_name': '00105 - Statement - Consolidated Statements Of Operations (Parenthetical)',
#    'filename': 'R3.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Consolidated Statements Of Comprehensive Income',
#    'long_name': '00200 - Statement - Consolidated Statements Of Comprehensive Income',
#    'filename': 'R4.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Consolidated Balance Sheets',
#    'long_name': '00300 - Statement - Consolidated Balance Sheets',
#    'filename': 'R5.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Consolidated Balance Sheets (Parenthetical)',
#    'long_name': '00305 - Statement - Consolidated Balance Sheets (Parenthetical)',
#    'filename': 'R6.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Consolidated Statements Of Cash Flows',
#    'long_name': '00400 - Statement - Consolidated Statements Of Cash Flows',
#    'filename': 'R7.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': "Consolidated Statements Of Stockholders' Equity (Deficit)",
#    'long_name': "00500 - Statement - Consolidated Statements Of Stockholders' Equity (Deficit)",
#    'filename': 'R8.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': "Consolidated Statements Of Stockholders' Equity (Deficit) (Parenthetical)",
#    'long_name': "00505 - Statement - Consolidated Statements Of Stockholders' Equity (Deficit) (Parenthetical)",
#    'filename': 'R9.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Reorganization',
#    'long_name': '10101 - Disclosure - Reorganization',
#    'filename': 'R10.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Summary Of Accounting Policies',
#    'long_name': '10201 - Disclosure - Summary Of Accounting Policies',
#    'filename': 'R11.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Special Charges And Restructuring Activities',
#    'long_name': '10301 - Disclosure - Special Charges And Restructuring Activities',
#    'filename': 'R12.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Investments And Fair Value Measurements',
#    'long_name': '10401 - Disclosure - Investments And Fair Value Measurements',
#    'filename': 'R13.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Commitments, Contingencies And Guarantees',
#    'long_name': '10501 - Disclosure - Commitments, Contingencies And Guarantees',
#    'filename': 'R14.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Leases',
#    'long_name': '10601 - Disclosure - Leases',
#    'filename': 'R15.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Indebtedness',
#    'long_name': '10701 - Disclosure - Indebtedness',
#    'filename': 'R16.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Financial Instruments And Risk Management',
#    'long_name': '10801 - Disclosure - Financial Instruments And Risk Management',
#    'filename': 'R17.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Income Taxes',
#    'long_name': '10901 - Disclosure - Income Taxes',
#    'filename': 'R18.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Share Based Compensation',
#    'long_name': '11001 - Disclosure - Share Based Compensation',
#    'filename': 'R19.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Retirement Benefits',
#    'long_name': '11101 - Disclosure - Retirement Benefits',
#    'filename': 'R20.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Intangible Assets',
#    'long_name': '11201 - Disclosure - Intangible Assets',
#    'filename': 'R21.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Accumulated Other Comprehensive Income (Loss)',
#    'long_name': '11301 - Disclosure - Accumulated Other Comprehensive Income (Loss)',
#    'filename': 'R22.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Earnings (Loss) Per Share',
#    'long_name': '11401 - Disclosure - Earnings (Loss) Per Share',
#    'filename': 'R23.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Segment Reporting',
#    'long_name': '11501 - Disclosure - Segment Reporting',
#    'filename': 'R24.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Quarterly Financial Data',
#    'long_name': '11601 - Disclosure - Quarterly Financial Data',
#    'filename': 'R25.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'AMR Eagle Divestiture',
#    'long_name': '11701 - Disclosure - AMR Eagle Divestiture',
#    'filename': 'R26.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Subsequent Events',
#    'long_name': '11801 - Disclosure - Subsequent Events',
#    'filename': 'R27.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Schedule II - Valuation And Qualifying Accounts And Reserves',
#    'long_name': '11901 - Disclosure - Schedule II - Valuation And Qualifying Accounts And Reserves',
#    'filename': 'R28.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Summary Of Accounting Policies (Policy)',
#    'long_name': '20202 - Disclosure - Summary Of Accounting Policies (Policy)',
#    'filename': 'R29.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Bankruptcy (Tables)',
#    'long_name': '30103 - Disclosure - Bankruptcy (Tables)',
#    'filename': 'R30.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Special Charges And Restructuring Activities (Tables)',
#    'long_name': '30303 - Disclosure - Special Charges And Restructuring Activities (Tables)',
#    'filename': 'R31.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Investments And Fair Value Measurements (Tables)',
#    'long_name': '30403 - Disclosure - Investments And Fair Value Measurements (Tables)',
#    'filename': 'R32.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Commitments, Contingencies And Guarantees (Tables)',
#    'long_name': '30503 - Disclosure - Commitments, Contingencies And Guarantees (Tables)',
#    'filename': 'R33.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Leases (Tables)',
#    'long_name': '30603 - Disclosure - Leases (Tables)',
#    'filename': 'R34.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Indebtedness (Tables)',
#    'long_name': '30703 - Disclosure - Indebtedness (Tables)',
#    'filename': 'R35.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Financial Instruments And Risk Management (Tables)',
#    'long_name': '30803 - Disclosure - Financial Instruments And Risk Management (Tables)',
#    'filename': 'R36.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Income Taxes (Tables)',
#    'long_name': '30903 - Disclosure - Income Taxes (Tables)',
#    'filename': 'R37.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Share Based Compensation (Tables)',
#    'long_name': '31003 - Disclosure - Share Based Compensation (Tables)',
#    'filename': 'R38.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Retirement Benefits (Tables)',
#    'long_name': '31103 - Disclosure - Retirement Benefits (Tables)',
#    'filename': 'R39.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Intangible Assets (Tables)',
#    'long_name': '31203 - Disclosure - Intangible Assets (Tables)',
#    'filename': 'R40.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Accumulated Other Comprehensive Income (Loss) (Tables)',
#    'long_name': '31303 - Disclosure - Accumulated Other Comprehensive Income (Loss) (Tables)',
#    'filename': 'R41.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Earnings (Loss) Per Share (Tables)',
#    'long_name': '31403 - Disclosure - Earnings (Loss) Per Share (Tables)',
#    'filename': 'R42.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Segment Reporting (Tables)',
#    'long_name': '31503 - Disclosure - Segment Reporting (Tables)',
#    'filename': 'R43.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Quarterly Financial Data (Tables)',
#    'long_name': '31603 - Disclosure - Quarterly Financial Data (Tables)',
#    'filename': 'R44.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Reorganization (Narrative) (Details)',
#    'long_name': '40101 - Disclosure - Reorganization (Narrative) (Details)',
#    'filename': 'R45.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Reorganization (Schedule Of Liabilities Subject To Compromise) (Details)',
#    'long_name': '40102 - Disclosure - Reorganization (Schedule Of Liabilities Subject To Compromise) (Details)',
#    'filename': 'R46.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Reorganization (Components Of Long-Term Debt) (Details)',
#    'long_name': '40103 - Disclosure - Reorganization (Components Of Long-Term Debt) (Details)',
#    'filename': 'R47.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Reorganization (Schedule Of Reorganization Items) (Details)',
#    'long_name': '40104 - Disclosure - Reorganization (Schedule Of Reorganization Items) (Details)',
#    'filename': 'R48.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Summary Of Accounting Policies (Narrative) (Details)',
#    'long_name': '40201 - Disclosure - Summary Of Accounting Policies (Narrative) (Details)',
#    'filename': 'R49.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Summary Of Accounting Policies (Schedule Of Depreciable Lives Used For Principal Depreciable Asset Classifications) (Details)',
#    'long_name': '40202 - Disclosure - Summary Of Accounting Policies (Schedule Of Depreciable Lives Used For Principal Depreciable Asset Classifications) (Details)',
#    'filename': 'R50.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Special Charges And Restructuring Activities (Narrative) (Details)',
#    'long_name': '40301 - Disclosure - Special Charges And Restructuring Activities (Narrative) (Details)',
#    'filename': 'R51.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': "Special Charges And Restructuring Activities (Components Of Company's Special Charges) (Details)",
#    'long_name': "40302 - Disclosure - Special Charges And Restructuring Activities (Components Of Company's Special Charges) (Details)",
#    'filename': 'R52.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Investments And Fair Value Measurements (Short-Term Investments) (Details)',
#    'long_name': '40401 - Disclosure - Investments And Fair Value Measurements (Short-Term Investments) (Details)',
#    'filename': 'R53.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Investments And Fair Value Measurements (Short-Term Investments By Contractual Maturity) (Details)',
#    'long_name': '40402 - Disclosure - Investments And Fair Value Measurements (Short-Term Investments By Contractual Maturity) (Details)',
#    'filename': 'R54.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Investments And Fair Value Measurements (Assets And Liabilities Measured At Fair Value On A Recurring Basis) (Details)',
#    'long_name': '40403 - Disclosure - Investments And Fair Value Measurements (Assets And Liabilities Measured At Fair Value On A Recurring Basis) (Details)',
#    'filename': 'R55.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Commitments, Contingencies And Guarantees (Narrative) (Details)',
#    'long_name': '40501 - Disclosure - Commitments, Contingencies And Guarantees (Narrative) (Details)',
#    'filename': 'R56.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Commitments, Contingencies And Guarantees (Aircraft Acquisition Commitments) (Details)',
#    'long_name': '40502 - Disclosure - Commitments, Contingencies And Guarantees (Aircraft Acquisition Commitments) (Details)',
#    'filename': 'R57.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Leases (Narrative) (Details)',
#    'long_name': '40601 - Disclosure - Leases (Narrative) (Details)',
#    'filename': 'R58.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Leases (Future Minimum Lease Payments Under Capital Leases) (Details)',
#    'long_name': '40602 - Disclosure - Leases (Future Minimum Lease Payments Under Capital Leases) (Details)',
#    'filename': 'R59.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Leases (Future Minimum Lease Payments Under Operating Leases) (Details)',
#    'long_name': '40603 - Disclosure - Leases (Future Minimum Lease Payments Under Operating Leases) (Details)',
#    'filename': 'R60.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Indebtedness (Narrative) (Details)',
#    'long_name': '40701 - Disclosure - Indebtedness (Narrative) (Details)',
#    'filename': 'R61.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Indebtedness (Components Of Long-Term Debt) (Details)',
#    'long_name': '40702 - Disclosure - Indebtedness (Components Of Long-Term Debt) (Details)',
#    'filename': 'R62.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Indebtedness (Schedule Of Maturities Of Long Term Debt And Operating Lease Payments) (Details)',
#    'long_name': '40703 - Disclosure - Indebtedness (Schedule Of Maturities Of Long Term Debt And Operating Lease Payments) (Details)',
#    'filename': 'R63.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Indebtedness (Schedule Of Collateral Coverage Tests) (Details)',
#    'long_name': '40704 - Disclosure - Indebtedness (Schedule Of Collateral Coverage Tests) (Details)',
#    'filename': 'R64.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Financial Instruments And Risk Management (Narrative) (Details)',
#    'long_name': '40801 - Disclosure - Financial Instruments And Risk Management (Narrative) (Details)',
#    'filename': 'R65.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Financial Instruments And Risk Management (Effect Of Cash Flow Hedges On Financial Statements) (Details)',
#    'long_name': '40802 - Disclosure - Financial Instruments And Risk Management (Effect Of Cash Flow Hedges On Financial Statements) (Details)',
#    'filename': 'R66.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Financial Instruments And Risk Management (Effect Of Derivative Instruments On Statements Of Operations) (Details)',
#    'long_name': '40803 - Disclosure - Financial Instruments And Risk Management (Effect Of Derivative Instruments On Statements Of Operations) (Details)',
#    'filename': 'R67.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Financial Instruments And Risk Management (Summary Of Carrying Value And Estimated Fair Values Of Long-Term Debt) (Details)',
#    'long_name': '40804 - Disclosure - Financial Instruments And Risk Management (Summary Of Carrying Value And Estimated Fair Values Of Long-Term Debt) (Details)',
#    'filename': 'R68.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Income Taxes (Narrative) (Details)',
#    'long_name': '40901 - Disclosure - Income Taxes (Narrative) (Details)',
#    'filename': 'R69.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Income Taxes (Components Of Income Tax Provision (Benefit)) (Details)',
#    'long_name': '40902 - Disclosure - Income Taxes (Components Of Income Tax Provision (Benefit)) (Details)',
#    'filename': 'R70.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Income Taxes (Computation Of Income Tax Expense (Benefit)) (Details)',
#    'long_name': '40903 - Disclosure - Income Taxes (Computation Of Income Tax Expense (Benefit)) (Details)',
#    'filename': 'R71.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Income Taxes (Deferred Tax Assets And Liabilities) (Details)',
#    'long_name': '40904 - Disclosure - Income Taxes (Deferred Tax Assets And Liabilities) (Details)',
#    'filename': 'R72.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Income Taxes (Reconciliation Of Unrecognized Tax Benefit) (Details)',
#    'long_name': '40905 - Disclosure - Income Taxes (Reconciliation Of Unrecognized Tax Benefit) (Details)',
#    'filename': 'R73.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Share Based Compensation (Narrative) (Details)',
#    'long_name': '41001 - Disclosure - Share Based Compensation (Narrative) (Details)',
#    'filename': 'R74.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Share Based Compensation (Stock Based Compensation Awards, Expected Fair Value Assumptions) (Details)',
#    'long_name': '41002 - Disclosure - Share Based Compensation (Stock Based Compensation Awards, Expected Fair Value Assumptions) (Details)',
#    'filename': 'R75.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Share Based Compensation (Schedule Of Stock Options/SARs Activity) (Details)',
#    'long_name': '41003 - Disclosure - Share Based Compensation (Schedule Of Stock Options/SARs Activity) (Details)',
#    'filename': 'R76.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Share Based Compensation (Status And Changes Of Non-Vested Options/SARs) (Details)',
#    'long_name': '41004 - Disclosure - Share Based Compensation (Status And Changes Of Non-Vested Options/SARs) (Details)',
#    'filename': 'R77.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Share Based Compensation (Schedule Of Stock-Based Activities) (Details)',
#    'long_name': '41005 - Disclosure - Share Based Compensation (Schedule Of Stock-Based Activities) (Details)',
#    'filename': 'R78.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Retirement Benefits (Narrative) (Details)',
#    'long_name': '41101 - Disclosure - Retirement Benefits (Narrative) (Details)',
#    'filename': 'R79.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Retirement Benefits (Reconciliation Of Changes In Pension, Retiree Medical, Other Benefit Obligations And Fair Value Assets) (Details)',
#    'long_name': '41102 - Disclosure - Retirement Benefits (Reconciliation Of Changes In Pension, Retiree Medical, Other Benefit Obligations And Fair Value Assets) (Details)',
#    'filename': 'R80.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Retirement Benefits (Schedule Of Amounts Recognized In Consolidated Balance Sheets) (Details)',
#    'long_name': '41103 - Disclosure - Retirement Benefits (Schedule Of Amounts Recognized In Consolidated Balance Sheets) (Details)',
#    'filename': 'R81.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Retirement Benefits (Schedule Of Amounts Recognized In Other Comprehensive Loss) (Details)',
#    'long_name': '41104 - Disclosure - Retirement Benefits (Schedule Of Amounts Recognized In Other Comprehensive Loss) (Details)',
#    'filename': 'R82.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Retirement Benefits (Schedule Of Accumulated Benefit Obligations Exceeding Fair Value Of Plan Assets) (Details)',
#    'long_name': '41105 - Disclosure - Retirement Benefits (Schedule Of Accumulated Benefit Obligations Exceeding Fair Value Of Plan Assets) (Details)',
#    'filename': 'R83.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Retirement Benefits (Components Of Net Periodic Benefit Cost) (Details)',
#    'long_name': '41106 - Disclosure - Retirement Benefits (Components Of Net Periodic Benefit Cost) (Details)',
#    'filename': 'R84.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Retirement Benefits (Schedule Of Assumption Used Calculating Benefit Obligation) (Details)',
#    'long_name': '41107 - Disclosure - Retirement Benefits (Schedule Of Assumption Used Calculating Benefit Obligation) (Details)',
#    'filename': 'R85.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Retirement Benefits (Summary Of Target Assets Allocation) (Details)',
#    'long_name': '41108 - Disclosure - Retirement Benefits (Summary Of Target Assets Allocation) (Details)',
#    'filename': 'R86.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Retirement Benefits (Schedule Of Fair Values Of Pension Plan Assets By Asset Category) (Details)',
#    'long_name': '41109 - Disclosure - Retirement Benefits (Schedule Of Fair Values Of Pension Plan Assets By Asset Category) (Details)',
#    'filename': 'R87.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Retirement Benefits (Changes In Fair Value Measurements Of Level 3 Investments) (Details)',
#    'long_name': '41110 - Disclosure - Retirement Benefits (Changes In Fair Value Measurements Of Level 3 Investments) (Details)',
#    'filename': 'R88.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': "Retirement Benefits (Fair Values Of Company's Other Postretirement Benefit Plan Assets) (Details)",
#    'long_name': "41111 - Disclosure - Retirement Benefits (Fair Values Of Company's Other Postretirement Benefit Plan Assets) (Details)",
#    'filename': 'R89.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Retirement Benefits (Fair Value Of Investments In Money Market Fund) (Details)',
#    'long_name': '41112 - Disclosure - Retirement Benefits (Fair Value Of Investments In Money Market Fund) (Details)',
#    'filename': 'R90.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Retirement Benefits (Schedule Of One Percentage Point Change In Assumed Health Care Cost Trend Rates) (Details)',
#    'long_name': '41113 - Disclosure - Retirement Benefits (Schedule Of One Percentage Point Change In Assumed Health Care Cost Trend Rates) (Details)',
#    'filename': 'R91.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Retirement Benefits (Benefit Payments Of Expected Future Service ) (Details)',
#    'long_name': '41114 - Disclosure - Retirement Benefits (Benefit Payments Of Expected Future Service ) (Details)',
#    'filename': 'R92.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Intangible Assets (Narrative) (Details)',
#    'long_name': '41201 - Disclosure - Intangible Assets (Narrative) (Details)',
#    'filename': 'R93.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Intangible Assets (Summary Of Amortization Of Intangible Assets) (Details)',
#    'long_name': '41202 - Disclosure - Intangible Assets (Summary Of Amortization Of Intangible Assets) (Details)',
#    'filename': 'R94.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Accumulated Other Comprehensive Income (Loss) (Components Of Accumulated Other Comprehensive Income (Loss)) (Details)',
#    'long_name': '41301 - Disclosure - Accumulated Other Comprehensive Income (Loss) (Components Of Accumulated Other Comprehensive Income (Loss)) (Details)',
#    'filename': 'R95.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Earnings (Loss) Per Share (Computations Of Basic And Diluted Earnings (Loss) Per Share) (Details)',
#    'long_name': '41401 - Disclosure - Earnings (Loss) Per Share (Computations Of Basic And Diluted Earnings (Loss) Per Share) (Details)',
#    'filename': 'R96.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Segment Reporting (Operating Revenues By Geographic Region) (Details)',
#    'long_name': '41501 - Disclosure - Segment Reporting (Operating Revenues By Geographic Region) (Details)',
#    'filename': 'R97.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Quarterly Financial Data (Narrative) (Details)',
#    'long_name': '41601 - Disclosure - Quarterly Financial Data (Narrative) (Details)',
#    'filename': 'R98.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Quarterly Financial Data (Summarized Financial Data By Quarter) (Details)',
#    'long_name': '41602 - Disclosure - Quarterly Financial Data (Summarized Financial Data By Quarter) (Details)',
#    'filename': 'R99.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'AMR Eagle Divestiture (Details)',
#    'long_name': '41701 - Disclosure - AMR Eagle Divestiture (Details)',
#    'filename': 'R100.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Subsequent Events (Details)',
#    'long_name': '41801 - Disclosure - Subsequent Events (Details)',
#    'filename': 'R101.htm',
#    'filetype': 'htmlfilename'}],
#  '17': [{'short_name': 'Document and Entity Information',
#    'long_name': '1001 - Document - Document and Entity Information',
#    'filename': 'R1.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Consolidated Statements of Operations',
#    'long_name': '1003 - Statement - Consolidated Statements of Operations',
#    'filename': 'R2.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Consolidated Statements of Comprehensive Income',
#    'long_name': '1004 - Statement - Consolidated Statements of Comprehensive Income',
#    'filename': 'R3.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Consolidated Balance Sheets',
#    'long_name': '1005 - Statement - Consolidated Balance Sheets',
#    'filename': 'R4.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Consolidated Balance Sheets (Parenthetical)',
#    'long_name': '1006 - Statement - Consolidated Balance Sheets (Parenthetical)',
#    'filename': 'R5.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Consolidated Statements of Cash Flows',
#    'long_name': '1007 - Statement - Consolidated Statements of Cash Flows',
#    'filename': 'R6.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': "Consolidated Statements of Stockholders' Equity (Deficit)",
#    'long_name': "1008 - Statement - Consolidated Statements of Stockholders' Equity (Deficit)",
#    'filename': 'R7.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': "Consolidated Statements of Stockholders' Equity (Deficit) (Parenthetical)",
#    'long_name': "1009 - Statement - Consolidated Statements of Stockholders' Equity (Deficit) (Parenthetical)",
#    'filename': 'R8.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Basis of Presentation and Summary of Significant Accounting Policies',
#    'long_name': '1010 - Disclosure - Basis of Presentation and Summary of Significant Accounting Policies',
#    'filename': 'R9.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Special Items, Net',
#    'long_name': '1011 - Disclosure - Special Items, Net',
#    'filename': 'R10.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Earnings Per Common Share',
#    'long_name': '1012 - Disclosure - Earnings Per Common Share',
#    'filename': 'R11.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Share Repurchase Programs and Dividends',
#    'long_name': '1013 - Disclosure - Share Repurchase Programs and Dividends',
#    'filename': 'R12.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt',
#    'long_name': '1014 - Disclosure - Debt',
#    'filename': 'R13.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Income Taxes',
#    'long_name': '1015 - Disclosure - Income Taxes',
#    'filename': 'R14.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Risk Management',
#    'long_name': '1016 - Disclosure - Risk Management',
#    'filename': 'R15.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Fair Value Measurements',
#    'long_name': '1017 - Disclosure - Fair Value Measurements',
#    'filename': 'R16.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans',
#    'long_name': '1018 - Disclosure - Employee Benefit Plans',
#    'filename': 'R17.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Accumulated Other Comprehensive Income (Loss)',
#    'long_name': '1019 - Disclosure - Accumulated Other Comprehensive Income (Loss)',
#    'filename': 'R18.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Commitments, Contingencies and Guarantees',
#    'long_name': '1020 - Disclosure - Commitments, Contingencies and Guarantees',
#    'filename': 'R19.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Supplemental Cash Flow Information',
#    'long_name': '1021 - Disclosure - Supplemental Cash Flow Information',
#    'filename': 'R20.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Operating Segments and Related Disclosures',
#    'long_name': '1022 - Disclosure - Operating Segments and Related Disclosures',
#    'filename': 'R21.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Share-based Compensation',
#    'long_name': '1023 - Disclosure - Share-based Compensation',
#    'filename': 'R22.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Valuation and Qualifying Accounts',
#    'long_name': '1024 - Disclosure - Valuation and Qualifying Accounts',
#    'filename': 'R23.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Quarterly Financial Data (Unaudited)',
#    'long_name': '1025 - Disclosure - Quarterly Financial Data (Unaudited)',
#    'filename': 'R24.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Subsequent Events',
#    'long_name': '1026 - Disclosure - Subsequent Events',
#    'filename': 'R25.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Transactions with Related Parties',
#    'long_name': '1027 - Disclosure - Transactions with Related Parties',
#    'filename': 'R26.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Basis of Presentation and Summary of Significant Accounting Policies (Policies)',
#    'long_name': '1028 - Disclosure - Basis of Presentation and Summary of Significant Accounting Policies (Policies)',
#    'filename': 'R27.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Basis of Presentation and Summary of Significant Accounting Policies (Tables)',
#    'long_name': '1029 - Disclosure - Basis of Presentation and Summary of Significant Accounting Policies (Tables)',
#    'filename': 'R28.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Special Items, Net (Tables)',
#    'long_name': '1030 - Disclosure - Special Items, Net (Tables)',
#    'filename': 'R29.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Earnings Per Common Share (Tables)',
#    'long_name': '1031 - Disclosure - Earnings Per Common Share (Tables)',
#    'filename': 'R30.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Share Repurchase Programs and Dividends (Tables)',
#    'long_name': '1032 - Disclosure - Share Repurchase Programs and Dividends (Tables)',
#    'filename': 'R31.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt (Tables)',
#    'long_name': '1033 - Disclosure - Debt (Tables)',
#    'filename': 'R32.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Income Taxes (Tables)',
#    'long_name': '1034 - Disclosure - Income Taxes (Tables)',
#    'filename': 'R33.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Fair Value Measurements (Tables)',
#    'long_name': '1035 - Disclosure - Fair Value Measurements (Tables)',
#    'filename': 'R34.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans (Tables)',
#    'long_name': '1036 - Disclosure - Employee Benefit Plans (Tables)',
#    'filename': 'R35.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Accumulated Other Comprehensive Income (Loss) (Tables)',
#    'long_name': '1037 - Disclosure - Accumulated Other Comprehensive Income (Loss) (Tables)',
#    'filename': 'R36.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Commitments, Contingencies and Guarantees (Tables)',
#    'long_name': '1038 - Disclosure - Commitments, Contingencies and Guarantees (Tables)',
#    'filename': 'R37.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Supplemental Cash Flow Information (Tables)',
#    'long_name': '1039 - Disclosure - Supplemental Cash Flow Information (Tables)',
#    'filename': 'R38.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Operating Segments and Related Disclosures (Tables)',
#    'long_name': '1040 - Disclosure - Operating Segments and Related Disclosures (Tables)',
#    'filename': 'R39.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Share-based Compensation (Tables)',
#    'long_name': '1041 - Disclosure - Share-based Compensation (Tables)',
#    'filename': 'R40.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Valuation and Qualifying Accounts (Tables)',
#    'long_name': '1042 - Disclosure - Valuation and Qualifying Accounts (Tables)',
#    'filename': 'R41.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Quarterly Financial Data (Unaudited) (Tables)',
#    'long_name': '1043 - Disclosure - Quarterly Financial Data (Unaudited) (Tables)',
#    'filename': 'R42.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Transactions with Related Parties (Tables)',
#    'long_name': '1044 - Disclosure - Transactions with Related Parties (Tables)',
#    'filename': 'R43.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Basis of Presentation and Summary of Significant Accounting Policies - Additional Information (Detail)',
#    'long_name': '1045 - Disclosure - Basis of Presentation and Summary of Significant Accounting Policies - Additional Information (Detail)',
#    'filename': 'R44.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Basis of Presentation and Summary of Significant Accounting Policies - Summary of Depreciable Asset (Detail)',
#    'long_name': '1046 - Disclosure - Basis of Presentation and Summary of Significant Accounting Policies - Summary of Depreciable Asset (Detail)',
#    'filename': 'R45.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Basis of Presentation and Summary of Significant Accounting Policies - Schedule of Amortizable Intangible Assets (Detail)',
#    'long_name': '1047 - Disclosure - Basis of Presentation and Summary of Significant Accounting Policies - Schedule of Amortizable Intangible Assets (Detail)',
#    'filename': 'R46.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Basis of Presentation and Summary of Significant Accounting Policies - Schedule of Future Amortization Expense (Detail)',
#    'long_name': '1048 - Disclosure - Basis of Presentation and Summary of Significant Accounting Policies - Schedule of Future Amortization Expense (Detail)',
#    'filename': 'R47.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Basis of Presentation and Summary of Significant Accounting Policies - Components of Regional Expenses (Detail)',
#    'long_name': '1049 - Disclosure - Basis of Presentation and Summary of Significant Accounting Policies - Components of Regional Expenses (Detail)',
#    'filename': 'R48.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Basis of Presentation and Summary of Significant Accounting Policies - Components of Regional Expenses (Parenthetical) (Detail)',
#    'long_name': '1050 - Disclosure - Basis of Presentation and Summary of Significant Accounting Policies - Components of Regional Expenses (Parenthetical) (Detail)',
#    'filename': 'R49.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': "Special Items - Components of Company's Special Items, Net Included in Consolidated Statements of Operations (Detail)",
#    'long_name': "1051 - Disclosure - Special Items - Components of Company's Special Items, Net Included in Consolidated Statements of Operations (Detail)",
#    'filename': 'R50.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Special Items - Additional Disclosures (Detail)',
#    'long_name': '1052 - Disclosure - Special Items - Additional Disclosures (Detail)',
#    'filename': 'R51.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Earnings (Loss) per Share - Computation of Basic and Diluted Earnings per Common Share (Detail)',
#    'long_name': '1053 - Disclosure - Earnings (Loss) per Share - Computation of Basic and Diluted Earnings per Common Share (Detail)',
#    'filename': 'R52.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Earnings (Loss) per Share - Computation of Basic and Diluted Earnings per Common Share (Parenthetical) (Detail)',
#    'long_name': '1054 - Disclosure - Earnings (Loss) per Share - Computation of Basic and Diluted Earnings per Common Share (Parenthetical) (Detail)',
#    'filename': 'R53.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Share Repurchase Programs and Dividends - Share Repurchase Programs (Detail)',
#    'long_name': '1055 - Disclosure - Share Repurchase Programs and Dividends - Share Repurchase Programs (Detail)',
#    'filename': 'R54.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Share Repurchase Programs and Dividends - Dividends (Detail)',
#    'long_name': '1056 - Disclosure - Share Repurchase Programs and Dividends - Dividends (Detail)',
#    'filename': 'R55.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Components of Long-Term Debt (Detail)',
#    'long_name': '1057 - Disclosure - Debt - Components of Long-Term Debt (Detail)',
#    'filename': 'R56.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Summary of Availability under Revolving Credit Facilities (Detail)',
#    'long_name': '1058 - Disclosure - Debt - Summary of Availability under Revolving Credit Facilities (Detail)',
#    'filename': 'R57.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Additional Information (Detail)',
#    'long_name': '1059 - Disclosure - Debt - Additional Information (Detail)',
#    'filename': 'R58.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Schedule of Maturities of Long-Term Debt and Capital Leases (Detail)',
#    'long_name': '1060 - Disclosure - Debt - Schedule of Maturities of Long-Term Debt and Capital Leases (Detail)',
#    'filename': 'R59.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Components of Long-Term Debt - 2013, 2014 and 2016 Credit Facilities (Detail)',
#    'long_name': '1061 - Disclosure - Debt - Components of Long-Term Debt - 2013, 2014 and 2016 Credit Facilities (Detail)',
#    'filename': 'R60.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Components of Long-Term Debt - 2013, 2014 and 2016 Credit Facilities (Parenthetical) (Detail)',
#    'long_name': '1062 - Disclosure - Debt - Components of Long-Term Debt - 2013, 2014 and 2016 Credit Facilities (Parenthetical) (Detail)',
#    'filename': 'R61.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - 2013, 2014 and 2016 Credit Facilities (Detail)',
#    'long_name': '1063 - Disclosure - Debt - 2013, 2014 and 2016 Credit Facilities (Detail)',
#    'filename': 'R62.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Components of Long-Term Debt - 2016-1 Enhanced Equipment Trust Certificates (Detail)',
#    'long_name': '1064 - Disclosure - Debt - Components of Long-Term Debt - 2016-1 Enhanced Equipment Trust Certificates (Detail)',
#    'filename': 'R63.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Details of 2016-1 Enhanced Equipment Trust Certificates (Detail)',
#    'long_name': '1065 - Disclosure - Debt - Details of 2016-1 Enhanced Equipment Trust Certificates (Detail)',
#    'filename': 'R64.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Components of Long-Term Debt - 2016-2 Enhanced Equipment Trust Certificates (Detail)',
#    'long_name': '1066 - Disclosure - Debt - Components of Long-Term Debt - 2016-2 Enhanced Equipment Trust Certificates (Detail)',
#    'filename': 'R65.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Details of 2016-2 Enhanced Equipment Trust Certificates (Detail)',
#    'long_name': '1067 - Disclosure - Debt - Details of 2016-2 Enhanced Equipment Trust Certificates (Detail)',
#    'filename': 'R66.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Components of Long-Term Debt - 2016-3 Enhanced Equipment Trust Certificates (Detail)',
#    'long_name': '1068 - Disclosure - Debt - Components of Long-Term Debt - 2016-3 Enhanced Equipment Trust Certificates (Detail)',
#    'filename': 'R67.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Details of 2016-3 Enhanced Equipment Trust Certificates (Detail)',
#    'long_name': '1069 - Disclosure - Debt - Details of 2016-3 Enhanced Equipment Trust Certificates (Detail)',
#    'filename': 'R68.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Components of Long-Term Debt - Equipment Loans and Other Notes Payable Issued in 2016 (Detail)',
#    'long_name': '1070 - Disclosure - Debt - Components of Long-Term Debt - Equipment Loans and Other Notes Payable Issued in 2016 (Detail)',
#    'filename': 'R69.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Components of Long-Term Debt - Special Facility Revenue Bonds (Detail)',
#    'long_name': '1071 - Disclosure - Debt - Components of Long-Term Debt - Special Facility Revenue Bonds (Detail)',
#    'filename': 'R70.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Details of Senior Notes (Detail)',
#    'long_name': '1072 - Disclosure - Debt - Details of Senior Notes (Detail)',
#    'filename': 'R71.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Components of Long-Term Debt - Senior Notes (Detail)',
#    'long_name': '1073 - Disclosure - Debt - Components of Long-Term Debt - Senior Notes (Detail)',
#    'filename': 'R72.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Components of Long-Term Debt - Guarantees (Detail)',
#    'long_name': '1074 - Disclosure - Debt - Components of Long-Term Debt - Guarantees (Detail)',
#    'filename': 'R73.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Schedule of Collateral Coverage Tests (Detail)',
#    'long_name': '1075 - Disclosure - Debt - Schedule of Collateral Coverage Tests (Detail)',
#    'filename': 'R74.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Income Taxes - Components of Income Tax Provision (Benefit) (Detail)',
#    'long_name': '1076 - Disclosure - Income Taxes - Components of Income Tax Provision (Benefit) (Detail)',
#    'filename': 'R75.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Income Taxes - Computation of Income Tax Provision (Benefit) (Detail)',
#    'long_name': '1077 - Disclosure - Income Taxes - Computation of Income Tax Provision (Benefit) (Detail)',
#    'filename': 'R76.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Income Taxes (Detail)',
#    'long_name': '1078 - Disclosure - Income Taxes (Detail)',
#    'filename': 'R77.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Income Taxes - Deferred Tax Assets and Liabilities (Detail)',
#    'long_name': '1079 - Disclosure - Income Taxes - Deferred Tax Assets and Liabilities (Detail)',
#    'filename': 'R78.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Risk Management - Additional Information (Detail)',
#    'long_name': '1080 - Disclosure - Risk Management - Additional Information (Detail)',
#    'filename': 'R79.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Fair Value Measurements - Summary of Assets Measured at Fair Value on Recurring Basis (Detail)',
#    'long_name': '1081 - Disclosure - Fair Value Measurements - Summary of Assets Measured at Fair Value on Recurring Basis (Detail)',
#    'filename': 'R80.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Fair Value Measurements - Additional Information (Detail)',
#    'long_name': '1082 - Disclosure - Fair Value Measurements - Additional Information (Detail)',
#    'filename': 'R81.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Fair Value Measurements - Schedule of Carrying Value and Estimated Fair Value of Long-Term Debt, Including Current Maturities (Detail)',
#    'long_name': '1083 - Disclosure - Fair Value Measurements - Schedule of Carrying Value and Estimated Fair Value of Long-Term Debt, Including Current Maturities (Detail)',
#    'filename': 'R82.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Additional Information (Detail)',
#    'long_name': '1084 - Disclosure - Employee Benefit Plans - Additional Information (Detail)',
#    'filename': 'R83.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Changes in Projected Benefit Obligations (Detail)',
#    'long_name': '1085 - Disclosure - Employee Benefit Plans - Schedule of Changes in Projected Benefit Obligations (Detail)',
#    'filename': 'R84.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Changes in Fair Value of Plan Assets (Detail)',
#    'long_name': '1086 - Disclosure - Employee Benefit Plans - Schedule of Changes in Fair Value of Plan Assets (Detail)',
#    'filename': 'R85.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Changes in Fair Value of Plan Assets (Parenthetical) (Detail)',
#    'long_name': '1087 - Disclosure - Employee Benefit Plans - Schedule of Changes in Fair Value of Plan Assets (Parenthetical) (Detail)',
#    'filename': 'R86.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Amounts Recognized in Consolidated Balance Sheets (Detail)',
#    'long_name': '1088 - Disclosure - Employee Benefit Plans - Schedule of Amounts Recognized in Consolidated Balance Sheets (Detail)',
#    'filename': 'R87.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Amounts Recognized in Other Comprehensive Income (Detail)',
#    'long_name': '1089 - Disclosure - Employee Benefit Plans - Schedule of Amounts Recognized in Other Comprehensive Income (Detail)',
#    'filename': 'R88.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Amounts Recognized in Consolidated Balance Sheets (Parenthetical) (Detail)',
#    'long_name': '1090 - Disclosure - Employee Benefit Plans - Schedule of Amounts Recognized in Consolidated Balance Sheets (Parenthetical) (Detail)',
#    'filename': 'R89.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Accumulated Benefit Obligations Exceeding Fair Value of Plan Assets (Detail)',
#    'long_name': '1091 - Disclosure - Employee Benefit Plans - Schedule of Accumulated Benefit Obligations Exceeding Fair Value of Plan Assets (Detail)',
#    'filename': 'R90.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Components of Net Periodic Benefit Cost (Income) (Detail)',
#    'long_name': '1092 - Disclosure - Employee Benefit Plans - Components of Net Periodic Benefit Cost (Income) (Detail)',
#    'filename': 'R91.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Components of Net Periodic Benefit Cost (Income) (Parenthetical) (Detail)',
#    'long_name': '1093 - Disclosure - Employee Benefit Plans - Components of Net Periodic Benefit Cost (Income) (Parenthetical) (Detail)',
#    'filename': 'R92.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Assumption Used to Determine Benefit Obligations (Detail)',
#    'long_name': '1094 - Disclosure - Employee Benefit Plans - Schedule of Assumption Used to Determine Benefit Obligations (Detail)',
#    'filename': 'R93.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Assumption Used to Determine Benefit Obligations (Parenthetical) (Detail)',
#    'long_name': '1095 - Disclosure - Employee Benefit Plans - Schedule of Assumption Used to Determine Benefit Obligations (Parenthetical) (Detail)',
#    'filename': 'R94.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of One Percentage Point Change in Assumed Health Care Cost Trend Rates (Detail)',
#    'long_name': '1096 - Disclosure - Employee Benefit Plans - Schedule of One Percentage Point Change in Assumed Health Care Cost Trend Rates (Detail)',
#    'filename': 'R95.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Expected Future Service Benefit Payments (Detail)',
#    'long_name': '1097 - Disclosure - Employee Benefit Plans - Schedule of Expected Future Service Benefit Payments (Detail)',
#    'filename': 'R96.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Allocation of Plan Assets (Detail)',
#    'long_name': '1098 - Disclosure - Employee Benefit Plans - Schedule of Allocation of Plan Assets (Detail)',
#    'filename': 'R97.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Fair Value of Pension Plan Assets by Asset Category (Detail)',
#    'long_name': '1099 - Disclosure - Employee Benefit Plans - Schedule of Fair Value of Pension Plan Assets by Asset Category (Detail)',
#    'filename': 'R98.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Fair Value of Pension Plan Assets by Asset Category (Parenthetical) (Detail)',
#    'long_name': '1100 - Disclosure - Employee Benefit Plans - Schedule of Fair Value of Pension Plan Assets by Asset Category (Parenthetical) (Detail)',
#    'filename': 'R99.htm',
# ...
#    'filename': 'R51.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Basis of Presentation and Summary of Significant Accounting Policies - Changes in Loyalty Program Liability (Details)',
#    'long_name': '2401410 - Disclosure - Basis of Presentation and Summary of Significant Accounting Policies - Changes in Loyalty Program Liability (Details)',
#    'filename': 'R52.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Basis of Presentation and Summary of Significant Accounting Policies - Regional Expenses (Detail)',
#    'long_name': '2401411 - Disclosure - Basis of Presentation and Summary of Significant Accounting Policies - Regional Expenses (Detail)',
#    'filename': 'R53.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Special Items, Net (Details)',
#    'long_name': '2402402 - Disclosure - Special Items, Net (Details)',
#    'filename': 'R54.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Earnings Per Common Share (Details)',
#    'long_name': '2403402 - Disclosure - Earnings Per Common Share (Details)',
#    'filename': 'R55.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Share Repurchase Programs and Dividends - Share Repurchase Programs (Details)',
#    'long_name': '2404401 - Disclosure - Share Repurchase Programs and Dividends - Share Repurchase Programs (Details)',
#    'filename': 'R56.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Share Repurchase Programs and Dividends - Dividends (Details)',
#    'long_name': '2404402 - Disclosure - Share Repurchase Programs and Dividends - Dividends (Details)',
#    'filename': 'R57.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Components of Long-Term Debt (Details)',
#    'long_name': '2405402 - Disclosure - Debt - Components of Long-Term Debt (Details)',
#    'filename': 'R58.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Summary of Availability under Revolving Credit Facilities (Details)',
#    'long_name': '2405403 - Disclosure - Debt - Summary of Availability under Revolving Credit Facilities (Details)',
#    'filename': 'R59.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Schedule of Maturities of Long-Term Debt (Details)',
#    'long_name': '2405404 - Disclosure - Debt - Schedule of Maturities of Long-Term Debt (Details)',
#    'filename': 'R60.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - 2013, 2014 and 2016 Credit Facilities (Details)',
#    'long_name': '2405405 - Disclosure - Debt - 2013, 2014 and 2016 Credit Facilities (Details)',
#    'filename': 'R61.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - 2019-1 EETCs (Details)',
#    'long_name': '2405406 - Disclosure - Debt - 2019-1 EETCs (Details)',
#    'filename': 'R62.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - 2019-1 EETCs - Certain Information (Details)',
#    'long_name': '2405407 - Disclosure - Debt - 2019-1 EETCs - Certain Information (Details)',
#    'filename': 'R63.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Equipment Loans and Other Notes Payable Issued in 2019 (Details)',
#    'long_name': '2405408 - Disclosure - Debt - Equipment Loans and Other Notes Payable Issued in 2019 (Details)',
#    'filename': 'R64.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Senior Notes (Details)',
#    'long_name': '2405409 - Disclosure - Debt - Senior Notes (Details)',
#    'filename': 'R65.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Guarantees (Details)',
#    'long_name': '2405410 - Disclosure - Debt - Guarantees (Details)',
#    'filename': 'R66.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Debt - Collateral-Related Covenants (Details)',
#    'long_name': '2405411 - Disclosure - Debt - Collateral-Related Covenants (Details)',
#    'filename': 'R67.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Leases - Additional Information (Details)',
#    'long_name': '2406402 - Disclosure - Leases - Additional Information (Details)',
#    'filename': 'R68.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Leases - Components of Lease Expense (Details)',
#    'long_name': '2406403 - Disclosure - Leases - Components of Lease Expense (Details)',
#    'filename': 'R69.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Leases - Supplemental Balance Sheet Information (Details)',
#    'long_name': '2406404 - Disclosure - Leases - Supplemental Balance Sheet Information (Details)',
#    'filename': 'R70.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Leases - Supplemental Cash Flow and Other Information (Details)',
#    'long_name': '2406405 - Disclosure - Leases - Supplemental Cash Flow and Other Information (Details)',
#    'filename': 'R71.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Leases - Maturities of Lease Liabilities (Details)',
#    'long_name': '2406406 - Disclosure - Leases - Maturities of Lease Liabilities (Details)',
#    'filename': 'R72.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Income Taxes - Components of Income Tax Provision (Benefit) (Details)',
#    'long_name': '2407402 - Disclosure - Income Taxes - Components of Income Tax Provision (Benefit) (Details)',
#    'filename': 'R73.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Income Taxes - Reconciliation of Income Tax Provision (Details)',
#    'long_name': '2407403 - Disclosure - Income Taxes - Reconciliation of Income Tax Provision (Details)',
#    'filename': 'R74.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Income Taxes - Deferred Tax Assets and Liabilities (Details)',
#    'long_name': '2407404 - Disclosure - Income Taxes - Deferred Tax Assets and Liabilities (Details)',
#    'filename': 'R75.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Income Taxes - Additional Disclosures (Details)',
#    'long_name': '2407405 - Disclosure - Income Taxes - Additional Disclosures (Details)',
#    'filename': 'R76.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Risk Management (Details)',
#    'long_name': '2408401 - Disclosure - Risk Management (Details)',
#    'filename': 'R77.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Fair Value Measurements and Other Investments - Summary of Assets Measured at Fair Value on Recurring Basis (Details)',
#    'long_name': '2409402 - Disclosure - Fair Value Measurements and Other Investments - Summary of Assets Measured at Fair Value on Recurring Basis (Details)',
#    'filename': 'R78.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Fair Value Measurements and Other Investments - Schedule of Carrying Value and Estimated Fair Value of Long-Term Debt, Including Current Maturities (Details)',
#    'long_name': '2409403 - Disclosure - Fair Value Measurements and Other Investments - Schedule of Carrying Value and Estimated Fair Value of Long-Term Debt, Including Current Maturities (Details)',
#    'filename': 'R79.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Additional Information (Details)',
#    'long_name': '2410402 - Disclosure - Employee Benefit Plans - Additional Information (Details)',
#    'filename': 'R80.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Changes in Projected Benefit Obligations (Details)',
#    'long_name': '2410403 - Disclosure - Employee Benefit Plans - Schedule of Changes in Projected Benefit Obligations (Details)',
#    'filename': 'R81.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Changes in Fair Value of Plan Assets (Details)',
#    'long_name': '2410404 - Disclosure - Employee Benefit Plans - Schedule of Changes in Fair Value of Plan Assets (Details)',
#    'filename': 'R82.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Amounts Recognized in Consolidated Balance Sheets (Details)',
#    'long_name': '2410405 - Disclosure - Employee Benefit Plans - Schedule of Amounts Recognized in Consolidated Balance Sheets (Details)',
#    'filename': 'R83.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Amounts Recognized in Other Comprehensive Income (Details)',
#    'long_name': '2410406 - Disclosure - Employee Benefit Plans - Schedule of Amounts Recognized in Other Comprehensive Income (Details)',
#    'filename': 'R84.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Accumulated Benefit Obligations Exceeding Fair Value of Plan Assets (Details)',
#    'long_name': '2410407 - Disclosure - Employee Benefit Plans - Schedule of Accumulated Benefit Obligations Exceeding Fair Value of Plan Assets (Details)',
#    'filename': 'R85.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Components of Net Periodic Benefit Cost (Income) (Details)',
#    'long_name': '2410408 - Disclosure - Employee Benefit Plans - Components of Net Periodic Benefit Cost (Income) (Details)',
#    'filename': 'R86.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Assumption Used to Determine Benefit Obligations (Details)',
#    'long_name': '2410409 - Disclosure - Employee Benefit Plans - Schedule of Assumption Used to Determine Benefit Obligations (Details)',
#    'filename': 'R87.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of One Percentage Point Change in Assumed Health Care Cost Trend Rates (Details)',
#    'long_name': '2410410 - Disclosure - Employee Benefit Plans - Schedule of One Percentage Point Change in Assumed Health Care Cost Trend Rates (Details)',
#    'filename': 'R88.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Expected Future Service Benefit Payments (Details)',
#    'long_name': '2410411 - Disclosure - Employee Benefit Plans - Schedule of Expected Future Service Benefit Payments (Details)',
#    'filename': 'R89.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Allocation of Plan Assets (Details)',
#    'long_name': '2410412 - Disclosure - Employee Benefit Plans - Schedule of Allocation of Plan Assets (Details)',
#    'filename': 'R90.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Fair Value of Pension Plan Assets by Asset Category (Details)',
#    'long_name': '2410413 - Disclosure - Employee Benefit Plans - Schedule of Fair Value of Pension Plan Assets by Asset Category (Details)',
#    'filename': 'R91.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Schedule of Fair Value of Pension Plan Assets by Asset Category - Additional Information (Details)',
#    'long_name': '2410414 - Disclosure - Employee Benefit Plans - Schedule of Fair Value of Pension Plan Assets by Asset Category - Additional Information (Details)',
#    'filename': 'R92.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Changes in Fair Value Measurements of Level 3 Investments (Details)',
#    'long_name': '2410415 - Disclosure - Employee Benefit Plans - Changes in Fair Value Measurements of Level 3 Investments (Details)',
#    'filename': 'R93.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Fair Values of Retiree Medical and Other Postretirement Benefit Plans Assets by Asset Category (Details)',
#    'long_name': '2410416 - Disclosure - Employee Benefit Plans - Fair Values of Retiree Medical and Other Postretirement Benefit Plans Assets by Asset Category (Details)',
#    'filename': 'R94.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Defined Contribution and Multiemployer Plans (Details)',
#    'long_name': '2410417 - Disclosure - Employee Benefit Plans - Defined Contribution and Multiemployer Plans (Details)',
#    'filename': 'R95.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Employee Benefit Plans - Profit Sharing Program (Details)',
#    'long_name': '2410418 - Disclosure - Employee Benefit Plans - Profit Sharing Program (Details)',
#    'filename': 'R96.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Accumulated Other Comprehensive Loss - Components of Accumulated Other Comprehensive Loss (AOCI) (Details)',
#    'long_name': '2411402 - Disclosure - Accumulated Other Comprehensive Loss - Components of Accumulated Other Comprehensive Loss (AOCI) (Details)',
#    'filename': 'R97.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Accumulated Other Comprehensive Loss - Reclassifications out of AOCI (Details)',
#    'long_name': '2411403 - Disclosure - Accumulated Other Comprehensive Loss - Reclassifications out of AOCI (Details)',
#    'filename': 'R98.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Commitments, Contingencies and Guarantees - Aircraft, Engine and Other Purchase Commitments (Details)',
#    'long_name': '2412402 - Disclosure - Commitments, Contingencies and Guarantees - Aircraft, Engine and Other Purchase Commitments (Details)',
#    'filename': 'R99.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Commitments, Contingencies and Guarantees - Capacity Purchase Agreements (Details)',
#    'long_name': '2412403 - Disclosure - Commitments, Contingencies and Guarantees - Capacity Purchase Agreements (Details)',
#    'filename': 'R100.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Commitments, Contingencies and Guarantees - Additional Information (Details)',
#    'long_name': '2412404 - Disclosure - Commitments, Contingencies and Guarantees - Additional Information (Details)',
#    'filename': 'R101.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Supplemental Cash Flow Information (Details)',
#    'long_name': '2413402 - Disclosure - Supplemental Cash Flow Information (Details)',
#    'filename': 'R102.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Operating Segments and Related Disclosures (Details)',
#    'long_name': '2414401 - Disclosure - Operating Segments and Related Disclosures (Details)',
#    'filename': 'R103.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Share Based Compensation - Additional Information (Details)',
#    'long_name': '2415402 - Disclosure - Share Based Compensation - Additional Information (Details)',
#    'filename': 'R104.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Share Based Compensation - Restricted Stock Unit Awards (Details)',
#    'long_name': '2415403 - Disclosure - Share Based Compensation - Restricted Stock Unit Awards (Details)',
#    'filename': 'R105.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Valuation and Qualifying Accounts (Details)',
#    'long_name': '2416402 - Disclosure - Valuation and Qualifying Accounts (Details)',
#    'filename': 'R106.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Quarterly Financial Data - Summarized Financial Data (Details)',
#    'long_name': '2417402 - Disclosure - Quarterly Financial Data - Summarized Financial Data (Details)',
#    'filename': 'R107.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Quarterly Financial Data - Additional Information (Details)',
#    'long_name': '2417403 - Disclosure - Quarterly Financial Data - Additional Information (Details)',
#    'filename': 'R108.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Transactions with Related Parties - Net Receivables (Payables) to Related Parties (Details)',
#    'long_name': '2418402 - Disclosure - Transactions with Related Parties - Net Receivables (Payables) to Related Parties (Details)',
#    'filename': 'R109.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Transactions with Related Parties - Additional Information (Details)',
#    'long_name': '2418403 - Disclosure - Transactions with Related Parties - Additional Information (Details)',
#    'filename': 'R110.htm',
#    'filetype': 'htmlfilename'},
#   {'short_name': 'Subsequent Event (Details)',
#    'long_name': '2419401 - Disclosure - Subsequent Event (Details)',
#    'filename': 'R111.htm',
#    'filetype': 'htmlfilename'}]}

# %%
# Read in ticker list

filepath=os.path.join(PROJ_ROOT_PATH,'files','tickers')

with open(filepath, 'r') as f:
    
  tickers=f.readlines()
  
  #Remove trailing \n

  ticker_list = [item.strip() for item in tickers]
    
ticker_list
# Out:
# ['AA',
#  'AAL',
#  'AAP',
#  'AAPL',
#  'ABBV',
#  'ABNB',
#  'ABT',
#  'ACGL',
#  'ACHC',
#  'ACI',
#  'ACM',
#  'ACN',
#  'ADBE',
#  'ADI',
#  'ADM',
#  'ADP',
#  'ADSK',
#  'ADT',
#  'AEE',
#  'AEP',
#  'AES',
#  'AFG',
#  'AFL',
#  'AFRM',
#  'AGCO',
#  'AGL',
#  'AGNC',
#  'AGO',
#  'AGR',
#  'AIG',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'AL',
#  'ALB',
#  'ALGM',
#  'ALGN',
#  'ALK',
#  'ALL',
#  'ALLE',
#  'ALLY',
#  'ALNY',
#  'ALSN',
#  'AM',
#  'AMAT',
#  'AMC',
#  'AMCR',
#  'AMD',
#  'AME',
#  'AMED',
#  'AMG',
#  'AMGN',
#  'AMH',
#  'AMP',
#  'AMT',
#  'AMZN',
#  'AN',
#  'ANET',
#  'ANSS',
#  'AON',
#  'AOS',
#  'APA',
#  'APD',
#  'APH',
#  'APO',
#  'APP',
#  'APTV',
#  'AR',
#  'ARE',
#  'ARES',
#  'ARMK',
#  'ARW',
#  'ASH',
#  'ATO',
#  'ATR',
#  'ATUS',
#  'ATVI',
#  'AVB',
#  'AVGO',
#  'AVT',
#  'AVTR',
#  'AWI',
#  'AWK',
#  'AXON',
#  'AXS',
#  'AXTA',
#  'AYI',
#  'AYX',
#  'AZEK',
#  'AZO',
#  'AZTA',
#  'BA',
#  'BAC',
#  'BAH',
#  'BALL',
#  'BAX',
#  'BBWI',
#  'BBY',
#  'BC',
#  'BDX',
#  'BEN',
#  'BERY',
#  'BFAM',
#  'BG',
#  'BHF',
#  'BIIB',
#  'BILL',
#  'BIO',
#  'BJ',
#  'BK',
#  'BKI',
#  'BKNG',
#  'BLD',
#  'BLDR',
#  'BLK',
#  'BMRN',
#  'BMY',
#  'BOKF',
#  'BR',
#  'BRKR',
#  'BRO',
#  'BRX',
#  'BSX',
#  'BSY',
#  'BURL',
#  'BWA',
#  'BWXT',
#  'BX',
#  'BXP',
#  'BYD',
#  'C',
#  'CABO',
#  'CACC',
#  'CACI',
#  'CAG',
#  'CAH',
#  'CAR',
#  'CARR',
#  'CASY',
#  'CAT',
#  'CB',
#  'CBOE',
#  'CBRE',
#  'CBSH',
#  'CC',
#  'CCCS',
#  'CCI',
#  'CCK',
#  'CCL',
#  'CDAY',
#  'CDNS',
#  'CDW',
#  'CE',
#  'CEG',
#  'CERT',
#  'CF',
#  'CFG',
#  'CFLT',
#  'CFR',
#  'CG',
#  'CGNX',
#  'CHD',
#  'CHDN',
#  'CHE',
#  'CHH',
#  'CHK',
#  'CHPT',
#  'CHRW',
#  'CHTR',
#  'CI',
#  'CIEN',
#  'CINF',
#  'CL',
#  'CLH',
#  'CLVT',
#  'CLX',
#  'CMA',
#  'CMCSA',
#  'CME',
#  'CMG',
#  'CMI',
#  'CMS',
#  'CNA',
#  'CNC',
#  'CNM',
#  'CNP',
#  'CNXC',
#  'COF',
#  'COIN',
#  'COLB',
#  'COLD',
#  'COLM',
#  'COO',
#  'COST',
#  'COTY',
#  'CPB',
#  'CPRI',
#  'CPRT',
#  'CPT',
#  'CR',
#  'CRI',
#  'CRL',
#  'CRUS',
#  'CRWD',
#  'CSCO',
#  'CSGP',
#  'CSL',
#  'CSX',
#  'CTAS',
#  'CTLT',
#  'CTRA',
#  'CTSH',
#  'CTVA',
#  'CUBE',
#  'CUZ',
#  'CVNA',
#  'CVS',
#  'CVX',
#  'CW',
#  'CZR',
#  'D',
#  'DAL',
#  'DAR',
#  'DASH',
#  'DBX',
#  'DCI',
#  'DD',
#  'DDOG',
#  'DECK',
#  'DEI',
#  'DFS',
#  'DG',
#  'DGX',
#  'DH',
#  'DHI',
#  'DHR',
#  'DINO',
#  'DIS',
#  'DISH',
#  'DKNG',
#  'DKS',
#  'DLB',
#  'DLR',
#  'DLTR',
#  'DNA',
#  'DNB',
#  'DOCS',
#  'DOCU',
#  'DOV',
#  'DOW',
#  'DPZ',
#  'DRI',
#  'DRVN',
#  'DT',
#  'DTE',
#  'DTM',
#  'DUK',
#  'DV',
#  'DVA',
#  'DVN',
#  'DXC',
#  'DXCM',
#  'EA',
#  'EBAY',
#  'ECL',
#  'ED',
#  'EEFT',
#  'EFX',
#  'EGP',
#  'EHAB',
#  'EHC',
#  'EIX',
#  'EL',
#  'ELAN',
#  'ELS',
#  'ELV',
#  'EMN',
#  'EMR',
#  'ENOV',
#  'ENPH',
#  'ENTG',
#  'EOG',
#  'EPAM',
#  'EPR',
#  'EQH',
#  'EQIX',
#  'EQR',
#  'EQT',
#  'ERIE',
#  'ES',
#  'ESAB',
#  'ESI',
#  'ESS',
#  'ESTC',
#  'ETN',
#  'ETR',
#  'ETSY',
#  'EVA',
#  'EVR',
#  'EVRG',
#  'EW',
#  'EWBC',
#  'EXAS',
#  'EXC',
#  'EXEL',
#  'EXP',
#  'EXPD',
#  'EXPE',
#  'EXR',
#  'F',
#  'FAF',
#  'FANG',
#  'FAST',
#  'FCN',
#  'FCNCA',
#  'FCX',
#  'FDS',
#  'FDX',
#  'FE',
#  'FFIV',
#  'FG',
#  'FHB',
#  'FHN',
#  'FICO',
#  'FIS',
#  'FISV',
#  'FITB',
#  'FIVE',
#  'FIVN',
#  'FLO',
#  'FLS',
#  'FLT',
#  'FMC',
#  'FNB',
#  'FND',
#  'FNF',
#  'FOUR',
#  'FOX',
#  'FOXA',
#  'FR',
#  'FRPT',
#  'FRT',
#  'FSLR',
#  'FTNT',
#  'FTV',
#  'FWONA',
#  'FWONK',
#  'FYBR',
#  'G',
#  'GD',
#  'GDDY',
#  'GE',
#  'GGG',
#  'GILD',
#  'GIS',
#  'GL',
#  'GLPI',
#  'GLW',
#  'GM',
#  'GME',
#  'GMED',
#  'GNRC',
#  'GNTX',
#  'GO',
#  'GOOG',
#  'GOOGL',
#  'GPC',
#  'GPK',
#  'GPN',
#  'GPS',
#  'GRMN',
#  'GS',
#  'GTES',
#  'GWRE',
#  'GWW',
#  'GXO',
#  'H',
#  'HAL',
#  'HAS',
#  'HAYW',
#  'HBAN',
#  'HBI',
#  'HCA',
#  'HD',
#  'HE',
#  'HEI',
#  'HES',
#  'HHC',
#  'HIG',
#  'HII',
#  'HIW',
#  'HLT',
#  'HOG',
#  'HOLX',
#  'HON',
#  'HPE',
#  'HPP',
#  'HPQ',
#  'HR',
#  'HRB',
#  'HRL',
#  'HSIC',
#  'HST',
#  'HSY',
#  'HTZ',
#  'HUBB',
#  'HUBS',
#  'HUM',
#  'HUN',
#  'HWM',
#  'HXL',
#  'HZNP',
#  'IAC',
#  'IART',
#  'IBKR',
#  'IBM',
#  'ICE',
#  'ICUI',
#  'IDA',
#  'IDXX',
#  'IEX',
#  'IFF',
#  'ILMN',
#  'INCY',
#  'INFA',
#  'INGR',
#  'INTC',
#  'INTU',
#  'INVH',
#  'IONS',
#  'IP',
#  'IPG',
#  'IPGP',
#  'IQV',
#  'IR',
#  'IRM',
#  'ISRG',
#  'IT',
#  'ITT',
#  'ITW',
#  'IVZ',
#  'J',
#  'JAMF',
#  'JAZZ',
#  'JBGS',
#  'JBHT',
#  'JBL',
#  'JBLU',
#  'JCI',
#  'JEF',
#  'JHG',
#  'JKHY',
#  'JLL',
#  'JNJ',
#  'JNPR',
#  'JPM',
#  'JWN',
#  'K',
#  'KBR',
#  'KD',
#  'KDP',
#  'KEX',
#  'KEY',
#  'KEYS',
#  'KHC',
#  'KIM',
#  'KKR',
#  'KLAC',
#  'KMB',
#  'KMI',
#  'KMPR',
#  'KMX',
#  'KNX',
#  'KO',
#  'KR',
#  'KRC',
#  'KSS',
#  'L',
#  'LAD',
#  'LAMR',
#  'LAZ',
#  'LBRDA',
#  'LBRDK',
#  'LCID',
#  'LDOS',
#  'LEA',
#  'LECO',
#  'LEG',
#  'LEN',
#  'LESL',
#  'LFUS',
#  'LH',
#  'LHX',
#  'LII',
#  'LIN',
#  'LITE',
#  'LKQ',
#  'LLY',
#  'LMT',
#  'LNC',
#  'LNG',
#  'LNT',
#  'LOPE',
#  'LOW',
#  'LPLA',
#  'LPX',
#  'LRCX',
#  'LSCC',
#  'LSI',
#  'LSTR',
#  'LSXMA',
#  'LSXMK',
#  'LULU',
#  'LUMN',
#  'LUV',
#  'LVS',
#  'LW',
#  'LYB',
#  'LYFT',
#  'LYV',
#  'M',
#  'MA',
#  'MAA',
#  'MAN',
#  'MANH',
#  'MAR',
#  'MAS',
#  'MASI',
#  'MAT',
#  'MCD',
#  'MCHP',
#  'MCK',
#  'MCO',
#  'MCW',
#  'MDB',
#  'MDLZ',
#  'MDT',
#  'MDU',
#  'MET',
#  'META',
#  'MGM',
#  'MHK',
#  'MIDD',
#  'MKC',
#  'MKL',
#  'MKSI',
#  'MKTX',
#  'MLM',
#  'MMC',
#  'MMM',
#  'MNST',
#  'MO',
#  'MOH',
#  'MORN',
#  'MOS',
#  'MP',
#  'MPC',
#  'MPW',
#  'MPWR',
#  'MRCY',
#  'MRK',
#  'MRNA',
#  'MRO',
#  'MRTX',
#  'MRVI',
#  'MRVL',
#  'MS',
#  'MSA',
#  'MSCI',
#  'MSFT',
#  'MSGS',
#  'MSI',
#  'MSM',
#  'MTB',
#  'MTCH',
#  'MTD',
#  'MTG',
#  'MTN',
#  'MTZ',
#  'MU',
#  'NATI',
#  'NBIX',
#  'NCLH',
#  'NCNO',
#  'NCR',
#  'NDAQ',
#  'NDSN',
#  'NEE',
#  'NEM',
#  'NET',
#  'NEU',
#  'NEWR',
#  'NFE',
#  'NFG',
#  'NFLX',
#  'NI',
#  'NKE',
#  'NLY',
#  'NNN',
#  'NOC',
#  'NOV',
#  'NOW',
#  'NRG',
#  'NSA',
#  'NSC',
#  'NTAP',
#  'NTNX',
#  'NTRA',
#  'NTRS',
#  'NUE',
#  'NVAX',
#  'NVCR',
#  'NVDA',
#  'NVR',
#  'NVST',
#  'NVT',
#  'NWL',
#  'NWS',
#  'NWSA',
#  'NXST',
#  'NYCB',
#  'NYT',
#  'O',
#  'OC',
#  'ODFL',
#  'OGE',
#  'OGN',
#  'OHI',
#  'OKE',
#  'OKTA',
#  'OLED',
#  'OLLI',
#  'OLN',
#  'OLPX',
#  'OMC',
#  'OMF',
#  'ON',
#  'OPEN',
#  'ORCL',
#  'ORI',
#  'ORLY',
#  'OSH',
#  'OSK',
#  'OTIS',
#  'OVV',
#  'OWL',
#  'OXY',
#  'PACW',
#  'PAG',
#  'PANW',
#  'PARA',
#  'PARAA',
#  'PATH',
#  'PAYC',
#  'PAYX',
#  'PB',
#  'PCAR',
#  'PCG',
#  'PCOR',
#  'PCTY',
#  'PDCE',
#  'PEAK',
#  'PEG',
#  'PEGA',
#  'PEN',
#  'PENN',
#  'PEP',
#  'PFE',
#  'PFG',
#  'PFGC',
#  'PG',
#  'PGR',
#  'PH',
#  'PHM',
#  'PII',
#  'PINC',
#  'PINS',
#  'PK',
#  'PKG',
#  'PKI',
#  'PLD',
#  'PLNT',
#  'PLTK',
#  'PLTR',
#  'PLUG',
#  'PM',
#  'PNC',
#  'PNFP',
#  'PNR',
#  'PNW',
#  'PODD',
#  'POOL',
#  'POST',
#  'PPC',
#  'PPG',
#  'PPL',
#  'PRGO',
#  'PRI',
#  'PRU',
#  'PSA',
#  'PSTG',
#  'PSX',
#  'PTC',
#  'PTON',
#  'PVH',
#  'PWR',
#  'PXD',
#  'PYCR',
#  'PYPL',
#  'QCOM',
#  'QDEL',
#  'QRVO',
#  'QS',
#  'RARE',
#  'RE',
#  'REG',
#  'REGN',
#  'REXR',
#  'REYN',
#  'RF',
#  'RGA',
#  'RGEN',
#  'RH',
#  'RJF',
#  'RL',
#  'RMD',
#  'RNG',
#  'RNR',
#  'RRC',
#  'RRX',
#  'RS',
#  'RSG',
#  'RTX',
#  'RUN',
#  'RYN',
#  'S',
#  'SAM',
#  'SBUX',
#  'SCCO',
#  'SCHW',
#  'SCI',
#  'SEB',
#  'SEE',
#  'SEIC',
#  'SF',
#  'SGEN',
#  'SHC',
#  'SHW',
#  'SIRI',
#  'SITE',
#  'SIX',
#  'SJM',
#  'SKX',
#  'SLB',
#  'SLG',
#  'SLGN',
#  'SMAR',
#  'SMG',
#  'SNA',
#  'SNDR',
#  'SNOW',
#  'SNPS',
#  'SNV',
#  'SNX',
#  'SO',
#  'SOFI',
#  'SON',
#  'SPB',
#  'SPG',
#  'SPLK',
#  'SPR',
#  'SQ',
#  'SRC',
#  'SRCL',
#  'SRE',
#  'SSNC',
#  'SSRM',
#  'ST',
#  'STE',
#  'STLD',
#  'STT',
#  'STWD',
#  'STZ',
#  'SUI',
#  'SWK',
#  'SWKS',
#  'SWN',
#  'SYF',
#  'SYK',
#  'SYNH',
#  'SYY',
#  'T',
#  'TAP',
#  'TDC',
#  'TDG',
#  'TDOC',
#  'TDY',
#  'TECH',
#  'TER',
#  'TFC',
#  'TFSL',
#  'TFX',
#  'TGT',
#  'THC',
#  'THG',
#  'THO',
#  'TJX',
#  'TKR',
#  'TMO',
#  'TMUS',
#  'TNDM',
#  'TNL',
#  'TOL',
#  'TOST',
#  'TPL',
#  'TPR',
#  'TPX',
#  'TREX',
#  'TRGP',
#  'TRIP',
#  'TRMB',
#  'TROW',
#  'TRU',
#  'TRV',
#  'TSCO',
#  'TSLA',
#  'TSN',
#  'TT',
#  'TTC',
#  'TTD',
#  'TTEK',
#  'TTWO',
#  'TW',
#  'TWKS',
#  'TWLO',
#  'TXG',
#  'TXN',
#  'TXT',
#  'TYL',
#  'U',
#  'UA',
#  'UAA',
#  'UAL',
#  'UBER',
#  'UDR',
#  'UGI',
#  'UHAL',
#  'UHS',
#  'UI',
#  'ULTA',
#  'UNH',
#  'UNM',
#  'UNP',
#  'UNVR',
#  'UPS',
#  'UPST',
#  'URI',
#  'USB',
#  'USFD',
#  'UTHR',
#  'UWMC',
#  'V',
#  'VAC',
#  'VEEV',
#  'VFC',
#  'VICI',
#  'VIRT',
#  'VLO',
#  'VMC',
#  'VMI',
#  'VMW',
#  'VNO',
#  'VNT',
#  'VOYA',
#  'VRSK',
#  'VRSN',
#  'VRT',
#  'VRTX',
#  'VSAT',
#  'VSCO',
#  'VST',
#  'VTR',
#  'VTRS',
#  'VVV',
#  'VZ',
#  'W',
#  'WAB',
#  'WAL',
#  'WAT',
#  'WBA',
#  'WBD',
#  'WBS',
#  'WCC',
#  'WDAY',
#  'WDC',
#  'WE',
#  'WEC',
#  'WELL',
#  'WEN',
#  'WEX',
#  'WFC',
#  'WH',
#  'WHR',
#  'WLK',
#  'WM',
#  'WMB',
#  'WMS',
#  'WMT',
#  'WOLF',
#  'WOOF',
#  'WPC',
#  'WRB',
#  'WRK',
#  'WSC',
#  'WSM',
#  'WSO',
#  'WST',
#  'WTFC',
#  'WTM',
#  'WTRG',
#  'WTW',
#  'WU',
#  'WWD',
#  'WWE',
#  'WY',
#  'WYNN',
#  'X',
#  'XEL',
#  'XOM',
#  'XPO',
#  'XRAY',
#  'XYL',
#  'YETI',
#  'YUM',
#  'Z',
#  'ZBRA',
#  'ZG']

# %%
#Generate a dataframe with a list of all files for all tickers

df = pd.DataFrame()

for ticker in ticker_list:
  print(ticker) 
  reports = get_reports(ticker)

  for key, value in reports.items():
    tmp_df = pd.DataFrame.from_dict(reports[key])
    tmp_df['FYR'] = key
    tmp_df['ticker'] = ticker

    df = pd.concat([df,tmp_df])
# Out:
# AA
# AAL
# FilingSummary.xml not found:  AAL 10
# AAP
# FilingSummary.xml not found:  AAP 10
# AAPL
# ABBV
# FilingSummary.xml not found:  ABBV 13
# ABNB
# FilingSummary.xml not found:  ABNB 21
# ABT
# ACGL
# FilingSummary.xml not found:  ACGL 10
# ACHC
# ACI
# ACM
# ACN
# ADBE
# ADI
# ADM
# ADP
# ADSK
# ADT
# FilingSummary.xml not found:  ADT 18
# AEE
# AEP
# AES
# AFG
# FilingSummary.xml not found:  AFG 10
# AFL
# AFRM
# AGCO
# FilingSummary.xml not found:  AGCO 10
# AGL
# AGNC
# FilingSummary.xml not found:  AGNC 10
# FilingSummary.xml not found:  AGNC 11
# AGO
# FilingSummary.xml not found:  AGO 10
# AGR
# AIG
# AIZ
# AJG
# FilingSummary.xml not found:  AJG 10
# AKAM
# AL
# ALB
# FilingSummary.xml not found:  ALB 10
# ALGM
# ALGN
# FilingSummary.xml not found:  ALGN 10
# ALK
# FilingSummary.xml not found:  ALK 10
# ALL
# ALLE
# FilingSummary.xml not found:  ALLE 14
# ALLY
# FilingSummary.xml not found:  ALLY 10
# FilingSummary.xml not found:  ALLY 11
# ALNY
# FilingSummary.xml not found:  ALNY 10
# ALSN
# AM
# AMAT
# AMC
# FilingSummary.xml not found:  AMC 14
# AMCR
# AMD
# FilingSummary.xml not found:  AMD 10
# AME
# AMED
# AMG
# FilingSummary.xml not found:  AMG 10
# AMGN
# AMH
# AMP
# AMT
# AMZN
# AN
# FilingSummary.xml not found:  AN 10
# ANET
# ANSS
# FilingSummary.xml not found:  ANSS 10
# AON
# AOS
# FilingSummary.xml not found:  AOS 10
# APA
# APD
# APH
# APO
# APP
# APTV
# FilingSummary.xml not found:  APTV 12
# AR
# ARE
# FilingSummary.xml not found:  ARE 10
# ARES
# ARMK
# ARW
# FilingSummary.xml not found:  ARW 10
# ASH
# ATO
# ATR
# FilingSummary.xml not found:  ATR 10
# ATUS
# ATVI
# AVB
# AVGO
# AVT
# FilingSummary.xml not found:  AVT 11
# AVTR
# AWI
# FilingSummary.xml not found:  AWI 10
# FilingSummary.xml not found:  AWI 11
# AWK
# FilingSummary.xml not found:  AWK 10
# AXON
# AXS
# FilingSummary.xml not found:  AXS 10
# AXTA
# AYI
# FilingSummary.xml not found:  AYI 10
# AYX
# AZEK
# AZO
# AZTA
# BA
# BAC
# BAH
# FilingSummary.xml not found:  BAH 11
# BALL
# FilingSummary.xml not found:  BALL 10
# BAX
# BBWI
# BBY
# BC
# FilingSummary.xml not found:  BC 10
# FilingSummary.xml not found:  BC 11
# BDX
# BEN
# BERY
# BFAM
# FilingSummary.xml not found:  BFAM 13
# BG
# BHF
# BIIB
# BILL
# BIO
# FilingSummary.xml not found:  BIO 10
# BJ
# BK
# BKI
# BKNG
# FilingSummary.xml not found:  BKNG 10
# BLD
# BLDR
# FilingSummary.xml not found:  BLDR 10
# FilingSummary.xml not found:  BLDR 11
# BLK
# BMRN
# FilingSummary.xml not found:  BMRN 10
# BMY
# BOKF
# FilingSummary.xml not found:  BOKF 10
# BR
# FilingSummary.xml not found:  BR 10
# BRKR
# FilingSummary.xml not found:  BRKR 10
# FilingSummary.xml not found:  BRKR 11
# BRO
# FilingSummary.xml not found:  BRO 10
# BRX
# BSX
# BSY
# BURL
# BWA
# BWXT
# FilingSummary.xml not found:  BWXT 12
# FilingSummary.xml not found:  BWXT 11
# BX
# FilingSummary.xml not found:  BX 10
# BXP
# BYD
# FilingSummary.xml not found:  BYD 10
# FilingSummary.xml not found:  BYD 11
# C
# CABO
# CACC
# FilingSummary.xml not found:  CACC 10
# FilingSummary.xml not found:  CACC 11
# CACI
# FilingSummary.xml not found:  CACI 10
# CAG
# CAH
# FilingSummary.xml not found:  CAH 10
# CAR
# FilingSummary.xml not found:  CAR 10
# CARR
# CASY
# FilingSummary.xml not found:  CASY 10
# CAT
# CB
# CBOE
# FilingSummary.xml not found:  CBOE 11
# CBRE
# FilingSummary.xml not found:  CBRE 10
# CBSH
# FilingSummary.xml not found:  CBSH 10
# CC
# CCCS
# CCI
# FilingSummary.xml not found:  CCI 11
# CCK
# FilingSummary.xml not found:  CCK 10
# CCL
# CDAY
# CDNS
# FilingSummary.xml not found:  CDNS 10
# CDW
# FilingSummary.xml not found:  CDW 11
# CE
# CEG
# CERT
# FilingSummary.xml not found:  CERT 21
# CF
# CFG
# CFLT
# CFR
# FilingSummary.xml not found:  CFR 10
# CG
# CGNX
# FilingSummary.xml not found:  CGNX 10
# CHD
# FilingSummary.xml not found:  CHD 10
# CHDN
# FilingSummary.xml not found:  CHDN 10
# FilingSummary.xml not found:  CHDN 11
# CHE
# FilingSummary.xml not found:  CHE 10
# CHH
# FilingSummary.xml not found:  CHH 10
# CHK
# CHPT
# CHRW
# CHTR
# FilingSummary.xml not found:  CHTR 10
# FilingSummary.xml not found:  CHTR 11
# CI
# CIEN
# CINF
# FilingSummary.xml not found:  CINF 10
# CL
# CLH
# FilingSummary.xml not found:  CLH 10
# CLVT
# CLX
# CMA
# FilingSummary.xml not found:  CMA 10
# CMCSA
# CME
# CMG
# FilingSummary.xml not found:  CMG 10
# CMI
# CMS
# FilingSummary.xml not found:  CMS 10
# CNA
# FilingSummary.xml not found:  CNA 10
# FilingSummary.xml not found:  CNA 11
# CNC
# FilingSummary.xml not found:  CNC 10
# CNM
# CNP
# FilingSummary.xml not found:  CNP 11
# CNXC
# FilingSummary.xml not found:  CNXC 21
# COF
# FilingSummary.xml not found:  COF 11
# COIN
# COLB
# FilingSummary.xml not found:  COLB 10
# FilingSummary.xml not found:  COLB 11
# COLD
# FilingSummary.xml not found:  COLD 18
# COLM
# FilingSummary.xml not found:  COLM 10
# FilingSummary.xml not found:  COLM 11
# COO
# COST
# COTY
# FilingSummary.xml not found:  COTY 13
# CPB
# CPRI
# CPRT
# FilingSummary.xml not found:  CPRT 10
# FilingSummary.xml not found:  CPRT 11
# CPT
# FilingSummary.xml not found:  CPT 10
# CR
# FilingSummary.xml not found:  CR 10
# CRI
# FilingSummary.xml not found:  CRI 10
# CRL
# FilingSummary.xml not found:  CRL 10
# CRUS
# FilingSummary.xml not found:  CRUS 10
# FilingSummary.xml not found:  CRUS 11
# CRWD
# CSCO
# CSGP
# FilingSummary.xml not found:  CSGP 10
# FilingSummary.xml not found:  CSGP 11
# CSL
# FilingSummary.xml not found:  CSL 10
# CSX
# CTAS
# FilingSummary.xml not found:  CTAS 10
# CTLT
# CTRA
# CTSH
# CTVA
# CUBE
# FilingSummary.xml not found:  CUBE 10
# FilingSummary.xml not found:  CUBE 11
# CUZ
# FilingSummary.xml not found:  CUZ 10
# FilingSummary.xml not found:  CUZ 12
# FilingSummary.xml not found:  CUZ 11
# CVNA
# CVS
# CVX
# CW
# FilingSummary.xml not found:  CW 10
# CZR
# D
# DAL
# FilingSummary.xml not found:  DAL 10
# FilingSummary.xml not found:  DAL 11
# DAR
# FilingSummary.xml not found:  DAR 10
# DASH
# DBX
# DCI
# FilingSummary.xml not found:  DCI 10
# DD
# DDOG
# DECK
# FilingSummary.xml not found:  DECK 10
# DEI
# FilingSummary.xml not found:  DEI 10
# DFS
# DG
# FilingSummary.xml not found:  DG 10
# FilingSummary.xml not found:  DG 11
# DGX
# DH
# DHI
# DHR
# DINO
# DIS
# DISH
# DKNG
# DKS
# FilingSummary.xml not found:  DKS 10
# DLB
# DLR
# FilingSummary.xml not found:  DLR 10
# FilingSummary.xml not found:  DLR 11
# DLTR
# FilingSummary.xml not found:  DLTR 10
# FilingSummary.xml not found:  DLTR 12
# DNA
# DNB
# DOCS
# DOCU
# DOV
# DOW
# DPZ
# FilingSummary.xml not found:  DPZ 10
# FilingSummary.xml not found:  DPZ 11
# DRI
# DRVN
# FilingSummary.xml not found:  DRVN 21
# DT
# DTE
# DTM
# DUK
# DV
# DVA
# DVN
# DXC
# DXCM
# FilingSummary.xml not found:  DXCM 10
# FilingSummary.xml not found:  DXCM 11
# EA
# EBAY
# ECL
# ED
# EEFT
# FilingSummary.xml not found:  EEFT 10
# EFX
# FilingSummary.xml not found:  EFX 10
# EGP
# FilingSummary.xml not found:  EGP 10
# FilingSummary.xml not found:  EGP 11
# EHAB
# EHC
# FilingSummary.xml not found:  EHC 10
# EIX
# EL
# FilingSummary.xml not found:  EL 10
# ELAN
# ELS
# FilingSummary.xml not found:  ELS 10
# ELV
# EMN
# FilingSummary.xml not found:  EMN 10
# EMR
# ENOV
# ENPH
# ENTG
# FilingSummary.xml not found:  ENTG 10
# FilingSummary.xml not found:  ENTG 11
# EOG
# EPAM
# FilingSummary.xml not found:  EPAM 12
# EPR
# FilingSummary.xml not found:  EPR 10
# EQH
# EQIX
# FilingSummary.xml not found:  EQIX 10
# EQR
# EQT
# ERIE
# FilingSummary.xml not found:  ERIE 10
# ES
# ESAB
# ESI
# FilingSummary.xml not found:  ESI 14
# ESS
# FilingSummary.xml not found:  ESS 10
# ESTC
# ETN
# ETR
# FilingSummary.xml not found:  ETR 10
# ETSY
# EVA
# EVR
# FilingSummary.xml not found:  EVR 10
# FilingSummary.xml not found:  EVR 11
# EVRG
# EW
# FilingSummary.xml not found:  EW 10
# EWBC
# FilingSummary.xml not found:  EWBC 10
# FilingSummary.xml not found:  EWBC 11
# EXAS
# FilingSummary.xml not found:  EXAS 10
# FilingSummary.xml not found:  EXAS 11
# EXC
# EXEL
# FilingSummary.xml not found:  EXEL 10
# FilingSummary.xml not found:  EXEL 11
# EXP
# FilingSummary.xml not found:  EXP 10
# EXPD
# EXPE
# FilingSummary.xml not found:  EXPE 10
# EXR
# FilingSummary.xml not found:  EXR 10
# F
# FAF
# FANG
# FAST
# FCN
# FilingSummary.xml not found:  FCN 10
# FCNCA
# FilingSummary.xml not found:  FCNCA 10
# FCX
# FDS
# FilingSummary.xml not found:  FDS 10
# FDX
# FE
# FFIV
# FG
# FHB
# FHN
# FilingSummary.xml not found:  FHN 10
# FICO
# FIS
# FISV
# FITB
# FIVE
# FIVN
# FLO
# FilingSummary.xml not found:  FLO 10
# FLS
# FLT
# FilingSummary.xml not found:  FLT 11
# FMC
# FNB
# FilingSummary.xml not found:  FNB 10
# FND
# FNF
# FilingSummary.xml not found:  FNF 10
# FOUR
# FOX
# FOXA
# FR
# FilingSummary.xml not found:  FR 10
# FilingSummary.xml not found:  FR 12
# FilingSummary.xml not found:  FR 11
# FRPT
# FRT
# FilingSummary.xml not found:  FRT 10
# FSLR
# FTNT
# FilingSummary.xml not found:  FTNT 10
# FilingSummary.xml not found:  FTNT 12
# FilingSummary.xml not found:  FTNT 11
# FTV
# FWONA
# FWONK
# FYBR
# G
# FilingSummary.xml not found:  G 10
# GD
# GDDY
# GE
# GGG
# FilingSummary.xml not found:  GGG 10
# GILD
# GIS
# GL
# GLPI
# GLW
# GM
# FilingSummary.xml not found:  GM 10
# FilingSummary.xml not found:  GM 11
# GME
# GMED
# GNRC
# FilingSummary.xml not found:  GNRC 10
# FilingSummary.xml not found:  GNRC 11
# GNTX
# FilingSummary.xml not found:  GNTX 10
# GO
# GOOG
# GOOGL
# GPC
# GPK
# FilingSummary.xml not found:  GPK 10
# FilingSummary.xml not found:  GPK 11
# GPN
# FilingSummary.xml not found:  GPN 10
# GPS
# GRMN
# GS
# GTES
# FilingSummary.xml not found:  GTES 18
# GWRE
# GWW
# GXO
# H
# FilingSummary.xml not found:  H 10
# FilingSummary.xml not found:  H 11
# HAL
# HAS
# FilingSummary.xml not found:  HAS 10
# HAYW
# HBAN
# FilingSummary.xml not found:  HBAN 10
# HBI
# FilingSummary.xml not found:  HBI 10
# HCA
# FilingSummary.xml not found:  HCA 10
# FilingSummary.xml not found:  HCA 11
# HD
# HE
# FilingSummary.xml not found:  HE 10
# HEI
# HES
# HHC
# FilingSummary.xml not found:  HHC 11
# HIG
# FilingSummary.xml not found:  HIG 11
# HII
# HIW
# FilingSummary.xml not found:  HIW 10
# HLT
# FilingSummary.xml not found:  HLT 14
# HOG
# HOLX
# HON
# HPE
# HPP
# FilingSummary.xml not found:  HPP 15
# FilingSummary.xml not found:  HPP 11
# HPQ
# FilingSummary.xml not found:  HPQ 17
# HR
# HRB
# HRL
# HSIC
# FilingSummary.xml not found:  HSIC 10
# HST
# HSY
# HTZ
# HUBB
# FilingSummary.xml not found:  HUBB 10
# HUBS
# HUM
# HUN
# FilingSummary.xml not found:  HUN 10
# HWM
# HXL
# FilingSummary.xml not found:  HXL 10
# HZNP
# IAC
# IART
# FilingSummary.xml not found:  IART 10
# IBKR
# FilingSummary.xml not found:  IBKR 10
# IBM
# ICE
# ICUI
# IDA
# FilingSummary.xml not found:  IDA 10
# IDXX
# FilingSummary.xml not found:  IDXX 10
# IEX
# FilingSummary.xml not found:  IEX 10
# IFF
# FilingSummary.xml not found:  IFF 10
# ILMN
# FilingSummary.xml not found:  ILMN 10
# INCY
# FilingSummary.xml not found:  INCY 10
# FilingSummary.xml not found:  INCY 11
# INFA
# INGR
# FilingSummary.xml not found:  INGR 10
# INTC
# INTU
# INVH
# FilingSummary.xml not found:  INVH 17
# IONS
# FilingSummary.xml not found:  IONS 10
# IP
# IPG
# FilingSummary.xml not found:  IPG 10
# IPGP
# FilingSummary.xml not found:  IPGP 10
# FilingSummary.xml not found:  IPGP 11
# IQV
# IR
# IRM
# FilingSummary.xml not found:  IRM 10
# ISRG
# IT
# FilingSummary.xml not found:  IT 10
# ITT
# ITW
# IVZ
# J
# JAMF
# JAZZ
# FilingSummary.xml not found:  JAZZ 10
# FilingSummary.xml not found:  JAZZ 11
# JBGS
# JBHT
# FilingSummary.xml not found:  JBHT 10
# JBL
# FilingSummary.xml not found:  JBL 10
# JBLU
# FilingSummary.xml not found:  JBLU 10
# JCI
# JEF
# JHG
# JKHY
# FilingSummary.xml not found:  JKHY 10
# FilingSummary.xml not found:  JKHY 11
# JLL
# FilingSummary.xml not found:  JLL 10
# JNJ
# JNPR
# JPM
# JWN
# K
# KBR
# KD
# KDP
# FilingSummary.xml not found:  KDP 10
# KEX
# FilingSummary.xml not found:  KEX 10
# KEY
# KEYS
# FilingSummary.xml not found:  KEYS 14
# KHC
# KIM
# KKR
# FilingSummary.xml not found:  KKR 11
# KLAC
# FilingSummary.xml not found:  KLAC 10
# KMB
# KMI
# FilingSummary.xml not found:  KMI 11
# KMPR
# FilingSummary.xml not found:  KMPR 10
# KMX
# FilingSummary.xml not found:  KMX 10
# KNX
# FilingSummary.xml not found:  KNX 11
# KO
# KR
# KRC
# FilingSummary.xml not found:  KRC 10
# KSS
# L
# LAD
# FilingSummary.xml not found:  LAD 10
# FilingSummary.xml not found:  LAD 11
# LAMR
# FilingSummary.xml not found:  LAMR 10
# LAZ
# FilingSummary.xml not found:  LAZ 10
# LBRDA
# LBRDK
# LCID
# LDOS
# FilingSummary.xml not found:  LDOS 10
# LEA
# FilingSummary.xml not found:  LEA 10
# FilingSummary.xml not found:  LEA 11
# LECO
# FilingSummary.xml not found:  LECO 10
# LEG
# FilingSummary.xml not found:  LEG 10
# LEN
# FilingSummary.xml not found:  LEN 10
# LESL
# FilingSummary.xml not found:  LESL 20
# LFUS
# FilingSummary.xml not found:  LFUS 10
# FilingSummary.xml not found:  LFUS 11
# LH
# FilingSummary.xml not found:  LH 11
# LHX
# LII
# FilingSummary.xml not found:  LII 10
# LIN
# LITE
# LKQ
# FilingSummary.xml not found:  LKQ 10
# LLY
# LMT
# LNC
# LNG
# FilingSummary.xml not found:  LNG 10
# FilingSummary.xml not found:  LNG 12
# FilingSummary.xml not found:  LNG 11
# LNT
# FilingSummary.xml not found:  LNT 10
# LOPE
# FilingSummary.xml not found:  LOPE 10
# FilingSummary.xml not found:  LOPE 11
# LOW
# FilingSummary.xml not found:  LOW 10
# LPLA
# FilingSummary.xml not found:  LPLA 10
# FilingSummary.xml not found:  LPLA 11
# LPX
# FilingSummary.xml not found:  LPX 10
# FilingSummary.xml not found:  LPX 11
# LRCX
# FilingSummary.xml not found:  LRCX 10
# LSCC
# FilingSummary.xml not found:  LSCC 10
# FilingSummary.xml not found:  LSCC 11
# LSI
# FilingSummary.xml not found:  LSI 10
# LSTR
# FilingSummary.xml not found:  LSTR 10
# LSXMA
# LSXMK
# LULU
# FilingSummary.xml not found:  LULU 10
# LUMN
# LUV
# LVS
# FilingSummary.xml not found:  LVS 10
# FilingSummary.xml not found:  LVS 11
# LW
# LYB
# FilingSummary.xml not found:  LYB 11
# LYFT
# LYV
# FilingSummary.xml not found:  LYV 10
# FilingSummary.xml not found:  LYV 11
# M
# MA
# MAA
# FilingSummary.xml not found:  MAA 10
# MAN
# FilingSummary.xml not found:  MAN 10
# MANH
# FilingSummary.xml not found:  MANH 10
# FilingSummary.xml not found:  MANH 11
# MAR
# MAS
# MASI
# FilingSummary.xml not found:  MASI 10
# MAT
# MCD
# MCHP
# MCK
# MCO
# MCW
# MDB
# MDLZ
# MDT
# MDU
# MET
# META
# MGM
# FilingSummary.xml not found:  MGM 10
# MHK
# FilingSummary.xml not found:  MHK 10
# MIDD
# FilingSummary.xml not found:  MIDD 10
# MKC
# FilingSummary.xml not found:  MKC 10
# MKL
# FilingSummary.xml not found:  MKL 10
# MKSI
# FilingSummary.xml not found:  MKSI 10
# MKTX
# FilingSummary.xml not found:  MKTX 10
# FilingSummary.xml not found:  MKTX 11
# MLM
# FilingSummary.xml not found:  MLM 10
# MMC
# MMM
# MNST
# FilingSummary.xml not found:  MNST 10
# MO
# MOH
# FilingSummary.xml not found:  MOH 10
# FilingSummary.xml not found:  MOH 12
# FilingSummary.xml not found:  MOH 11
# MORN
# FilingSummary.xml not found:  MORN 10
# MOS
# FilingSummary.xml not found:  MOS 10
# MP
# MPC
# MPW
# FilingSummary.xml not found:  MPW 10
# FilingSummary.xml not found:  MPW 11
# MPWR
# FilingSummary.xml not found:  MPWR 10
# FilingSummary.xml not found:  MPWR 11
# MRCY
# FilingSummary.xml not found:  MRCY 10
# FilingSummary.xml not found:  MRCY 11
# MRK
# MRNA
# MRO
# MRTX
# MRVI
# FilingSummary.xml not found:  MRVI 21
# MRVL
# MS
# MSA
# FilingSummary.xml not found:  MSA 10
# MSCI
# FilingSummary.xml not found:  MSCI 10
# MSFT
# MSGS
# MSI
# MSM
# FilingSummary.xml not found:  MSM 10
# MTB
# MTCH
# FilingSummary.xml not found:  MTCH 10
# MTD
# FilingSummary.xml not found:  MTD 10
# MTG
# FilingSummary.xml not found:  MTG 10
# MTN
# FilingSummary.xml not found:  MTN 10
# MTZ
# FilingSummary.xml not found:  MTZ 10
# FilingSummary.xml not found:  MTZ 11
# MU
# FilingSummary.xml not found:  MU 10
# NATI
# FilingSummary.xml not found:  NATI 10
# NBIX
# FilingSummary.xml not found:  NBIX 10
# FilingSummary.xml not found:  NBIX 11
# NCLH
# FilingSummary.xml not found:  NCLH 13
# NCNO
# NCR
# FilingSummary.xml not found:  NCR 10
# NDAQ
# FilingSummary.xml not found:  NDAQ 10
# NDSN
# NEE
# NEM
# NET
# NEU
# FilingSummary.xml not found:  NEU 10
# NEWR
# NFE
# FilingSummary.xml not found:  NFE 19
# NFG
# NFLX
# NI
# FilingSummary.xml not found:  NI 10
# NKE
# NLY
# NNN
# FilingSummary.xml not found:  NNN 10
# NOC
# NOV
# NOW
# NRG
# NSA
# NSC
# NTAP
# FilingSummary.xml not found:  NTAP 10
# NTNX
# NTRA
# NTRS
# NUE
# NVAX
# FilingSummary.xml not found:  NVAX 10
# FilingSummary.xml not found:  NVAX 11
# NVCR
# NVDA
# NVR
# FilingSummary.xml not found:  NVR 10
# NVST
# NVT
# NWL
# FilingSummary.xml not found:  NWL 10
# NWS
# FilingSummary.xml not found:  NWS 13
# NWSA
# FilingSummary.xml not found:  NWSA 13
# NXST
# FilingSummary.xml not found:  NXST 10
# FilingSummary.xml not found:  NXST 12
# FilingSummary.xml not found:  NXST 11
# NYCB
# NYT
# FilingSummary.xml not found:  NYT 10
# O
# FilingSummary.xml not found:  O 10
# OC
# FilingSummary.xml not found:  OC 10
# ODFL
# FilingSummary.xml not found:  ODFL 10
# OGE
# FilingSummary.xml not found:  OGE 10
# OGN
# OHI
# FilingSummary.xml not found:  OHI 10
# OKE
# OKTA
# OLED
# FilingSummary.xml not found:  OLED 10
# FilingSummary.xml not found:  OLED 12
# FilingSummary.xml not found:  OLED 11
# OLLI
# OLN
# FilingSummary.xml not found:  OLN 10
# OLPX
# OMC
# FilingSummary.xml not found:  OMC 11
# OMF
# ON
# FilingSummary.xml not found:  ON 10
# OPEN
# ORCL
# ORI
# FilingSummary.xml not found:  ORI 10
# ORLY
# FilingSummary.xml not found:  ORLY 10
# OSH
# OSK
# OTIS
# OVV
# OWL
# OXY
# PACW
# FilingSummary.xml not found:  PACW 10
# FilingSummary.xml not found:  PACW 11
# PAG
# FilingSummary.xml not found:  PAG 10
# PANW
# FilingSummary.xml not found:  PANW 12
# PARA
# PARAA
# PATH
# PAYC
# PAYX
# PB
# FilingSummary.xml not found:  PB 10
# PCAR
# PCG
# PCOR
# PCTY
# PDCE
# FilingSummary.xml not found:  PDCE 10
# FilingSummary.xml not found:  PDCE 11
# PEAK
# PEG
# PEGA
# FilingSummary.xml not found:  PEGA 10
# FilingSummary.xml not found:  PEGA 11
# PEN
# PENN
# FilingSummary.xml not found:  PENN 10
# PEP
# PFE
# PFG
# PFGC
# PG
# PGR
# PH
# PHM
# FilingSummary.xml not found:  PHM 10
# PII
# FilingSummary.xml not found:  PII 10
# PINC
# PINS
# PK
# FilingSummary.xml not found:  PK 17
# PKG
# FilingSummary.xml not found:  PKG 10
# PKI
# FilingSummary.xml not found:  PKI 10
# PLD
# FilingSummary.xml not found:  PLD 10
# PLNT
# PLTK
# PLTR
# PLUG
# FilingSummary.xml not found:  PLUG 10
# FilingSummary.xml not found:  PLUG 11
# PM
# PNC
# PNFP
# FilingSummary.xml not found:  PNFP 10
# FilingSummary.xml not found:  PNFP 11
# PNR
# FilingSummary.xml not found:  PNR 10
# PNW
# FilingSummary.xml not found:  PNW 10
# PODD
# FilingSummary.xml not found:  PODD 10
# FilingSummary.xml not found:  PODD 11
# POOL
# FilingSummary.xml not found:  POOL 10
# POST
# PPC
# FilingSummary.xml not found:  PPC 11
# PPG
# PPL
# PRGO
# PRI
# FilingSummary.xml not found:  PRI 11
# PRU
# PSA
# PSTG
# PSX
# PTC
# PTON
# PVH
# FilingSummary.xml not found:  PVH 10
# PWR
# PXD
# PYCR
# PYPL
# QCOM
# QDEL
# QRVO
# QS
# RARE
# FilingSummary.xml not found:  RARE 14
# RE
# FilingSummary.xml not found:  RE 10
# REG
# FilingSummary.xml not found:  REG 10
# REGN
# FilingSummary.xml not found:  REGN 10
# REXR
# REYN
# FilingSummary.xml not found:  REYN 20
# RF
# FilingSummary.xml not found:  RF 11
# RGA
# FilingSummary.xml not found:  RGA 10
# RGEN
# FilingSummary.xml not found:  RGEN 10
# FilingSummary.xml not found:  RGEN 11
# RH
# RJF
# RL
# FilingSummary.xml not found:  RL 10
# RMD
# FilingSummary.xml not found:  RMD 10
# RNG
# RNR
# FilingSummary.xml not found:  RNR 10
# RRC
# FilingSummary.xml not found:  RRC 12
# FilingSummary.xml not found:  RRC 11
# RRX
# RS
# FilingSummary.xml not found:  RS 10
# RSG
# RTX
# RUN
# RYN
# FilingSummary.xml not found:  RYN 10
# S
# SAM
# FilingSummary.xml not found:  SAM 10
# FilingSummary.xml not found:  SAM 11
# SBUX
# SCCO
# SCHW
# SCI
# FilingSummary.xml not found:  SCI 10
# SEB
# FilingSummary.xml not found:  SEB 10
# FilingSummary.xml not found:  SEB 11
# SEE
# FilingSummary.xml not found:  SEE 10
# SEIC
# FilingSummary.xml not found:  SEIC 10
# SF
# FilingSummary.xml not found:  SF 10
# SGEN
# FilingSummary.xml not found:  SGEN 10
# FilingSummary.xml not found:  SGEN 11
# SHC
# FilingSummary.xml not found:  SHC 21
# SHW
# SIRI
# FilingSummary.xml not found:  SIRI 10
# SITE
# SIX
# FilingSummary.xml not found:  SIX 10
# FilingSummary.xml not found:  SIX 11
# SJM
# FilingSummary.xml not found:  SJM 10
# SKX
# FilingSummary.xml not found:  SKX 10
# FilingSummary.xml not found:  SKX 11
# SLB
# SLG
# FilingSummary.xml not found:  SLG 10
# SLGN
# FilingSummary.xml not found:  SLGN 10
# SMAR
# SMG
# SNA
# FilingSummary.xml not found:  SNA 10
# SNDR
# SNOW
# SNPS
# SNV
# FilingSummary.xml not found:  SNV 10
# SNX
# FilingSummary.xml not found:  SNX 10
# FilingSummary.xml not found:  SNX 11
# SO
# SOFI
# SON
# FilingSummary.xml not found:  SON 10
# SPB
# FilingSummary.xml not found:  SPB 10
# SPG
# SPLK
# SPR
# FilingSummary.xml not found:  SPR 10
# SQ
# FilingSummary.xml not found:  SQ 16
# SRC
# FilingSummary.xml not found:  SRC 10
# FilingSummary.xml not found:  SRC 11
# SRCL
# FilingSummary.xml not found:  SRCL 10
# SRE
# FilingSummary.xml not found:  SRE 12
# SSNC
# FilingSummary.xml not found:  SSNC 11
# SSRM
# ST
# FilingSummary.xml not found:  ST 11
# STE
# STLD
# STT
# STWD
# FilingSummary.xml not found:  STWD 10
# FilingSummary.xml not found:  STWD 11
# STZ
# FilingSummary.xml not found:  STZ 10
# SUI
# FilingSummary.xml not found:  SUI 10
# FilingSummary.xml not found:  SUI 12
# FilingSummary.xml not found:  SUI 11
# SWK
# FilingSummary.xml not found:  SWK 10
# SWKS
# SWN
# FilingSummary.xml not found:  SWN 16
# FilingSummary.xml not found:  SWN 11
# SYF
# SYK
# SYNH
# SYY
# T
# TAP
# TDC
# FilingSummary.xml not found:  TDC 10
# TDG
# TDOC
# TDY
# FilingSummary.xml not found:  TDY 10
# TECH
# FilingSummary.xml not found:  TECH 10
# TER
# FilingSummary.xml not found:  TER 10
# TFC
# TFSL
# TFX
# FilingSummary.xml not found:  TFX 10
# TGT
# THC
# FilingSummary.xml not found:  THC 10
# THG
# FilingSummary.xml not found:  THG 10
# THO
# FilingSummary.xml not found:  THO 10
# TJX
# TKR
# FilingSummary.xml not found:  TKR 10
# TMO
# TMUS
# FilingSummary.xml not found:  TMUS 10
# TNDM
# FilingSummary.xml not found:  TNDM 14
# TNL
# TOL
# TOST
# TPL
# TPR
# TPX
# FilingSummary.xml not found:  TPX 10
# TREX
# FilingSummary.xml not found:  TREX 10
# FilingSummary.xml not found:  TREX 11
# TRGP
# FilingSummary.xml not found:  TRGP 12
# FilingSummary.xml not found:  TRGP 11
# TRIP
# TRMB
# FilingSummary.xml not found:  TRMB 10
# TROW
# TRU
# TRV
# TSCO
# FilingSummary.xml not found:  TSCO 10
# TSLA
# FilingSummary.xml not found:  TSLA 11
# TSN
# TT
# TTC
# TTD
# TTEK
# TTWO
# TW
# TWKS
# TWLO
# TXG
# TXN
# TXT
# TYL
# FilingSummary.xml not found:  TYL 10
# FilingSummary.xml not found:  TYL 11
# U
# UA
# FilingSummary.xml not found:  UA 10
# UAA
# FilingSummary.xml not found:  UAA 10
# UAL
# FilingSummary.xml not found:  UAL 10
# UBER
# UDR
# FilingSummary.xml not found:  UDR 10
# UGI
# UHAL
# FilingSummary.xml not found:  UHAL 10
# FilingSummary.xml not found:  UHAL 11
# FilingSummary.xml not found:  UHAL 13
# UHS
# FilingSummary.xml not found:  UHS 10
# UI
# ULTA
# FilingSummary.xml not found:  ULTA 10
# FilingSummary.xml not found:  ULTA 11
# UNH
# UNM
# UNP
# UNVR
# UPS
# UPST
# FilingSummary.xml not found:  UPST 21
# URI
# FilingSummary.xml not found:  URI 10
# FilingSummary.xml not found:  URI 12
# FilingSummary.xml not found:  URI 11
# USB
# USFD
# UTHR
# FilingSummary.xml not found:  UTHR 10
# UWMC
# V
# VAC
# VEEV
# VFC
# VICI
# VIRT
# VLO
# VMC
# VMI
# FilingSummary.xml not found:  VMI 10
# VMW
# FilingSummary.xml not found:  VMW 10
# VNO
# VNT
# VOYA
# VRSK
# FilingSummary.xml not found:  VRSK 10
# FilingSummary.xml not found:  VRSK 11
# VRSN
# VRT
# VRTX
# FilingSummary.xml not found:  VRTX 10
# VSAT
# FilingSummary.xml not found:  VSAT 10
# VSCO
# VST
# VTR
# FilingSummary.xml not found:  VTR 11
# VTRS
# VVV
# FilingSummary.xml not found:  VVV 16
# FilingSummary.xml not found:  VVV 22
# VZ
# W
# WAB
# FilingSummary.xml not found:  WAB 10
# WAL
# FilingSummary.xml not found:  WAL 10
# FilingSummary.xml not found:  WAL 11
# WAT
# WBA
# WBD
# WBS
# FilingSummary.xml not found:  WBS 10
# WCC
# FilingSummary.xml not found:  WCC 10
# WDAY
# WDC
# WE
# WEC
# WELL
# FilingSummary.xml not found:  WELL 10
# FilingSummary.xml not found:  WELL 11
# WEN
# FilingSummary.xml not found:  WEN 10
# WEX
# FilingSummary.xml not found:  WEX 10
# WFC
# WH
# WHR
# FilingSummary.xml not found:  WHR 10
# WLK
# FilingSummary.xml not found:  WLK 10
# FilingSummary.xml not found:  WLK 11
# WM
# WMB
# WMS
# WMT
# WOLF
# WOOF
# FilingSummary.xml not found:  WOOF 21
# WPC
# FilingSummary.xml not found:  WPC 10
# WRB
# FilingSummary.xml not found:  WRB 10
# WRK
# WSC
# WSM
# FilingSummary.xml not found:  WSM 10
# WSO
# FilingSummary.xml not found:  WSO 10
# WST
# FilingSummary.xml not found:  WST 10
# FilingSummary.xml not found:  WST 12
# WTFC
# FilingSummary.xml not found:  WTFC 10
# WTM
# FilingSummary.xml not found:  WTM 10
# WTRG
# FilingSummary.xml not found:  WTRG 10
# WTW
# WU
# WWD
# WWE
# FilingSummary.xml not found:  WWE 10
# FilingSummary.xml not found:  WWE 11
# WY
# WYNN
# FilingSummary.xml not found:  WYNN 10
# X
# XEL
# XOM
# XPO
# FilingSummary.xml not found:  XPO 10
# FilingSummary.xml not found:  XPO 11
# XRAY
# XYL
# YETI
# YUM
# Z
# ZBRA
# FilingSummary.xml not found:  ZBRA 10
# ZG

# %%
#Save the dataframe as a pickle file

# Save to file

with open(PROJ_ROOT_PATH + '/pickle/filemap.pkl', 'wb') as f:
  pickle.dump(df, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       1 #Save the dataframe as a pickle file
#       2
#       3 # Save to file
#       5 with open(PROJ_ROOT_PATH + '/pickle/filemap.pkl', 'wb') as f:
# ----> 6   pickle.dump(df, f)
#
# NameError: name 'df' is not defined

# %%
# Save ticker list

with open(PROJ_ROOT_PATH + '/pickle/ticker_list.pkl', 'wb') as f:
  pickle.dump(ticker_list, f)

# %%
df = pd.read_pickle(PROJ_ROOT_PATH + '/pickle/filemap.pkl')
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = pd.read_pickle(PROJ_ROOT_PATH + '/pickle/filemap.pkl')
#
# File ~/projects/MD1/venv/lib/python3.9/site-packages/pandas/io/pickle.py:196, in read_pickle(filepath_or_buffer, compression, storage_options)
#     193     with warnings.catch_warnings(record=True):
#     194         # We want to silence any warnings about, e.g. moved modules.
#     195         warnings.simplefilter("ignore", Warning)
# --> 196         return pickle.load(handles.handle)
#     197 except excs_to_catch:
#     198     # e.g.
#     199     #  "No module named 'pandas.core.sparse.series'"
#     200     #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
#     201     return pc.load(handles.handle, encoding=None)
#
# EOFError: Ran out of input

# %%
df
# Out:
#                                                                                       short_name  \
# 0                                                                Document and Entity Information
# 1                                                           Statement of Consolidated Operations
# 2                                          Statement of Consolidated Comprehensive (Loss) Income
# 3                                                                     Consolidated Balance Sheet
# 4                                                           Statement of Consolidated Cash Flows
# ..                                                                                           ...
# 98                                              Self-Insurance - Additional Information (Detail)
# 99                                       Employee Benefit Plan - Additional Information (Detail)
# 100                            Segment Information and Revenue - Additional Information (Detail)
# 101                                Segment Information and Revenue - Revenue Categories (Detail)
# 102  Segment Information and Revenue - Reconciliation of Segment Gross Profit and Loss (Details)
#
#                                                                                                long_name  \
# 0                                                      1001 - Document - Document and Entity Information
# 1                                                1003 - Statement - Statement of Consolidated Operations
# 2                               1004 - Statement - Statement of Consolidated Comprehensive (Loss) Income
# 3                                                          1005 - Statement - Consolidated Balance Sheet
# 4                                                1006 - Statement - Statement of Consolidated Cash Flows
# ..                                                                                                   ...
# 98                               2488447 - Disclosure - Self-Insurance - Additional Information (Detail)
# 99                        2490448 - Disclosure - Employee Benefit Plan - Additional Information (Detail)
# 100             2493449 - Disclosure - Segment Information and Revenue - Additional Information (Detail)
# 101                 2494450 - Disclosure - Segment Information and Revenue - Revenue Categories (Detail)
# 102  2495451 - Disclosure - Segment Information and Revenue - Reconciliation of Segment Gross Profit ...
#
#      filename      filetype FYR ticker
# 0      R1.htm  htmlfilename  17     AA
# 1      R2.htm  htmlfilename  17     AA
# 2      R3.htm  htmlfilename  17     AA
# 3      R4.htm  htmlfilename  17     AA
# 4      R5.htm  htmlfilename  17     AA
# ..        ...           ...  ..    ...
# 98    R99.htm  htmlfilename  20     ZG
# 99   R100.htm  htmlfilename  20     ZG
# 100  R101.htm  htmlfilename  20     ZG
# 101  R102.htm  htmlfilename  20     ZG
# 102  R103.htm  htmlfilename  20     ZG
#
# [1009856 rows x 6 columns]

# %%
s_temp = df[df['long_name'].str.contains(r" - Statement - ")]['long_name'] \
             .str.split(r" - Statement - ",expand=True)[1].str.lower().unique()
s_temp = pd.Series(s_temp)
s_temp
# Out:
# 0                                                                      statement of consolidated operations
# 1                                                     statement of consolidated comprehensive (loss) income
# 2                                                                                consolidated balance sheet
# 3                                                                      statement of consolidated cash flows
# 4                                                               statement of changes in consolidated equity
#                                                        ...
# 2658    consolidated and combined statements of changes in stockholders' equity and comprehensive income...
# 2659                                         consolidated and combined statements of cash flows (unaudited)
# 2660              consolidated statements of shareholders' equity (deficit) and comprehensive income (loss)
# 2661    parenthetical data for consolidated statement of shareholders' equity (deficit) and comprehensiv...
# 2662    consolidated statements of shareholders' equity (deficit) and comprehensive income (loss) (paren...
# Length: 2663, dtype: object
